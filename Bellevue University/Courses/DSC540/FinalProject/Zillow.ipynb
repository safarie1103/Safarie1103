# %%
from lxml import html
import requests
import unicodecsv as csv
import argparse
import json
from bs4 import BeautifulSoup

# %%
def clean(text):
    if text:
        return ' '.join(' '.join(text).split())
    return None





def create_url(zipcode, filter):
    # Creating Zillow URL based on the filter.

    if filter == "newest":
        url = "https://www.zillow.com/homes/for_sale/{0}/0_singlestory/days_sort".format(zipcode)
    elif filter == "cheapest":
        url = "https://www.zillow.com/homes/for_sale/{0}/0_singlestory/pricea_sort/".format(zipcode)
    else:
        url = "https://www.zillow.com/homes/for_sale/{0}_rb/?fromHomePage=true&shouldFireSellPageImplicitClaimGA=false&fromHomePageTab=buy".format(zipcode)
    print(url)
    return url


def save_to_file(response):
    # saving response to `response.html`

    with open("response.html", 'w') as fp:
        fp.write(response.text)


def write_data_to_csv(data):
    # saving scraped data to csv.

    with open("properties-%s.csv" % (zipcode), 'wb') as csvfile:
        fieldnames = ['title', 'address', 'city', 'state', 'postal_code', 'price', 'facts and features', 'real estate provider', 'url']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)


def get_data_from_json(raw_json_data):
    # getting data from json (type 2 of their A/B testing page)

    cleaned_data = clean(raw_json_data).replace('<!--', "").replace("-->", "")
    properties_list = []

    try:
        json_data = json.loads(cleaned_data)
        search_results = json_data.get('searchResults').get('listResults', [])

        for properties in search_results:
            address = properties.get('addressWithZip')
            property_info = properties.get('hdpData', {}).get('homeInfo')
            city = property_info.get('city')
            state = property_info.get('state')
            postal_code = property_info.get('zipcode')
            price = properties.get('price')
            bedrooms = properties.get('beds')
            bathrooms = properties.get('baths')
            area = properties.get('area')
            info = f'{bedrooms} bds, {bathrooms} ba ,{area} sqft'
            broker = properties.get('brokerName')
            property_url = properties.get('detailUrl')
            title = properties.get('statusText')

            data = {'address': address,
                    'city': city,
                    'state': state,
                    'postal_code': postal_code,
                    'price': price,
                    'facts and features': info,
                    'real estate provider': broker,
                    'url': property_url,
                    'title': title}
            properties_list.append(data)

        return properties_list

    except ValueError:
        print("Invalid json")
        return None


def parse(zipcode, filter=None):
    url = create_url(zipcode, filter)
    response = get_response(url)

    if not response:
        print("Failed to fetch the page, please check `response.html` to see the response received from zillow.com.")
        return None

    parser = html.fromstring(response.text)
    search_results = parser.xpath("//div[@id='search-results']//article")

    if not search_results:
        print("parsing from json data")
        # identified as type 2 page
        raw_json_data = parser.xpath('//script[@data-zrr-shared-data-key="mobileSearchPageStore"]//text()')
        return get_data_from_json(raw_json_data)

    print("parsing from html page")
    properties_list = []
    for properties in search_results:
        raw_address = properties.xpath(".//span[@itemprop='address']//span[@itemprop='streetAddress']//text()")
        raw_city = properties.xpath(".//span[@itemprop='address']//span[@itemprop='addressLocality']//text()")
        raw_state = properties.xpath(".//span[@itemprop='address']//span[@itemprop='addressRegion']//text()")
        raw_postal_code = properties.xpath(".//span[@itemprop='address']//span[@itemprop='postalCode']//text()")
        raw_price = properties.xpath(".//span[@class='zsg-photo-card-price']//text()")
        raw_info = properties.xpath(".//span[@class='zsg-photo-card-info']//text()")
        raw_broker_name = properties.xpath(".//span[@class='zsg-photo-card-broker-name']//text()")
        url = properties.xpath(".//a[contains(@class,'overlay-link')]/@href")
        raw_title = properties.xpath(".//h4//text()")

        address = clean(raw_address)
        city = clean(raw_city)
        state = clean(raw_state)
        postal_code = clean(raw_postal_code)
        price = clean(raw_price)
        info = clean(raw_info).replace(u"\xb7", ',')
        broker = clean(raw_broker_name)
        title = clean(raw_title)
        property_url = "https://www.zillow.com" + url[0] if url else None
        is_forsale = properties.xpath('.//span[@class="zsg-icon-for-sale"]')

        properties = {'address': address,
                      'city': city,
                      'state': state,
                      'postal_code': postal_code,
                      'price': price,
                      'facts and features': info,
                      'real estate provider': broker,
                      'url': property_url,
                      'title': title}
        if is_forsale:
            properties_list.append(properties)
    return properties_list

# %%
url = create_url("78133","")
print(url)
# Out:
# https://www.zillow.com/homes/for_sale/78133_rb/?fromHomePage=true&shouldFireSellPageImplicitClaimGA=false&fromHomePageTab=buy
# https://www.zillow.com/homes/for_sale/78133_rb/?fromHomePage=true&shouldFireSellPageImplicitClaimGA=false&fromHomePageTab=buy

# %%
url="https://www.trulia.com/TX/Canyon_Lake/78133/"
response = get_response(url)
print(response.text)
# Out:
# status code received: 200
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><script>
#             window.__uspapi = function(command, version, callback) {
#               try {
#                 if (command === 'getUSPData') {
#                   var cookies = document.cookie.split(';');
#                   for (var i = 0; i < cookies.length; i++) {
#                     var cookie = cookies[i];
#                     var separatorIndex = cookie.indexOf('=');
#                     separatorIndex = separatorIndex < 0 ? cookie.length : separatorIndex;
#                     var cookie_name = decodeURIComponent(cookie.slice(0, separatorIndex).replace(/^\s+/, ''));
#                     if (cookie_name === 'usprivacy') {
#                       var uspString = decodeURIComponent(cookie.slice(separatorIndex + 1));
#                       callback({ version: version, uspString: uspString }, true);
#                       return;
#                     }
#                   }
#                 }
#               } catch (ex) {
#                 console.error(ex);
#               }
#               callback(null, false);
#             }
#
#             window.addEventListener('message', function(event) {
#               if (event && event.data && event.data.__uspapiCall) {
#                 window.__uspapi(
#                   event.data.__uspapiCall.command,
#                   event.data.__uspapiCall.version,
#                   function(data, success) {
#                     event.source.postMessage({
#                       __uspapiReturn: {
#                         returnValue: data,
#                         success: success,
#                         callId: event.data.__uspapiCall.callId
#                       }
#                     });
#                   }
#                 );
#               }
#             }, false);
#           </script><script>
#           window.trulia = window.trulia || {};
#           trulia.analytics = trulia.analytics || {};
#           trulia.analytics.automaticTrackState = false;
#         </script><style data-styled="kjzsGg inmahM bfmRJs fYgJnX bGszDK gBZyJP fNMKGX fvuCmi faAZJU buxSWU jZkUGk ktdObN IBNRr hFGnNb kumvrt dCeMHc ZgkBV bXFlOO kbIvfC gaDJiU eSBgcd gfnyjA ioFwXj iXPXzs kvhnhQ gJkXiX fNAZEr cXxjgC dSpwZH kbQVPR kqCUnO kZbhWa jbjNtt coXJy kWwGkS ilnCTJ gxjfUt kBfKeP kGlRoU fWVErM liRMYt ilWqyg fktMQQ iSpCWw bcHqd dkumKO ghPwXF kOTflL kNBbhi lcNNgu iahKtL dDYpyB BfBLT dBjOcI dEMVEd jIGxjA dkBjfX hgbrER cKksqA cFlLIz jtvyqB jCIsEf cLtGLl fOYmco ulsLG gwauQU bjWpdk bNGqqo hCHNHU eZsMcN laCDnn dQkAwQ cQXYZo hXCpqp czvezX cLWItX eHdwsb hzDLCq cuyNCJ cknFRB dVmMGh hMhIdB kCndDt kBVJLu eICseL jXnTqo hAWXCg gGTRtw faqTnc hWgsUV iQSGxZ eMnXuJ dkizBS MLLJw bumWFt iWugwH haUgfs gQFVfk fDvMaM jjWbLK dbHpFV jIQUBl irdxqq gTEzpL fGoYrJ bFWtgt bjkSbC cFfole fHLXOp ehWeYU gKJaNz kQJnzb ggsvKn clGuYl jfPWPB gBrrSa ikRpSq jVEtvE yBPkK liRlFI dfGhQm irmqAr jViosh eoYqRI fkwbDs bkyVoY bPeJil fZYJOZ eaauWM jwpuQL iCUPTM fKQzWD izHacP gIWWdz esIRaf bwKYWt ceaWvQ gkWsAI lVIkx cfYDZe kSTXzl bIgymU bXWAAO eQRIzw ezNsuk eTYjnc hvPboF bPLygi fuYoJK" data-styled-version="4.4.1">
# /* sc-component-id: MediaBlock__MediaContainer-ldzu2c-0 */
# .faqTnc{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: MediaBlock__MediaContent-ldzu2c-1 */
# .hWgsUV{margin:0 8px;} .hWgsUV:last-child{margin-right:0;} .hWgsUV:first-child{margin-left:0;}.iQSGxZ{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;} .iQSGxZ:last-child{margin-right:0;} .iQSGxZ:first-child{margin-left:0;}.eMnXuJ{margin:0 8px;overflow:hidden;} .eMnXuJ:last-child{margin-right:0;} .eMnXuJ:first-child{margin-left:0;}.dkizBS{margin:0 2px;} .dkizBS:last-child{margin-right:0;} .dkizBS:first-child{margin-left:0;}.MLLJw{margin:0 2px;overflow:hidden;} .MLLJw:last-child{margin-right:0;} .MLLJw:first-child{margin-left:0;}.bumWFt{margin:0 4px;} .bumWFt:last-child{margin-right:0;} .bumWFt:first-child{margin-left:0;}
# /* sc-component-id: getUiSvgContainer__SvgContainer-sc-12y8qp5-0 */
# .gfnyjA{width:24px !important;height:24px !important;display:inline-block;font-size:0;} .gfnyjA .svg{width:24px;} .gfnyjA .svg{height:24px;} .gfnyjA path{fill:rgb(0,120,130);}.ioFwXj{width:16px !important;height:16px !important;display:inline-block;font-size:0;} .ioFwXj .svg{width:16px;} .ioFwXj .svg{height:16px;} .ioFwXj path{fill:rgb(134,144,153);}.iXPXzs{width:24px !important;height:24px !important;display:inline-block;font-size:0;} .iXPXzs .svg{width:24px;} .iXPXzs .svg{height:24px;} .iXPXzs path{fill:rgb(255,255,255);}.kvhnhQ{width:16px !important;height:24px !important;display:inline-block;font-size:0;} .kvhnhQ .svg{width:16px;} .kvhnhQ .svg{height:24px;} .kvhnhQ path{fill:rgb(59,65,68);}.gJkXiX{width:24px !important;height:24px !important;display:inline-block;font-size:0;} .gJkXiX .svg{width:24px;} .gJkXiX .svg{height:24px;} .gJkXiX path{fill:rgb(59,65,68);}.fNAZEr{width:16px !important;height:16px !important;display:inline-block;font-size:0;} .fNAZEr .svg{width:16px;} .fNAZEr .svg{height:16px;} .fNAZEr path{fill:rgb(0,120,130);}.cXxjgC{width:20px !important;height:20px !important;display:inline-block;font-size:0;} .cXxjgC .svg{width:20px;} .cXxjgC .svg{height:20px;} .cXxjgC path{fill:rgb(255,94,63);}.dSpwZH{width:20px !important;height:20px !important;display:inline-block;font-size:0;} .dSpwZH .svg{width:20px;} .dSpwZH .svg{height:20px;} .dSpwZH path{fill:rgb(0,178,91);}.kbQVPR{width:20px !important;height:20px !important;display:inline-block;font-size:0;} .kbQVPR .svg{width:20px;} .kbQVPR .svg{height:20px;} .kbQVPR path{fill:rgb(0,120,130);}.kqCUnO{width:15px !important;height:15px !important;display:inline-block;font-size:0;} .kqCUnO .svg{width:15px;} .kqCUnO .svg{height:15px;} .kqCUnO path{fill:rgb(59,65,68);}
# /* sc-component-id: Text__TextBase-sc-1i9uasc-0 */
# .dVmMGh{font-weight:bold;}.hMhIdB{font-size:14px;line-height:1.43;} .hMhIdB .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;width:20.02px;}.kBVJLu{color:rgb(0,120,130);}
# /* sc-component-id: Text__TextContainerBase-sc-1i9uasc-1 */
# .ilWqyg{font-weight:bold;font-size:50px;line-height:1.12;} .ilWqyg .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:56.00000000000001px;width:56.00000000000001px;}.fktMQQ{font-size:20px;line-height:1.2;} .fktMQQ .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}.iSpCWw{font-weight:bold;font-size:38px;line-height:1.05;} .iSpCWw .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:39.9px;width:39.9px;}.bcHqd{font-weight:bold;font-size:24px;line-height:1.33;} .bcHqd .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:31.92px;width:31.92px;}.dkumKO{font-size:16px;line-height:1.5;} .dkumKO .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}.ghPwXF{white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.kOTflL{font-weight:bold;font-size:20px;line-height:1.2;} .kOTflL .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}.kNBbhi{font-weight:bold;font-size:20px;line-height:1.2;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;} .kNBbhi .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}.lcNNgu{font-size:16px;line-height:1.5;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;} .lcNNgu .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}.iahKtL{font-weight:bold;font-size:14px;line-height:1.43;} .iahKtL .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;width:20.02px;}.dDYpyB{color:rgb(134,144,153);font-size:12px;line-height:1.33;} .dDYpyB .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}.BfBLT{font-weight:bold;font-size:14px;line-height:1.43;} @media (min-width:376px){.BfBLT{font-size:14px;}} @media (min-width:570px){.BfBLT{font-size:14px;}} @media (min-width:768px){.BfBLT{font-size:16px;}} @media (min-width:376px){.BfBLT{line-height:1.43;}} @media (min-width:570px){.BfBLT{line-height:1.43;}} @media (min-width:768px){.BfBLT{line-height:1.5;}} .BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;width:20.02px;} @media (min-width:376px){.BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;}} @media (min-width:570px){.BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;}} @media (min-width:768px){.BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;}} @media (min-width:376px){.BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{width:20.02px;}} @media (min-width:570px){.BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{width:20.02px;}} @media (min-width:768px){.BfBLT .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{width:24px;}}.dBjOcI{font-weight:bold;}
# /* sc-component-id: Padding-sc-1d43y5s-0 */
# .fvuCmi{padding:0 8px 0 0;}.faAZJU{padding:8px 0 0 0;}.buxSWU{padding:16px 16px 0 16px;}.jZkUGk{padding:0 0 16px 0;}.ktdObN{padding:16px 0 0 0;}.IBNRr{padding:8px 16px 8px 16px;}.hFGnNb{padding:0 0 0 4px;}.kumvrt{padding:0 0 8px 0;}.dCeMHc{padding:0 4px 0 0;}.ZgkBV{padding:0 0 32px 0;}
# /* sc-component-id: sc-global-1528046865 */
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff") format("woff");font-weight:400;font-style:normal;font-display:swap;} @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff") format("woff");font-weight:600;font-style:normal;font-display:swap;} html,body{margin:0;padding:0;font-family:'TruliaSans',system,-apple-system,Roboto,Segoe UI Bold,Arial,sans-serif;color:rgb(59,65,68);background-color:rgb(255,255,255);font-size:16px;line-height:1.5;-webkit-letter-spacing:-.1px;-moz-letter-spacing:-.1px;-ms-letter-spacing:-.1px;letter-spacing:-.1px;} html .getUiSvgContainer__SvgContainer-sc-12y8qp5-0,body .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} *{box-sizing:border-box;} ::-moz-focus-inner{border:0;} a{color:rgb(0,120,130);-webkit-text-decoration:none;text-decoration:none;} ul{margin:0;padding:0;list-style:none;} h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:8px;} h1{font-size:28px;} h2{font-size:24px;} h3{font-size:20px;} h4{font-size:16px;} h5{font-size:14px;} h6{font-size:12px;} input,button,textarea{font-family:'TruliaSans',system,-apple-system,Roboto,Segoe UI Bold,Arial,sans-serif;font-size:16px;line-height:1.5;} input .getUiSvgContainer__SvgContainer-sc-12y8qp5-0,button .getUiSvgContainer__SvgContainer-sc-12y8qp5-0,textarea .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .modalActive{overflow:hidden !important;max-height:100%;}
# /* sc-component-id: FlexContainers__Rows-sc-1ezkc0e-0 */
# .hvPboF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;} @media (max-width:47.9375em){.hvPboF{display:block;}}
# /* sc-component-id: FlexContainers__Columns-sc-1ezkc0e-2 */
# .fkwbDs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}
# /* sc-component-id: getSvgContainer__SvgContainer-sc-30hfky-0 */
# .bfmRJs{width:70px;height:24px;display:inline-block;line-height:0;} .bfmRJs .svg{width:70px;} .bfmRJs .svg{height:24px;}.fYgJnX{width:20px;height:20px;display:inline-block;line-height:0;} .fYgJnX .svg{width:20px;} .fYgJnX .svg{height:20px;}
# /* sc-component-id: ButtonBase-c2s2ot-0 */
# .dbHpFV{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;} .dbHpFV path{-webkit-transition:fill 0.1s;transition:fill 0.1s;} .dbHpFV .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .dbHpFV::-moz-focus-inner{border:0;} .dbHpFV[class~='focus'],.dbHpFV:focus{outline:none;} .dbHpFV[disabled]{cursor:none;pointer-events:none;}
# /* sc-component-id: PrimaryButton-sc-2em7ay-0 */
# .fOYmco{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;box-shadow:0px 8px 20px -15px rgba(59,65,68,0.7);margin-bottom:16px;} .fOYmco path{-webkit-transition:fill 0.1s;transition:fill 0.1s;} .fOYmco .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .fOYmco::-moz-focus-inner{border:0;} .fOYmco[class~='focus'],.fOYmco:focus{outline:none;} .fOYmco[disabled]{cursor:none;pointer-events:none;} .fOYmco .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .fOYmco[class~='hover'],.fOYmco:hover{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);} .fOYmco[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.fOYmco:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);} .fOYmco[class~='focus'],.fOYmco:focus{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);} .fOYmco[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.fOYmco:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);} .fOYmco[class~='active'],.fOYmco:active{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;box-shadow:none;} .fOYmco[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.fOYmco:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .fOYmco[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;} .fOYmco[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}
# /* sc-component-id: Button-sc-1dzv3kc-0 */
# .gaDJiU{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);} .gaDJiU path{-webkit-transition:fill 0.1s;transition:fill 0.1s;} .gaDJiU .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .gaDJiU::-moz-focus-inner{border:0;} .gaDJiU[class~='focus'],.gaDJiU:focus{outline:none;} .gaDJiU[disabled]{cursor:none;pointer-events:none;} .gaDJiU:hover,.gaDJiU[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;} .gaDJiU[class~='focus'],.gaDJiU:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(134,144,153);} .gaDJiU[class~='active'],.gaDJiU:active{color:rgb(255,255,255);background-color:rgb(134,144,153);border-color:transparent;} .gaDJiU[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.gaDJiU:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .gaDJiU[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);} .gaDJiU[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}
# /* sc-component-id: Grid__CellBox-sc-5ig2n4-0 */
# .ilnCTJ{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;} @media (min-width:376px){.ilnCTJ{width:90%;}} @media (min-width:570px){.ilnCTJ{width:40%;}} @media (min-width:768px){.ilnCTJ{width:100%;}}.gxjfUt{height:60px;-webkit-order:1;-ms-flex-order:1;order:1;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}.kBfKeP{height:60px;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}.kGlRoU{width:100%;-webkit-order:1;-ms-flex-order:1;order:1;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;} @media (min-width:376px){.kGlRoU{width:100%;}} @media (min-width:570px){.kGlRoU{width:100%;}} @media (min-width:768px){.kGlRoU{width:33%;}} @media (min-width:993px){.kGlRoU{width:33%;}}.fWVErM{width:100%;-webkit-order:2;-ms-flex-order:2;order:2;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;} @media (min-width:376px){.fWVErM{width:100%;}} @media (min-width:570px){.fWVErM{width:100%;}} @media (min-width:768px){.fWVErM{width:33%;}} @media (min-width:993px){.fWVErM{width:33%;}}.liRMYt{width:100%;-webkit-order:3;-ms-flex-order:3;order:3;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;} @media (min-width:376px){.liRMYt{width:100%;}} @media (min-width:570px){.liRMYt{width:100%;}} @media (min-width:768px){.liRMYt{width:33%;}} @media (min-width:993px){.liRMYt{width:33%;}}
# /* sc-component-id: Grid__GridContainer-sc-5ig2n4-1 */
# .coXJy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;} .coXJy > .Grid__CellBox-sc-5ig2n4-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}.kWwGkS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;} .kWwGkS > .Grid__CellBox-sc-5ig2n4-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}
# /* sc-component-id: TertiaryButton-sc-1qjx54x-0 */
# .jtvyqB{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(255,255,255);background-color:rgb(217,60,35);border-color:transparent;} .jtvyqB path{-webkit-transition:fill 0.1s;transition:fill 0.1s;} .jtvyqB .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .jtvyqB::-moz-focus-inner{border:0;} .jtvyqB[class~='focus'],.jtvyqB:focus{outline:none;} .jtvyqB[disabled]{cursor:none;pointer-events:none;} .jtvyqB .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .jtvyqB[class~='hover'],.jtvyqB:hover{color:rgb(217,60,35);background-color:rgb(255,255,255);border-color:rgb(217,60,35);} .jtvyqB[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.jtvyqB:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(217,60,35);} .jtvyqB[class~='focus'],.jtvyqB:focus{color:rgb(217,60,35);background-color:rgb(255,234,216);border-color:rgb(217,60,35);} .jtvyqB[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.jtvyqB:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(217,60,35);} .jtvyqB[class~='active'],.jtvyqB:active{color:rgb(255,255,255);background-color:rgb(156,17,20);border-color:transparent;box-shadow:none;} .jtvyqB[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.jtvyqB:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .jtvyqB[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;} .jtvyqB[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}
# /* sc-component-id: Box-sc-8ox7qa-0 */
# .jIGxjA{display:block;}.dkBjfX{display:block;border-style:solid !important;border-color:rgb(205,209,212);border-width:0 0 1px 0;}.hgbrER{display:block;} @media (min-width:376px){.hgbrER{display:block;}} @media (min-width:570px){.hgbrER{display:block;}} @media (min-width:768px){.hgbrER{display:none;}} @media (min-width:993px){.hgbrER{display:none;}}.cKksqA{display:none;} @media (min-width:376px){.cKksqA{display:none;}} @media (min-width:570px){.cKksqA{display:none;}} @media (min-width:768px){.cKksqA{display:block;}} @media (min-width:993px){.cKksqA{display:none;}}.cFlLIz{display:none;} @media (min-width:376px){.cFlLIz{display:none;}} @media (min-width:570px){.cFlLIz{display:none;}} @media (min-width:768px){.cFlLIz{display:block;}}
# /* sc-component-id: Navbar__Nav-sc-1jgd0jm-0 */
# .kjzsGg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:64px;margin:0;padding:0 16px 0 16px;padding:0 calc(16px + env(safe-area-inset-right)) 0 calc(16px + env(safe-area-inset-left));background-color:rgb(255,255,255);position:relative;z-index:100;font-size:15px;border-bottom:1px solid rgb(232,233,234);} @media (max-width:62em){.kjzsGg{padding:0 12px;}}
# /* sc-component-id: Navbar__NavbarMobileMenuToggle-sc-1jgd0jm-1 */
# .eSBgcd{margin-left:16px;margin-top:8px;cursor:pointer;border:none;background-color:rgb(255,255,255);} @media (max-width:62em){.eSBgcd{margin-right:-10px;margin-left:2px;}}
# /* sc-component-id: Navbar__LogoContainer-sc-1jgd0jm-2 */
# .inmahM{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding:16px 24px 16px 0;} @media (max-width:62em){.inmahM{padding:20px 12px 12px 12px;}}
# /* sc-component-id: BoxButton-sc-100k4t8-0 */
# .dfGhQm{cursor:pointer;display:inline;} .dfGhQm[role='button']:focus,.dfGhQm[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(134,144,153);}
# /* sc-component-id: UiButton-s4vt60-0 */
# .liRlFI{line-height:1;color:inherit;}
# /* sc-component-id: NavbarItem-sc-14jn7y9-0 */
# .kbIvfC{color:rgb(59,65,68);-webkit-transition:background 0.15s ease-in-out;transition:background 0.15s ease-in-out;position:relative;} .kbIvfC > a,.kbIvfC > span,.kbIvfC > button:not(.Button-sc-1dzv3kc-0){cursor:pointer;padding:8px 16px 8px 16px;color:rgb(59,65,68);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:8px;} .kbIvfC > a:focus svg path,.kbIvfC > span:focus svg path,.kbIvfC > button:not(.Button-sc-1dzv3kc-0):focus svg path{fill:rgb(59,65,68);} .kbIvfC svg{margin-top:-1px;} .kbIvfC > span{cursor:default;} .kbIvfC:hover > a,.kbIvfC:hover > span,.kbIvfC:hover > button:not(.Button-sc-1dzv3kc-0){color:rgb(255,255,255);background-color:rgb(0,120,130);} .kbIvfC:hover > a svg path,.kbIvfC:hover > span svg path,.kbIvfC:hover > button:not(.Button-sc-1dzv3kc-0) svg path{fill:rgb(255,255,255);} .kbIvfC:hover > ul{display:block;} .kbIvfC:hover > ul::before{display:block;position:absolute;content:'';width:100%;height:15px;top:-15px;} .kbIvfC ul{display:none;position:absolute;top:45px;background:rgb(255,255,255);border-radius:4px;box-shadow:0 2px 4px 0 rgba(59,65,68,0.5);padding:4px 0;} .kbIvfC ul a,.kbIvfC ul button{color:rgb(59,65,68);white-space:nowrap;display:block;} .kbIvfC ul a:hover,.kbIvfC ul button:hover{color:rgb(59,65,68);background-color:rgb(232,233,234);}
# /* sc-component-id: GlobalNavigationButton-x5u2ga-0 */
# .bXFlOO{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:transparent;} .bXFlOO path{-webkit-transition:fill 0.1s;transition:fill 0.1s;} .bXFlOO .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .bXFlOO::-moz-focus-inner{border:0;} .bXFlOO[class~='focus'],.bXFlOO:focus{outline:none;} .bXFlOO[disabled]{cursor:none;pointer-events:none;} .bXFlOO .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(59,65,68);} .bXFlOO[class~='hover'],.bXFlOO:hover{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transprant;} .bXFlOO[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.bXFlOO:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .bXFlOO[class~='focus'],.bXFlOO:focus{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);} .bXFlOO[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.bXFlOO:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);} .bXFlOO[class~='active'],.bXFlOO:active{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;box-shadow:none;} .bXFlOO[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.bXFlOO:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(59,65,68);} .bXFlOO[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;} .bXFlOO[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}
# /* sc-component-id: List__ListContainer-sc-1mezygb-0 */
# .cknFRB li{display:inline-block;border-style:none;margin-right:8px;} .cknFRB li:last-child{margin:0;}
# /* sc-component-id: NavbarContainer__SearchBarSection-sc-1uz2f9m-1 */
# .dQkAwQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;-webkit-flex:0 1 420px;-ms-flex:0 1 420px;flex:0 1 420px;} .dQkAwQ:first-of-type{padding-left:0;} @media (min-width:1060px){} @media (min-width:1240px){} @media (max-width:62em){.dQkAwQ{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}}
# /* sc-component-id: NavbarContainer__NavLinkSection-sc-1uz2f9m-2 */
# .bGszDK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} .bGszDK:first-of-type{padding-left:0;} @media (min-width:1060px){} @media (min-width:1240px){} @media (max-width:1060px){.bGszDK{display:none;}}.gBZyJP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} .gBZyJP:first-of-type{padding-left:0;} @media (min-width:1060px){} @media (min-width:1240px){} @media (max-width:1240px){.gBZyJP{display:none;}} @media (max-width:1060px){.gBZyJP{display:none;}}
# /* sc-component-id: NavbarContainer__UserButtonsSection-sc-1uz2f9m-3 */
# .fNMKGX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;} .fNMKGX:first-of-type{padding-left:0;} @media (min-width:1060px){} @media (min-width:1240px){} @media (max-width:62em){.fNMKGX{display:none;}}
# /* sc-component-id: LocationAutosuggestInput__Input-sc-113k62k-0 */
# .czvezX{border:1px solid rgb(245,246,247);border-radius:8px;background-color:rgb(245,246,247);padding:8px 64px 8px 16px;color:rgb(59,65,68);font-size:16px;line-height:1.5;width:100%;height:42px;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;display:inline-block;-webkit-appearance:none;-moz-appearance:none;appearance:none;} .czvezX.react-autosuggest__input--open{border:1px solid rgb(245,246,247);border-radius:8px;border-bottom-left-radius:0px;border-bottom-right-radius:0px;border-bottom:none;} .czvezX .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;} .czvezX::-webkit-input-placeholder{color:rgb(134,144,153);} .czvezX::-moz-placeholder{color:rgb(134,144,153);} .czvezX:-ms-input-placeholder{color:rgb(134,144,153);} .czvezX::placeholder{color:rgb(134,144,153);} .czvezX[placeholder]{text-overflow:ellipsis;} .czvezX::-ms-clear{display:none;} .czvezX:focus{border-color:rgb(205,209,212);background-color:rgb(255,255,255);outline:none;} .czvezX:focus{padding-right:80px;}
# /* sc-component-id: LocationAutosuggestInput__InputContainer-sc-113k62k-1 */
# .hXCpqp{position:relative;}
# /* sc-component-id: LocationAutosuggestInput__RightInnerIcon-sc-113k62k-2 */
# .cLWItX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;right:48px;top:0;height:100%;padding:12px;} input:not(:focus) + .cLWItX{display:none;}
# /* sc-component-id: LocationAutosuggestInput__RightIcon-sc-113k62k-3 */
# .eHdwsb{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;right:0;top:0;height:100%;min-width:42px;cursor:pointer;background-color:rgb(217,60,35);padding:9px 12px;border-bottom-right-radius:8px;border-top-right-radius:8px;-webkit-transition:background-color 0.15s ease;transition:background-color 0.15s ease;} .react-autosuggest__input--open ~ .eHdwsb{border-bottom-right-radius:0;} .eHdwsb:hover{background-color:rgb(156,17,20);}
# /* sc-component-id: LocationAutosuggestDrodown__LocationAutosuggestDropdown-sc-1qu0vk4-0 */
# .hzDLCq{border:1px solid rgb(205,209,212);border-top:none;border-bottom-right-radius:8px;border-bottom-left-radius:8px;position:absolute;width:100%;background:white;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;max-height:50vh;overflow:auto;-webkit-overflow-scrolling:touch;opacity:0;}
# /* sc-component-id: LocationAutosuggestDrodown__LocationAutosuggestBoxContainer-sc-1qu0vk4-3 */
# .cQXYZo{position:relative;width:100%;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;} .cQXYZo .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-1qu0vk4-2{border-top:1px solid rgb(205,209,212);} .cQXYZo .react-autosuggest__section-title + .react-autosuggest__suggestions-list > .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-1qu0vk4-2{border-top:none;}
# /* sc-component-id: FooterAnchor__Anchor-b00yg-0 */
# .eZsMcN{color:rgb(59,65,68);} .eZsMcN:hover{color:rgb(0,120,130);} @media (max-width:23.4375em){.eZsMcN{line-height:25px;}}
# /* sc-component-id: Copyright__Container-crgciy-0 */
# .hCHNHU{padding:16px env(safe-area-inset-right) env(safe-area-inset-bottom) env(safe-area-inset-left);font-size:10px;line-height:1.6;} .hCHNHU .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:16px;width:16px;}
# /* sc-component-id: Accessibility__Container-mmbqg0-0 */
# .bjWpdk{padding:16px env(safe-area-inset-right) 16px env(safe-area-inset-left);font-size:12px;line-height:1.33;} .bjWpdk .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;} @media (max-width:23.4375em){.bjWpdk{line-height:22px;}}
# /* sc-component-id: Footer__FooterContainer-sc-1vgcaho-0 */
# .gwauQU{padding:0;font-size:12px;line-height:1.33;} .gwauQU .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}
# /* sc-component-id: LinkColumn__Link-qxr6c7-0 */
# .gkWsAI{color:rgb(59,65,68);padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;} .gkWsAI:hover{color:rgb(0,120,130);} .gkWsAI div{padding-right:24px;} @media (max-width:47.9375em){.gkWsAI{display:inline;}.gkWsAI:after{content:' • ';}.gkWsAI:last-child:after{content:'';}} @media (max-width:23.4375em){.gkWsAI{line-height:25px;}}.lVIkx{color:rgb(59,65,68);padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:none;} .lVIkx:hover{color:rgb(0,120,130);} .lVIkx div{padding-right:24px;} @media (max-width:23.4375em){.lVIkx{line-height:25px;}}
# /* sc-component-id: LinkColumn__LinkColumnHeading-qxr6c7-1 */
# .ceaWvQ{padding:32px 0 8px 0;} @media (min-width:48em){.ceaWvQ{padding:2px 0;}} .ceaWvQ a{color:rgb(59,65,68);} .ceaWvQ a:hover{color:rgb(0,120,130);}
# /* sc-component-id: LinkColumn__ToggleMenuButton-qxr6c7-2 */
# .cfYDZe{position:relative;cursor:pointer;color:rgb(0,173,187);font-size:12px;line-height:1.33;padding:0;background:none;border:none;} .cfYDZe .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}
# /* sc-component-id: LinkColumn__Column-qxr6c7-3 */
# .bwKYWt{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;margin-left:8px;} .bwKYWt:first-child{margin-left:0;} @media (max-width:47.9375em){.bwKYWt{-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;margin-left:0;}}
# /* sc-component-id: NavigationSecondary__Container-sc-12kqh3d-0 */
# .gIWWdz{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}
# /* sc-component-id: NavigationSecondary__Inner-sc-12kqh3d-1 */
# .esIRaf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:0 0 24px;} @media (max-width:47.9375em){.esIRaf{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}
# /* sc-component-id: FooterLinkList__Container-sc-1hgdfiw-0 */
# .kSTXzl{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}
# /* sc-component-id: FooterLinkList__LinkLabel-sc-1hgdfiw-1 */
# .bXWAAO{padding:0 8px 0 0;}
# /* sc-component-id: FooterLinkList__LinkList-sc-1hgdfiw-2 */
# .bIgymU{list-style:none;display:inline-block;margin:0;padding:16px 0 16px;} .bIgymU li{display:inline;} .bIgymU li + li::before{content:'•';padding:0 4px;}
# /* sc-component-id: BasicFooter__FooterContainer-sc-6plbdj-0 */
# .ulsLG{width:100%;max-width:1267px;margin:0 auto;padding:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: TruliaHelp__CollapsingHeading-sc-1998z2t-0 */
# @media (max-width:47.9375em){.cLtGLl{max-width:260px;margin:auto;}}
# /* sc-component-id: Error404Page__HeroContainer-zptun3-0 */
# .jbjNtt{margin:0;padding-left:32px;padding-bottom:32px;}
# /* sc-component-id: Error404Page__Error404PageContainer-zptun3-1 */
# .kZbhWa{background:'#fff';display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-bottom:48px;max-width:1267px;margin:96px auto auto auto;width:100%;} @media (max-width:62em){.kZbhWa{margin-top:32px;}}
# /* sc-component-id: Error404Page__CollapsingHeading-zptun3-2 */
# .dEMVEd{padding-top:16px;} @media (max-width:35.5625em){.dEMVEd{max-width:225px;}}
# /* sc-component-id: Error404Page__ImageCell-zptun3-3 */
# .jCIsEf{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;position:relative;z-index:1;margin:-300px auto auto auto;} @media (min-width:376px){.jCIsEf{width:100%;}} @media (min-width:570px){.jCIsEf{width:100%;}} @media (min-width:768px){.jCIsEf{width:90%;}} @media (max-width:62em){.jCIsEf{margin:-140px auto auto auto;}} @media (max-width:35.5625em){.jCIsEf{margin:-80px auto auto auto;}}
# /* sc-component-id: Card-yrmhiy-0 */
# .eTYjnc{background-color:rgb(255,255,255);border:1px solid rgb(232,233,234);border-radius:8px;padding:0;}
# /* sc-component-id: SecondaryButton-sc-12z1yri-0 */
# .jjWbLK{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,173,187);} .jjWbLK .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);} .jjWbLK[class~='hover'],.jjWbLK:hover{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);} .jjWbLK[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.jjWbLK:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);} .jjWbLK[class~='focus'],.jjWbLK:focus{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);} .jjWbLK[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.jjWbLK:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);} .jjWbLK[class~='active'],.jjWbLK:active{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;} .jjWbLK[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.jjWbLK:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);} .jjWbLK[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);} .jjWbLK[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}
# /* sc-component-id: Select__SelectContainer-sc-1wiporl-0 */
# .iWugwH{width:100%;display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;font-weight:bold;border:1px solid rgb(205,209,212);border-radius:8px;background-color:rgb(255,255,255);padding:8px;outline:none;-webkit-transition:box-shadow 0.15s ease,border-color 0.15s ease;transition:box-shadow 0.15s ease,border-color 0.15s ease;} .iWugwH:focus,.iWugwH:focus-within{border-color:rgb(0,173,187);box-shadow:0 0 0 2px rgb(0,120,130);}
# /* sc-component-id: Select__NativeSelect-sc-1wiporl-1 */
# .haUgfs{position:absolute;opacity:0;width:100%;height:100%;top:0;left:0;right:0;bottom:0;cursor:pointer;-webkit-appearance:none;font-size:16px;line-height:1.5;} .haUgfs .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}
# /* sc-component-id: ButtonGroup-bkavsp-0 */
# .bPLygi{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;} .bPLygi > .ButtonBase-c2s2ot-0{box-shadow:none;margin:0;} .bPLygi > .ButtonBase-c2s2ot-0:not(:first-child){border-top-left-radius:0;border-bottom-left-radius:0;} .bPLygi > .ButtonBase-c2s2ot-0:not(:last-child){border-top-right-radius:0;border-bottom-right-radius:0;border-right:0;} .bPLygi > .ButtonBase-c2s2ot-0:focus{border-right:1px solid;} .bPLygi > .ButtonBase-c2s2ot-0:focus + .ButtonBase-c2s2ot-0{border-left:0;} .bPLygi > .PrimaryButton-sc-2em7ay-0:focus,.bPLygi > .TertiaryButton-sc-1qjx54x-0:focus,.bPLygi > .PrimaryButton-sc-2em7ay-0:hover,.bPLygi > .TertiaryButton-sc-1qjx54x-0:hover{border-right:1px solid;} .bPLygi > .PrimaryButton-sc-2em7ay-0:focus + .ButtonBase-c2s2ot-0,.bPLygi > .TertiaryButton-sc-1qjx54x-0:focus + .ButtonBase-c2s2ot-0,.bPLygi > .PrimaryButton-sc-2em7ay-0:hover + .ButtonBase-c2s2ot-0,.bPLygi > .TertiaryButton-sc-1qjx54x-0:hover + .ButtonBase-c2s2ot-0{border-left:0;} .bPLygi > .PrimaryButton-sc-2em7ay-0 + .ButtonBase-c2s2ot-0,.bPLygi > .TertiaryButton-sc-1qjx54x-0 + .ButtonBase-c2s2ot-0,.bPLygi > [enabled='1'] + .ButtonBase-c2s2ot-0{border-left-color:transparent;}
# /* sc-component-id: Tiles__TileBackground-wy0px0-0 */
# .jfPWPB{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}
# /* sc-component-id: Tiles__TileContainer-wy0px0-1 */
# .clGuYl{background-color:rgb(232,233,234);position:relative;border-radius:8px;overflow:hidden;cursor:pointer;width:100%;height:100%;} @media (hover:hover){.clGuYl{-webkit-mask-image:-webkit-radial-gradient(white,black);}.clGuYl > .Tiles__TileBackground-wy0px0-0{-webkit-transition:-webkit-transform 0.45s cubic-bezier(0.645,0.045,0.355,1);-webkit-transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);}.clGuYl:hover > .Tiles__TileBackground-wy0px0-0{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}}
# /* sc-component-id: Picture__Image-ktdqlh-0 */
# .ikRpSq{object-fit:cover;width:100%;height:100%;}
# /* sc-component-id: Picture__PictureContainer-ktdqlh-1 */
# .gBrrSa{height:100%;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: IconButton-fejjl6-0 */
# .yBPkK{min-width:44px;min-height:44px;width:44px;height:44px;overflow:visible;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: Tag__TagBase-l0an8r-1 */
# .eoYqRI{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:2px 8px;border-radius:4px;background-color:rgb(232,233,234);cursor:default;} .eoYqRI:focus{outline:none;box-shadow:0 0 1px 1px rgb(134,144,153);}
# /* sc-component-id: PropertyTag-sc-1oqnx2r-0 */
# .jViosh{margin-right:4px;text-transform:uppercase;background-color:rgb(255,255,255);color:rgb(59,65,68);font-size:12px;line-height:1.33;padding:2px 4px;} .jViosh .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}
# /* sc-component-id: PropertyCard__PropertyCardContainer-sc-1ush98q-2 */
# .gKJaNz{min-width:224px;width:224px;width:100%;height:100%;} .gKJaNz a,.gKJaNz a:hover{color:inherit;}
# /* sc-component-id: PropertyCardMedia__PropertyCardMediaContainer-qf4uhf-0 */
# .kQJnzb{position:relative;z-index:0;height:calc(100% - 104px);}
# /* sc-component-id: PropertyCardMedia__PropertyTagsContainer-qf4uhf-1 */
# .irmqAr{display:block;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:80%;height:19px;overflow:hidden;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;position:absolute;top:8px;left:8px;}
# /* sc-component-id: PropertyCardMedia__SaveHomeButtonContainer-qf4uhf-4 */
# .jVEtvE{position:absolute;top:0;right:0;z-index:1;}
# /* sc-component-id: PropertyCardMedia__PhotoTileContainer-qf4uhf-5 */
# .ggsvKn{min-height:160px;}
# /* sc-component-id: Breadcrumb__BreadcrumbContainer-sc-1xyrxr-0 */
# .fKQzWD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;width:100%;}
# /* sc-component-id: SearchResultsHeader__HeaderContainer-sc-1n45ts4-0 */
# .laCDnn{width:100%;height:64px;} .laCDnn > *{z-index:100;position:fixed;border-bottom:none;}
# /* sc-component-id: SearchResultsList__Container-sc-183kqex-0 */
# .bjkSbC{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:16px;padding-left:calc(16px + env(safe-area-inset-left));} @media (max-width:47.9375em){.bjkSbC{padding-right:calc(16px + env(safe-area-inset-right));}}
# /* sc-component-id: SearchResultsList__HeadingContainer-sc-183kqex-1 */
# .cFfole{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;padding-bottom:8px;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;} @media (max-width:62em){.cFfole{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}} .cFfole .HeadingText{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;margin-right:8px;} @media screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.cFfole .HeadingText{overflow:auto;}} .cFfole .HeadingText .TextPlaceholder-w2p5np-2{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}
# /* sc-component-id: SearchResultsList__WideCell-sc-183kqex-3 */
# .ehWeYU{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;padding-bottom:16px;} @media (min-width:376px){.ehWeYU{width:100%;}} @media (min-width:570px){.ehWeYU{width:50%;}} @media (min-width:768px){.ehWeYU{width:100%;}} @media (min-width:993px){.ehWeYU{width:50%;}} @media (min-width:1440px){.ehWeYU{width:33.33333%;}} @media (min-width:2160px){.ehWeYU{width:25%;}}
# /* sc-component-id: SearchResultsList__ResultCountText-sc-183kqex-4 */
# .fHLXOp{font-size:16px;color:rgb(134,144,153);font-weight:normal;margin:0;padding-bottom:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: PaginationButton__PaginationCarouselButton-cmg92v-0 */
# ...
# /* sc-component-id: SearchResultsLGXLXXLFilterContainer__Container-sc-344kht-0 */
# .gQFVfk{width:100%;height:74px;background-color:rgb(255,255,255);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:10px 16px 16px 16px;padding-left:calc(16px + env(safe-area-inset-left));padding-right:calc(16px + env(safe-area-inset-right));}
# /* sc-component-id: SearchResultsLGXLXXLFilterContainer__FilterList-sc-344kht-1 */
# .fDvMaM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: SearchResultsFilters__FiltersContainer-sc-1f5udhj-0 */
# .jXnTqo{width:100%;height:74px;background-color:rgb(255,255,255);} .jXnTqo > *{position:fixed;z-index:1;}
# /* sc-component-id: SearchResultsFilters__CustomXLBox-sc-1f5udhj-1 */
# .irdxqq{display:none;} @media (min-width:376px){.irdxqq{display:none;}} @media (min-width:570px){.irdxqq{display:none;}} @media (min-width:768px){.irdxqq{display:none;}} @media (min-width:993px){.irdxqq{display:block;}} @media (min-width:1440px){.irdxqq{display:none;}}
# /* sc-component-id: SearchResultsFilters__CustomXXLBox-sc-1f5udhj-2 */
# .gTEzpL{display:block;display:none;} @media (min-width:1440px){.gTEzpL{display:block;}}
# /* sc-component-id: SearchResultsBreadcrumbs__CenteredBreadcrumbs-al7i2i-0 */
# .iCUPTM{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} .iCUPTM a:not([href]){color:rgb(134,144,153);}
# /* sc-component-id: SearchResultsContentLayout__MainContent-sc-15fhfe9-0 */
# .eICseL{min-height:calc(100vh - 64px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: SearchResultsContentLayout__Container-sc-15fhfe9-1 */
# .fGoYrJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: SearchResultsContentLayout__ResultColumn-sc-15fhfe9-2 */
# .bFWtgt{width:50%;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;} @media (max-width:47.9375em){.bFWtgt{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}
# /* sc-component-id: SearchResultsContentLayout__MapColumn-sc-15fhfe9-3 */
# .eQRIzw{width:calc(50% - 16px);position:fixed;right:0;bottom:0;top:138px;height:calc(100vh - 154px);margin:0 16px 16px 0;border-radius:8px;touch-action:manipulation;-webkit-transform:translate3d(0px,0px,0px);-webkit-mask-image:-webkit-radial-gradient(white,black);} @media (max-width:47.9375em){.eQRIzw{width:100%;height:calc(100vh - 138px);margin:0;border-radius:0;display:none;-webkit-transform:none;-webkit-mask-image:none;}} .branch-banner-is-active .eQRIzw{top:214px;} @media (max-width:47.9375em){.branch-banner-is-active .eQRIzw{height:calc(100vh - 214px);}}
# /* sc-component-id: SearchResultsContentLayout__FooterContainer-sc-15fhfe9-4 */
# .izHacP{padding:16px;padding-top:0;} @media (max-width:47.9375em){.izHacP{padding-right:0;}}</style><script>
#               new Image().src = "/track/trackingPixel.gif?lifetimeID=200501q9o8o5hcw13e1i5rmr7kovm693&abTests=958_control;1181c;1205a;1216a;1219c;1227a;1228a;1229_control;1230_control;1231_control;1232_control;1233a;1234a;1235_control;1236_control&requestID=f0cuvT-msoTfS8uEVjZC5v6NgqZPYkSdKeMsjC0OXjnDtnuU2JO0Mw=="
#           </script><script>
#         (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#         branch.init("key_live_pkrocc5yGCN4njTWV2CmGlapwtfdRBt8", {"metadata":{"page":"srp","pageType":"for-sale-srp"},"isDirectVisit":"1"});
#         branch.setBranchViewData({"data":{"city":"Canyon Lake","state":"TX","zipCode":"78133"}});
#       </script><script async="" src="//js-sec.indexww.com/ht/htw-trulia.js"></script><meta charSet="utf-8"/><title>78133 Real Estate &amp; Homes For Sale | Trulia</title><meta name="description" content="443 Homes For Sale in Canyon Lake, TX 78133. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia."/><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, viewport-fit=cover, minimal-ui"/><meta property="fb:admins" content="5953837487"/><meta property="fb:app_id" content="183577541666001"/><meta property="application-name" content="Trulia"/><meta property="msapplication-starturl" content="https://www.trulia.com"/><meta property="msapplication-tooltip" content="Trulia: Real Estate Search"/><meta property="msapplication-config" content="/browserconfig.xml"/><meta property="og:locale" content="en_US"/><meta property="og:site_name" content="Trulia Real Estate Search"/><meta property="og:type" content="website"/><meta property="twitter:site" content="@trulia"/><meta property="mobile-web-app-capable" content="yes"/><meta property="theme-color" content="#ffffff"/><meta property="apple-mobile-web-app-capable" content="yes"/><link rel="preconnect" href="https://assets.adobedtm.com"/><link rel="preconnect" href="https://maps.googleapis.com"/><link rel="preconnect" href="https://collector-PXYO6YjwLb.perimeterx.net"/><link rel="preconnect" href="https:///static.trulia-cdn.com"/><link rel="dns-prefetch" href="https://assets.adobedtm.com"/><link rel="dns-prefetch" href="https://maps.googleapis.com"/><link rel="dns-prefetch" href="https://collector-PXYO6YjwLb.perimeterx.net"/><link rel="dns-prefetch" href="https:///static.trulia-cdn.com"/><link rel="manifest" href="/manifest"/><link rel="apple-touch-icon-precomposed" href="//www.trulia.com/images/icons/app/app-icon-120.png"/><link rel="apple-touch-icon-precomposed" sizes="144x144" href="//www.trulia.com/images/icons/app/app-icon-144.png"/><link rel="apple-touch-icon-precomposed" sizes="152x152" href="//www.trulia.com/images/icons/app/app-icon-152.png"/><link rel="apple-touch-icon-precomposed" sizes="180x180" href="//www.trulia.com/images/icons/app/app-icon-180.png"/><link rel="shortcut icon" sizes="196x196" href="//www.trulia.com/images/icons/app/app-icon-196.png"/><link rel="icon" sizes="120x120" href="//www.trulia.com/images/icons/favicon-rebrand-128.png"/><link rel="icon" sizes="196x196" href="//www.trulia.com/images/icons/favicon-rebrand-196.png"/><link rel="icon" sizes="228x228" href="//www.trulia.com/images/icons/app/app-icon-228.png"/><link rel="mask-icon" href="//www.trulia.com/images/icons/mask-icon.svg" color="#00ADBB"/><meta name="robots" content="INDEX, FOLLOW"/><meta property="og:url" content="https://www.trulia.com/TX/Canyon_Lake/78133/"/><meta property="og:description" content="443 Homes For Sale in Canyon Lake, TX 78133. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia."/><meta property="og:title" content="78133 Real Estate &amp; Homes For Sale | Trulia"/><meta property="og:image" content="https://www.trulia.com/images/logos/standardized/v4/logo-with-icon-200x200.png"/><meta property="og:image:width" content="200"/><meta property="og:image:height" content="200"/><link rel="alternate" href="android-app://com.trulia.android/https/www.trulia.com/TX/Canyon_Lake/78133/"/><link rel="alternate" href="ios-app://288487321/https/www.trulia.com/TX/Canyon_Lake/78133/"/><link rel="canonical" href="https://www.trulia.com/TX/Canyon_Lake/78133/"/><link rel="next" href="https://www.trulia.com/TX/Canyon_Lake/78133/2_p/"/><meta name="next-head-count" content="46"/></head><body><div id="__next"><div data-testid="search-results-header" class="SearchResultsHeader__HeaderContainer-sc-1n45ts4-0 laCDnn"><nav class="Navbar__Nav-sc-1jgd0jm-0 kjzsGg"><a href="/" aria-label="Go to Trulia Home" class="Navbar__LogoContainer-sc-1jgd0jm-2 inmahM"><div width="70" height="24" class="getSvgCont ...
#       if (
#         window.performance &&
#         window.performance.mark &&
#         window.performance.measure
#       ) {
#         var cards = document.querySelectorAll('[data-hero-element-id="srp-home-card"]');
#         var loadedImages = [];
#
#         for (var i = 0; i < cards.length; i++) {
#           var image = cards[i].querySelector('img');
#           if (image.complete) {
#             loadedImages.push(Promise.resolve(image));
#           } else {
#             loadedImages.push(
#               new Promise(function (accept) {
#                 image.addEventListener('load', function () {
#                   accept(this);
#                 });
#               })
#             );
#           }
#         }
#
#         Promise.all(loadedImages).then(function() {
#           window.performance.mark('hero_image_load_end');
#           window.performance.measure('hero_image_load');
#         });
#       }
#     </script></div></div><div data-testid="search-results-pagination" class="SearchResultsPagination__Container-sc-1g9fbhd-0 bkyVoY"><ul aria-label="Pagination Navigation" class="List__ListContainer-sc-1mezygb-0 cknFRB SearchResultsPagination__PageLinkList-sc-1g9fbhd-1 bPeJil"><li data-testid="pagination-page-link"><a href="/TX/Canyon_Lake/78133/" aria-label="Page 1" aria-current="page" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 fZYJOZ">1</a></li><li data-testid="pagination-page-link"><a href="/TX/Canyon_Lake/78133/2_p/" aria-label="Page 2" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 eaauWM">2</a></li><li data-testid="pagination-page-link"><a href="/TX/Canyon_Lake/78133/3_p/" aria-label="Page 3" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 eaauWM">3</a></li><li aria-hidden="true" data-testid="pagination-ellipses"><div class="Text__TextBase-sc-1i9uasc-0-div Text__TextContainerBase-sc-1i9uasc-1 iahKtL">…</div></li><li data-testid="pagination-page-link"><a href="/TX/Canyon_Lake/78133/13_p/" aria-label="Page 13" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 eaauWM">13</a></li><li data-testid="pagination-page-link"><a href="/TX/Canyon_Lake/78133/14_p/" aria-label="Page 14" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 eaauWM">14</a></li><li data-testid="pagination-page-link"><a href="/TX/Canyon_Lake/78133/15_p/" aria-label="Page 15" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 eaauWM">15</a></li><li data-testid="pagination-next-page"><a href="/TX/Canyon_Lake/78133/2_p/" rel="next" aria-label="Next Page" class="ButtonBase-c2s2ot-0 PrimaryButton-sc-2em7ay-0 PaginationButton__PaginationCarouselButton-cmg92v-0 jwpuQL"><div class="getUiSvgContainer__SvgContainer-sc-12y8qp5-0 iXPXzs"><svg class="svg" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M17.65 16.513l-7.147-7.055 1.868-1.893 9.068 8.951-9.069 8.927-1.866-1.896z" fill="#869099"></path></svg></div></a></li></ul><div data-testid="pagination-caption" class="Text__TextBase-sc-1i9uasc-0-div Text__TextContainerBase-sc-1i9uasc-1 dDYpyB">1-30 of 443 Results</div></div><div class="Padding-sc-1d43y5s-0 ZgkBV"><script type="application/ld+json" data-testid="srp-seo-breadcrumbs-list">{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"/sitemap/","name":"United States"}},{"@type":"ListItem","position":2,"item":{"@id":"/sitemap/Texas-real-estate/","name":"Texas"}},{"@type":"ListItem","position":3,"item":{"@id":"/TX/Canyon_Lake/","name":"Canyon Lake"}}]}</script><nav class="Breadcrumb__BreadcrumbContainer-sc-1xyrxr-0 fKQzWD SearchResultsBreadcrumbs__CenteredBreadcrumbs-al7i2i-0 iCUPTM"><div r="xxs" class="Padding-sc-1d43y5s-0 dCeMHc"><div class="MediaBlock__MediaContainer-ldzu2c-0 faqTnc"><div class="MediaBlock__MediaContent-ldzu2c-1 bumWFt"><span class="Text__TextBase-sc-1i9uasc-0 hMhIdB"><span><a href="/sitemap/">United States</a></span></span></div><div class="getUiSvgContainer__SvgContainer-sc-12y8qp5-0 ioFwXj"><svg class="svg" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M17.65 16.513l-7.147-7.055 1.868-1.893 9.068 8.951-9.069 8.927-1.866-1.896z" fill="#869099"></path></svg></div></div></div><div r="xxs" class="Padding-sc-1d43y5s-0 dCeMHc"><div class="MediaBlock__MediaContainer-ldzu2c-0 faqTnc"><div class="MediaBlock__MediaContent-ldzu2c-1 bumWFt"><span class="Text__TextBase-sc-1i9uasc-0 hMhIdB"><span><a href="/sitemap/Texas-real-estate/">Texas</a></span></span></div><div class="getUiSvgContainer__SvgContainer-sc-12y8qp5-0 ioFwXj"><svg class="svg" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M17.65 16.513l-7.147-7.055 1.868-1.893 9.068 8.951-9.069 8.927-1.866-1.896z" fill="#869099"></path></svg></div></div></div><div r="xxs" class="Padding-sc-1d43y5s-0 dCeMHc"><div class="MediaBlock__MediaContainer-ldzu2c-0 faqTnc"><div class="MediaBlock__MediaContent-ldzu2c-1 bumWFt"><span class="Text__TextBase-sc-1i9uasc-0 hMhIdB" ...
#           function initTracking(pageviewPayload) {
#     window.s = window.s || {};
#     window.trulia = window.trulia || {};
#     window.trulia.dataLayer = window.trulia.dataLayer || {};
#     window.trulia.dataLayer.referrer = document.referrer;
#
#     function listenersDefined() {
#       const listeners = window.trulia.dataLayer.listeners;
#       return typeof listeners !== 'undefined' && listeners.length !== 0;
#     }
#
#     const queue = [];
#
#     const track = function (event, data, isInitialPageView) {
#       if (processQueue()) {
#         handleEvent(event, data, isInitialPageView);
#       } else {
#         queue.push({
#           event: event,
#           data: data,
#           isInitialPageView: isInitialPageView
#         });
#       }
#     };
#
#     const handleEvent = function (event, data, isInitialPageView) {
#       if (isInitialPageView) {
#         window.s.referrer = window.trulia.dataLayer.referrer;
#       }
#
#       trulia.dataLayer.listeners.forEach(function (listener) {
#         listener(event, data);
#       });
#     };
#
#     const processQueue = function () {
#       if (listenersDefined()) {
#         if (queue.length) {
#           let queuedData;
#
#           while (queuedData = queue.shift()) {
#             handleEvent(queuedData.event, queuedData.data, queuedData.isInitialPageView);
#           }
#         }
#
#         return true;
#       }
#
#       setTimeout(processQueue, 300);
#       return false;
#     };
#
#     if (pageviewPayload) {
#       track('trackState', pageviewPayload, true);
#     }
#
#     window.trulia.dataLayer.track = track;
#   }
#           initTracking(null);
#         </script><script>
#             (function() {
#                 window._pxAppId = 'PXYO6YjwLb';
#                 // Custom parameters
#                 // window._pxParam1 = "<param1>";
#                 var p = document.getElementsByTagName('script')[0],
#                     s = document.createElement('script');
#                 s.async = 1;
#                 s.src = '//client.perimeterx.net/PXYO6YjwLb/main.min.js';
#                 p.parentNode.insertBefore(s, p);
#             }());
#             </script><noscript><div style="position:fixed;top:0;left:0;display:none" width="1" height="1"><img alt="px pixel" src="//collector-PXYO6YjwLb.perimeterx.net/api/v1/collector/noScript.gif?appId=PXYO6YjwLb"/></div></noscript></body></html>

# %%
URL = 'https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia'
page = requests.get(URL)

# %%
page.text
# Out:
# '<!DOCTYPE html>\r\n<html xmlns="https://www.w3.org/1999/xhtml" xml:lang="en" lang="en">\r\n<head>\r\n    \r\n            <link rel="preconnect" href="https://coda.newjobs.com" />\r\n            <link rel="preconnect" href="https://js-seeker.newjobs.com" />\r\n            <link rel="preconnect" href="https://css-seeker.newjobs.com" />\r\n            <link rel="preconnect" href="https://securemedia.newjobs.com" />\r\n            <link rel="preconnect" href="https://logs2.jobs.com" />\r\n            <link rel="preconnect" href="https://job-openings.monster.com" />\r\n            <link rel="preconnect" href="https://apis.google.com" />\r\n            <link rel="preconnect" href="https://www.google.com" />\r\n            <link rel="preconnect" href="https://accounts.google.com" />\r\n            <link rel="preconnect" href="https://content.googleapis.com" />\r\n            <link rel="preconnect" href="https://ssl.gstatic.com" />\r\n            <link rel="preconnect" href="https://www.dropbox.com" />\r\n            <link rel="preconnect" href="http://js.live.net" />\r\n            <link rel="preconnect" href="https://r.turn.com" />\r\n            <link rel="preconnect" href="https://www.facebook.com" />\r\n            <link rel="preconnect" href="https://dpm.demdex.net" />\r\n            <link rel="preconnect" href="https://monster.demdex.net" />\r\n            <link rel="preconnect" href="https://fast.monster.demdex.net" />\r\n            <link rel="preconnect" href="https://logs.jobs.com" />\r\n            <link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin />\r\n        <link rel="preconnect" href="https://cdnjs.cloudflare.com/" crossorigin />\r\n        <link rel="preconnect" href="https://netdna.bootstrapcdn.com/" crossorigin />\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n<meta http-equiv="Expires" content="0" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1" />\r\n<meta name="j_jp" content="1" />\r\n<meta charset="UTF-8">\r\n<title>Software Developer Jobs in Australia. Australia Software Developer Jobs. | Monster.com</title>\r\n\r\n        <style type="text/css">\r\n                @font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxFIzIXKMnyrYk.woff2) format(\'woff2\');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxMIzIXKMnyrYk.woff2) format(\'woff2\');unicode-range:U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxEIzIXKMnyrYk.woff2) format(\'woff2\');unicode-range:U+1F00-1FFF}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxLIzIXKMnyrYk.woff2) format(\'woff2\');unicode-range:U+0370-03FF}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/roboto/v19/KFOkCnqEu92Fr1MmgVxHIzIXKMnyrYk.woff2) format(\'woff2\');unicode-range:U+0102-0103,U+0110-0111,U+1EA0-1EF9,U+20AB}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:100;font-display:optional;src:local(\'Roboto Thin\'),local(\'Roboto-Thin\'),local(\'sans-serif-thin\'),url(https://fonts.gstatic.com/s/ro ...

# %%
parser = html.fromstring(response.text)
search_results = parser.xpath("//div[@id='search-results']//article")
print(search_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-8ee645f0215d> in <module>
# ----> 1 parser = html.fromstring(response.text)
#       2 search_results = parser.xpath("//div[@id='search-results']//article")
#       3 print(search_results)
#
# AttributeError: 'bytes' object has no attribute 'fromstring'

# %%
if not search_results:
        print("parsing from json data")
# Out:
# parsing from json data

# %%
zipcode = "02126"
sort = "newest"
#scraped_data = parse(zipcode, sort)
#if scraped_data:
#    print ("Writing data to output file")
#    write_data_to_csv(scraped_data)

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup
import ssl
import json
import ast
import os
from urllib.request import Request, urlopen

# %%
# For ignoring SSL certificate errors

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# Input from user

# url = input('Enter Zillow House Listing Url- ')
url = "https://www.zillow.com/homedetails/638-Grant-Ave-North-Baldwin-NY-11510/31220792_zpid/"
# Making the website believe that you are accessing it using a mozilla browser

req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# Creating a BeautifulSoup object of the html page for easy extraction of data.

soup = BeautifulSoup(webpage, 'html.parser')
html = soup.prettify('utf-8')
property_json = {}
property_json['Details_Broad'] = {}
property_json['Address'] = {}

# Extract Title of the property listing

for title in soup.findAll('title'):
    property_json['Title'] = title.text.strip()
    break

for meta in soup.findAll('meta', attrs={'name': 'description'}):
    property_json['Detail_Short'] = meta['content'].strip()

for div in soup.findAll('div', attrs={'class': 'character-count-truncated'}):
    property_json['Details_Broad']['Description'] = div.text.strip()

for (i, script) in enumerate(soup.findAll('script',
                             attrs={'type': 'application/ld+json'})):
    if i == 0:
        json_data = json.loads(script.text)
        property_json['Details_Broad']['Number of Rooms'] = json_data['numberOfRooms']
        property_json['Details_Broad']['Floor Size (in sqft)'] = json_data['floorSize']['value']
        property_json['Address']['Street'] = json_data['address']['streetAddress']
        property_json['Address']['Locality'] = json_data['address']['addressLocality']
        property_json['Address']['Region'] = json_data['address']['addressRegion']
        property_json['Address']['Postal Code'] = json_data['address']['postalCode']
    if i == 1:
        json_data = json.loads(script.text)
        property_json['Price in $'] = json_data['offers']['price']
        property_json['Image'] = json_data['image']
        break

with open('data.json', 'w') as outfile:
    json.dump(property_json, outfile, indent=4)

with open('output_file.html', 'wb') as file:
    file.write(html)

print ('----------Extraction of data is complete. Check json file.----------')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-32-5a663371c711> in <module>
#      37                              attrs={'type': 'application/ld+json'})):
#      38     if i == 0:
# ---> 39         json_data = json.loads(script.text)
#      40         property_json['Details_Broad']['Number of Rooms'] = json_data['numberOfRooms']
#      41         property_json['Details_Broad']['Floor Size (in sqft)'] = json_data['floorSize']['value']
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

abbrev_us_state = dict(map(reversed, us_state_abbrev.items()))

# %%
import geopy

def create_url(city,state,zipcode):
    # Creating Zillow URL based on the filter.

    url = "https://www.trulia.com/" + state + "/" + city + "/" + zipcode
    return url

def get_headers():
    # Creating headers.
    headers = {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
               'accept-encoding': 'gzip, deflate, sdch, br',
               'accept-language': 'en-GB,en;q=0.8,en-US;q=0.6,ml;q=0.4',
               'cache-control': 'max-age=0',
               'upgrade-insecure-requests': '1',
               'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}

    #headers = {'cache-control': 'no-cache'}
    return headers


def get_response(url):
    # Getting response from zillow.com.

    for i in range(5):
        response = requests.get(url, headers=get_headers())
        print("status code received:", response.status_code)
        if response.status_code != 200:
            # saving response to file for debugging purpose.
            save_to_file(response)
            continue
        else:
            save_to_file(response)
            return response
    return None


def GetCityStateZip(lat,lon):
    lat = lat/10**6
    lon = lon/10**6

    location = geolocator.reverse((lat, lon))
   

    city = location.raw['address']['city']
    state = us_state_abbrev[location.raw['address']['state']]

    zipcode = location.raw['address']['postcode'].split('-')[0]
   
    return city,state,zipcode

# %%
city,state,zipcode = GetCityStateZip(34144442,-118654084)
print("city=", city)
print("state=", state)
print("zipcode=",zipcode)
# Out:
# city= Calabasas
# state= CA
# zipcode= 91302

# %%
url = create_url(city,state,zipcode)
print(url)
# Out:
# https://www.trulia.com/CA/Calabasas/91302

# %%
response = get_response(url)
print(response.text)
# Out:
# status code received: 200
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Access to this page has been denied.</title>
#     <style>
#         @font-face {
#             font-family: "PostGrotesk";
#             src: url("//static.trulia-cdn.com/images/fonts/PostGroteskBook_20150623/PostGrotesk-Book.eot");
#             src: url("//static.trulia-cdn.com/images/fonts/PostGroteskBook_20150623/PostGrotesk-Book.eot?#iefix") format("embedded-opentype"), url("//static.trulia-cdn.com/images/fonts/PostGroteskBook_20150623/PostGrotesk-Book.woff") format("woff"), url("//static.trulia-cdn.com/images/fonts/PostGroteskBook_20150623/PostGrotesk-Book.ttf") format("truetype"), url("//static.trulia-cdn.com/images/fonts/PostGroteskBook_20150623/PostGrotesk-Book.svg#PostGroteskRegular") format("svg");
#             font-weight: 400;
#             font-style: normal;
#             font-display: swap;
#         }
#
#         @font-face {
#             font-family: "PostGrotesk";
#             src: url("//static.trulia-cdn.com/images/fonts/PostGroteskMedium/PostGrotesk-Medium.eot");
#             src: url("//static.trulia-cdn.com/images/fonts/PostGroteskMedium/PostGrotesk-Medium.eot?#iefix") format("embedded-opentype"), url("//static.trulia-cdn.com/images/fonts/PostGroteskMedium//PostGrotesk-Medium.woff") format("woff"), url("//static.trulia-cdn.com/images/fonts/PostGroteskMedium//PostGrotesk-Medium.ttf") format("truetype"), url("//static.trulia-cdn.com/images/fonts/PostGroteskMedium//PostGrotesk-Medium.svg#PostGroteskBold") format("svg");
#             font-weight: 600;
#             font-style: normal;
#             font-display: swap;
#         }
#
#         html,
#         body {
#             margin: 0;
#             padding: 0;
#             font-family: 'PostGrotesk', system, -apple-system, Roboto, Segoe UI Bold, Arial, sans-serif;
#             color: #000;
#             height: 100%;
#         }
#
#         a {
#             color: #c5c5c5;
#             text-decoration: none;
#         }
#
#         .container {
#             height: calc(100% - 60px);
#             margin: 0 30px -59px 30px;
#             padding-top: 60px;
#         }
#
#         .content {
#             position: relative;
#             max-width: 600px;
#             margin: auto;
#             z-index: 1;
#             padding: 2px;
#             background: white;
#             border-radius: 10px;
#         }
#
#         .logo {
#             max-width: 120px;
#             margin-bottom: 40px;
#         }
#
#         .page-footer-wrapper {
#             background-color: #000;
#             color: #c5c5c5;
#             font-size: 14px;
#             padding: 21px 0px;
#         }
#
#         .footer-content {
#             max-width: 800px;
#             margin: 0 auto;
#         }
#
#         .center {
#             text-align: center;
#         }
#
#         #px-captcha {
#             margin: auto;
#             width: 304px;
#             margin-bottom: 60px;
#         }
#
#         @keyframes robotMove {
#             0% { transform: translate3d(0%, 0, 0) }
#             5% { transform: translate3d(5%, 1.6%, 0) }
#             10% { transform: translate3d(10%, 4.4%, 0) }
#             15% { transform: translate3d(15%, 7.9%, 0) }
#             20% { transform: translate3d(20%, 11.5%, 0) }
#             25% { transform: translate3d(25%, 15.3%, 0) }
#             30% { transform: translate3d(30%, 17.6%, 0) }
#             35% { transform: translate3d(35%, 18.8%, 0) }
#             40% { transform: translate3d(40%, 18.6%, 0) }
#             45% { transform: translate3d(45%, 16.3%, 0) }
#             50% { transform: translate3d(50%, 12.6%, 0) }
#             55% { transform: translate3d(55%, 8.3%, 0) }
#             60% { transform: translate3d(60%, 4.4%, 0) }
#             65% { transform: translate3d(65%, 2.1%, 0) }
#             70% { transform: translate3d(70%, 0.7%, 0) }
#             75% { transform: translate3d(75%, 0.5%, 0) }
#             80% { transform: translate3d(80%, 1.5%, 0) }
#             85% { transform: translate3d(85%, 4%, 0) }
#             90% { transform: translate3d(90%, 7.5%, 0) }
#             95% { transform: translate3d(95%, 12%, 0) }
#             100% { transform: translate3d(100%, 16.8%, 0) }
#         }
#
#         .robot-svg {
#             animation: robotMove 25s linear infinite;
#             transform-origin: 0% 100%;
#             transform-box: border-box;
#         }
#
#         div.svg-wrap {
#             position: absolute;
#             left: 0;
#             height: 0;
#             width: 100%;
#             padding: 0;
#             padding-bottom: 25%;
#             bottom: 55px;
#             overflow: hidden;
#         }
#
#         .svg-wrap svg {
#             position: absolute;
#             height: 100%;
#             width: 100%;
#             left: 0;
#             top: 0;
#         }
#
#         #ref-id {
#             display: none;
#         }
#
#         .main-content {
#             position: relative;
#             background-color: white;
#             z-index: 10;
#         }
#
#         @media (max-width: 768px) {
#             .container {
#                 height: calc(100% - 30px);
#                 margin: 0 30px -59px 30px;
#                 padding-top: 30px;
#             }
#
#             .logo { margin-bottom: 20px }
#
#             .g-recaptcha { margin-bottom: 40px }
#
#             .page-footer-wrapper {
#                 padding-left: 20px;
#             }
#         }
#
#         @media (max-width: 340px) {
#             .container {
#                 margin: 0 0 -59px;
#             }
#         }
#     </style>
# </head>
#
# <body>
#     <script>
#         window._pxAppId = 'PXYO6YjwLb';
#         window._pxJsClientSrc = 'https://client.perimeterx.net/PXYO6YjwLb/main.min.js';
#         window._pxHostUrl = 'https://collector-PXYO6YjwLb.perimeterx.net';
#     </script>
#     <script src="https://captcha.px-cdn.net/PXYO6YjwLb/captcha.js?a=c&m=0"></script>
#
#     <section class="container">
#         <div class="center">
#             <svg class="logo" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 198.96 50.44">
#                 <g id="Layer_2" data-name="Layer 2"><g id="FINAL_expanded_icons" data-name="FINAL expanded icons"><path d="M147.71,11a5.51,5.51,0,1,0-5.5-5.51A5.51,5.51,0,0,0,147.71,11Z"/><polygon points="152.7 40.56 152.7 14.64 137.2 14.64 137.2 23.92 143.42 23.92 143.42 49.84 158.91 49.84 158.91 40.56 152.7 40.56"/><polygon points="126.21 40.56 126.21 2.54 110.72 2.54 110.72 11.82 116.93 11.82 116.93 40.56 110.72 40.56 110.72 49.84 132.42 49.84 132.42 40.56 126.21 40.56"/><path d="M60.25,14.52H57.44a12.17,12.17,0,0,0-10.75,5.39L44.8,14.64H35.69v9.28H40V49.84h9.28V31.72a8.16,8.16,0,0,1,8.16-8.16h2.81Z"/><path d="M103.23,32.87h0V14.64H94V33.2a8.29,8.29,0,0,1-16.58,0V14.64H68.09V32.87h0a17.57,17.57,0,0,0,35.14,0h0Z"/><path d="M27.6,23.92V14.64H15.49V3.28H6.22V14.64H0v9.28H6.22v8.92h0A17.56,17.56,0,0,0,23.78,50.41,17.74,17.74,0,0,0,27.6,50V40.83a9.28,9.28,0,0,1-3.18.56,8.78,8.78,0,0,1-8.93-8.61v0h0V23.92Z"/><path d="M189.69,14.64v3.5a13.08,13.08,0,0,0-9.14-4l-.72,0c-9.17,0-16.6,8.12-16.6,18.15s7.43,18.19,16.6,18.15l.72,0a13.08,13.08,0,0,0,9.14-4v3.5H199V14.64Zm-8.81,26.82A9.06,9.06,0,0,1,172,32.23a8.85,8.85,0,1,1,17.69,0A9,9,0,0,1,180.88,41.46Z"/></g></g>
#             </svg>
#         </div>
#         <div class="content center">
#             <h1>Please verify you are a human</h1>
#             <p>Click "I am not a robot" to continue</p>
#             <div id="px-captcha"></div>
#             <p id="ref-id"> Reference ID: </p>
#         </div>
#     </section>
#     <div class="svg-wrap">
#         <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" viewBox="0 0 1619.8 401"><style>.st0 { clip-path:url(#SVGID_2_) } .st1 { opacity:.75;fill:#c7f9ce;enable-background:new } .st2 { fill:#94edb8 } .st3 { fill:#e3ffe8 } .st4 { fill:#d6e5d6 } .st5 { fill:#b6ceb6 } .st6 { fill:#aac1aa } .st7 { fill:none;stroke:#d6e5d6;stroke-width:4;stroke-miterlimit:10 } .st10,.st8,.st9 { clip-path:url(#SVGID_4_);fill:#8ea88e } .st10,.st9 { clip-path:url(#SVGID_6_) } .st10 { clip-path:url(#SVGID_8_) } .st11,.st12,.st13 { clip-path:url(#SVGID_10_);fill:#8ea88e } .st12,.st13 { clip-path:url(#SVGID_12_) } .st13 { clip-path:url(#SVGID_14_) } .st14 { fill:#ffdba9 } .st15 { fill:#efc38e } .st16 { clip-path:url(#SVGID_16_);fill:#a97c5d } .st17 { fill:#8acef3 } .st18 { fill:#b5e3f7 } .st19 { fill:#139cd8 } .st20 { fill:#d9db9c } .st21 { fill:#abaf74 } .st22 { clip-path:url(#SVGID_18_);fill:#e8ea8f } .st23 { clip-path:url(#SVGID_20_);fill:#abaf74 } .st24 { fill:#c2f9cd } .st25 { fill:#2ed975 } .st26 { fill:#89f4c0 } .st27 { fill:#08b796 } .st28 { fill:#a97c5d } .st29 { fill:#ede329;stroke:#e0ce28;stroke-miterlimit:10 } .st30 { fill:#eabb5e } .st31 { fill:#b8afa8 } .st32 { fill:#8d8884 } .st33 { fill:none;stroke:#707273;stroke-width:.5;stroke-miterlimit:10 } .st34 { clip-path:url(#SVGID_22_) } .st35,.st36 { fill:none;stroke:#228959;stroke-width:6;stroke-miterlimit:10 } .st36 { stroke-width:3 } .st37 { fill:#20c063 } .st38,.st39,.st40 { fill:none;stroke:#228959;stroke-width:8;stroke-miterlimit:10 } .st39,.st40 { stroke-width:5 } .st40 { stroke-width:7 } .st41 { fill:#228959 } .st42 { fill:#06e7bb } .st43 { fill:none;stroke:#228959;stroke-width:6;stroke-linecap:round;stroke-miterlimit:10 } .st44,.st45,.st46,.st47,.st48,.st49 { opacity:.3;clip-path:url(#SVGID_24_);fill:#20c063;enable-background:new } .st45,.st46,.st47,.st48,.st49 { clip-path:url(#SVGID_26_) } .st46,.st47,.st48,.st49 { clip-path:url(#SVGID_28_) } .st47,.st48,.st49 { clip-path:url(#SVGID_30_) } .st48,.st49 { clip-path:url(#SVGID_32_) } .st49 { clip-path:url(#SVGID_34_) } .st50 { fill:#2dafd3 } .st51 { fill:#64c5e8 } .st52 { opacity:.5;clip-path:url(#SVGID_36_) } .st53 { fill:none;stroke:#2dafd3;stroke-width:2;stroke-linecap:round;stroke-linejoin:round;stroke-miterlimit:10 } .st54 { opacity:.5;clip-path:url(#SVGID_38_) } .st55,.st56 { opacity:.5;clip-path:url(#SVGID_40_) } .st56 { clip-path:url(#SVGID_42_) } .st57 { clip-path:url(#SVGID_44_) } .st57,.st58 { opacity:.5 }</style><defs><path id="SVGID_1_" d="M0-246h1619.8v648H0z"></path></defs><clipPath id="SVGID_2_"><use xlink:href="#SVGID_1_" overflow="visible"></use></clipPath><g id="bg" class="st0"><path class="st1" d="M1109.9 212.2v-27.5c0-.2-.1-.5-.3-.7l-1.6-1.8c-.2-.2-.3-.4-.3-.7v-20c0-.3-.2-.7-.5-.8l-6.6-3.9v-.5l-2.6 1.2-22.4 10.6-1 .5V176.3c0 .4-.3.8-.7.9l-12.7 4.4-.6.2c-.4.1-.7.5-.7.9V212.4h-1.1v.8c0 .5-.4 1-1 1h-10.2c-.5 0-1 .4-1 1v10.9c0 .5.4.9.9 1l504.4 53c.1 0 .3 0 .4-.1l145.3-52.8c.4-.1.6-.5.6-.9v-11.1c0-.5-.4-1-1-1h-12.1c-.5 0-1-.4-1-1v-10.6c0-.5.4-1 1-1h.2c.5 0 1-.4 1-1v-2.1c0-.3-.1-.5-.3-.7l-7.4-7.5-10.4-10.6c-.4-.4-1-.4-1.4 0l-10.4 10.6-7.3 7.4c-.2.2-.3.4-.3.7v2.2c0 .5.4 1 1 1 .5 0 1 .4 1 1v10.6c0 .5-.4 1-1 1h-2.7c-.5 0-1-.4-1-1v-22.4c0-.5.4-1 1-1h.4c.5 0 1-.4 1-1v-2c0-.3-.1-.5-.3-.7l-7.6-7.7-10.5-10.7c-.4-.4-1-.4-1.4 0l-10.5 10.7-7.6 7.8c-.2.2-.3.4-.3.7v2c0 .5.4 1 1 1h.3c.5 0 1 .4 1 1v22.3c0 .5-.4 1-1 1h-1.8c-.5 0-1-.4-1-1v-80.5c0-.5-.4-1-1-1h-39.7c-.5 0-1 .4-1 1v28.6c0 .5-.4 1-1 1h-38.3c-.5 0-1 .4-1 1v49.8c0 .5-.4 1-1 1h-2.3c-.5 0-1-.4-1-1v-85.3c0-.5-.4-1-1-1h-32.9c-.5 0-1 .4-1 1v85.4c0 .5-.4 1-1 1h-3.1c-.5 0-1-.4-1-1v-52c0-.5-.4-1-1-1h-24.9c-.5 0-1-.4-1-1V94.8c0-.5-.4-1-1-1h-2.9c-.5 0-1 .4-1 1v118.4c0 .5-.4 1-1 1h-4.7c-.5 0-1-.4-1-1l-.5-134.6c0-.6-.6-1.1-1.2-1l-62.9 15.5c-.4.1-.8.5-.8 1v51c0 .5-.4 1-1 1h-35.2c-.5 0-1 .4-1 1v4.2c0 .5-.4 1-1 1h-32.5c-.5 0-1 .4-1 1v24.1c0 .5-.4 1-1 1h-10.1c-.5 0-1-.4-1-1V134c0-.5-.3-.9-.8-1l-29.6-5.8c-.2 0-.4 0-.6.1l-7.1 3.5c-.7.3-1.4-.2-1.4-.9V107c0-.5-.3-. ...
#     </div>
#
#     <footer class="page-footer-wrapper">
#         <p class="footer-content">Powered by <a href="https://www.perimeterx.com/whywasiblocked">PerimeterX</a> , Inc.</p>
#     </footer>
#
#     <script>
#         (function setRefId() {
#             var pxUuid = window._pxUuid;
#             if (!pxUuid) {
#                 url = window.location.href;
#                 var regex = new RegExp('[?&]uuid(=([^&#]*)|&|#|$)');
#                 var results = regex.exec(url);
#                 pxUuid = results && results.length > 2 ? results[2] : '';
#                 pxUuid = decodeURIComponent(pxUuid.replace(/\+/g, ' '));
#             }
#
#             var refIdElement = document.getElementById("ref-id");
#             if (pxUuid) {
#                 refIdElement.innerText += pxUuid;
#                 refIdElement.style.display = "block";
#             }
#         })();
#     </script>
# </body>
# </html>

# %%
import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup
#import ssl
#import json
#import ast
#import os
from urllib.request import Request, urlopen

# %%
# For ignoring SSL certificate errors

#ctx = ssl.create_default_context()
#ctx.check_hostname = False
#ctx.verify_mode = ssl.CERT_NONE


# Making the website believe that you are accessing it using a mozilla browser

req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# Creating a BeautifulSoup object of the html page for easy extraction of data.

soup = BeautifulSoup(webpage, 'html.parser')

# %%
html = soup.prettify('utf-8')
product_json = {}
# This code block will get you a one liner description of the listed property

for meta in soup.findAll('meta', attrs={'name': 'description'}):
    try:
        product_json['description'] = meta['content']
        break
    except:
        pass
print(product_json)
# Out:
# {'description': '127 Homes For Sale in Calabasas, CA 91302. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia.'}

# %%
# This code block will get you the link of the listed property

for link in soup.findAll('link', attrs={'rel': 'canonical'}):
    try:
        product_json['link'] = link['href']
        break
    except:
        pass


print(product_json)
# Out:
# {'description': '127 Homes For Sale in Calabasas, CA 91302. Browse photos, see new properties, get open house info, and research neighborhoods on Trulia.', 'link': 'https://www.trulia.com/CA/Calabasas/91302/'}

# %%
#scripts = soup.findAll('script',attrs={'type': 'application/ld+json'})
#print(len(scripts))
#details_json = scripts[0]
#print(details_json)

# %%
details = {}
listings_json = {}
index = 0
for price in  soup.findAll('div',attrs={'data-testid': 'property-price'}):
    details.update({index:price.text.strip()}) 
    index = index + 1

listings_json['price'] = {}
listings_json['price']  = details
print(listings_json['price'])
# Out:
# {0: '$8,899,000', 1: '$3,199,000', 2: '$1,499,000', 3: '$3,599,000', 4: '$32,000,000', 5: '$1,249,000', 6: '$25,000,000', 7: '$2,299,000', 8: '$10,980,000', 9: '$300,000', 10: '$6,749,000', 11: '$1,649,000', 12: '$6,750,000', 13: '$3,940,000', 14: '$1,777,000', 15: '$299,500', 16: '$4,599,000', 17: '$22,995,000', 18: '$90,000', 19: '$3,950,000', 20: '$3,049,000', 21: '$10,850,000', 22: '$1,995,000', 23: '$1,699,000', 24: '$11,900,000', 25: '$12,850,000', 26: '$14,495,000', 27: '$799,900', 28: '$6,250,000', 29: '$2,049,000'}

# %%
details = {}
index = 0
for bedroom  in  soup.findAll('div',attrs={'data-testid': 'property-beds'}):
    details.update({index:bedroom.text.strip()}) 
    index = index + 1

listings_json['bedroom'] = {}
listings_json['bedroom']  = details
print(listings_json)
# Out:
# {'price': {0: '$8,899,000', 1: '$3,199,000', 2: '$1,499,000', 3: '$3,599,000', 4: '$32,000,000', 5: '$1,249,000', 6: '$25,000,000', 7: '$2,299,000', 8: '$10,980,000', 9: '$300,000', 10: '$6,749,000', 11: '$1,649,000', 12: '$6,750,000', 13: '$3,940,000', 14: '$1,777,000', 15: '$299,500', 16: '$4,599,000', 17: '$22,995,000', 18: '$90,000', 19: '$3,950,000', 20: '$3,049,000', 21: '$10,850,000', 22: '$1,995,000', 23: '$1,699,000', 24: '$11,900,000', 25: '$12,850,000', 26: '$14,495,000', 27: '$799,900', 28: '$6,250,000', 29: '$2,049,000'}, 'bedroom': {0: '6bd', 1: '5bd', 2: '4bd', 3: '5bd', 4: '7bd', 5: '3bd', 6: '8bd', 7: '5bd', 8: '6bd', 9: '2bd', 10: '6bd', 11: '3bd', 12: '6bd', 13: '5bd', 14: '4bd', 15: '3bd', 16: '6bd', 17: '7bd', 18: '6bd', 19: '5bd', 20: '8bd', 21: '5bd', 22: '5bd', 23: '8bd', 24: '7bd', 25: '7bd', 26: '4bd', 27: '5bd', 28: '4bd'}}

# %%
details = {}
index = 0
for bathroom  in  soup.findAll('div',attrs={'data-testid': 'property-baths'}):
    details.update({index:bathroom.text.strip()}) 
    index = index + 1

listings_json['bathroom'] = {}
listings_json['bathroom']  = details
print(listings_json)
# Out:
# {'price': {0: '$8,899,000', 1: '$3,199,000', 2: '$1,499,000', 3: '$3,599,000', 4: '$32,000,000', 5: '$1,249,000', 6: '$25,000,000', 7: '$2,299,000', 8: '$10,980,000', 9: '$300,000', 10: '$6,749,000', 11: '$1,649,000', 12: '$6,750,000', 13: '$3,940,000', 14: '$1,777,000', 15: '$299,500', 16: '$4,599,000', 17: '$22,995,000', 18: '$90,000', 19: '$3,950,000', 20: '$3,049,000', 21: '$10,850,000', 22: '$1,995,000', 23: '$1,699,000', 24: '$11,900,000', 25: '$12,850,000', 26: '$14,495,000', 27: '$799,900', 28: '$6,250,000', 29: '$2,049,000'}, 'bedroom': {0: '6bd', 1: '5bd', 2: '4bd', 3: '5bd', 4: '7bd', 5: '3bd', 6: '8bd', 7: '5bd', 8: '6bd', 9: '2bd', 10: '6bd', 11: '3bd', 12: '6bd', 13: '5bd', 14: '4bd', 15: '3bd', 16: '6bd', 17: '7bd', 18: '6bd', 19: '5bd', 20: '8bd', 21: '5bd', 22: '5bd', 23: '8bd', 24: '7bd', 25: '7bd', 26: '4bd', 27: '5bd', 28: '4bd'}, 'bathroom': {0: '9ba', 1: '6ba', 2: '3ba', 3: '6ba', 4: '10ba', 5: '2ba', 6: '15ba', 7: '5ba', 8: '9ba', 9: '2ba', 10: '9ba', 11: '4ba', 12: '6ba', 13: '7ba', 14: '4ba', 15: '4ba', 16: '8ba', 17: '11ba', 18: '6ba', 19: '6ba', 20: '12ba', 21: '3ba', 22: '4ba', 23: '7ba', 24: '9ba', 25: '9ba', 26: '3ba', 27: '6ba', 28: '5ba'}}

# %%
details = {}
index = 0
for floorSpace  in  soup.findAll('div',attrs={'data-testid': 'property-floorSpace'}):
    details.update({index:floorSpace.text.strip()}) 
    index = index + 1

listings_json['floorSpace'] = {}
listings_json['floorSpace']  = details
print(listings_json)
# Out:
# {'price': {0: '$8,899,000', 1: '$3,199,000', 2: '$1,499,000', 3: '$3,599,000', 4: '$32,000,000', 5: '$1,249,000', 6: '$25,000,000', 7: '$2,299,000', 8: '$10,980,000', 9: '$300,000', 10: '$6,749,000', 11: '$1,649,000', 12: '$6,750,000', 13: '$3,940,000', 14: '$1,777,000', 15: '$299,500', 16: '$4,599,000', 17: '$22,995,000', 18: '$90,000', 19: '$3,950,000', 20: '$3,049,000', 21: '$10,850,000', 22: '$1,995,000', 23: '$1,699,000', 24: '$11,900,000', 25: '$12,850,000', 26: '$14,495,000', 27: '$799,900', 28: '$6,250,000', 29: '$2,049,000'}, 'bedroom': {0: '6bd', 1: '5bd', 2: '4bd', 3: '5bd', 4: '7bd', 5: '3bd', 6: '8bd', 7: '5bd', 8: '6bd', 9: '2bd', 10: '6bd', 11: '3bd', 12: '6bd', 13: '5bd', 14: '4bd', 15: '3bd', 16: '6bd', 17: '7bd', 18: '6bd', 19: '5bd', 20: '8bd', 21: '5bd', 22: '5bd', 23: '8bd', 24: '7bd', 25: '7bd', 26: '4bd', 27: '5bd', 28: '4bd'}, 'bathroom': {0: '9ba', 1: '6ba', 2: '3ba', 3: '6ba', 4: '10ba', 5: '2ba', 6: '15ba', 7: '5ba', 8: '9ba', 9: '2ba', 10: '9ba', 11: '4ba', 12: '6ba', 13: '7ba', 14: '4ba', 15: '4ba', 16: '8ba', 17: '11ba', 18: '6ba', 19: '6ba', 20: '12ba', 21: '3ba', 22: '4ba', 23: '7ba', 24: '9ba', 25: '9ba', 26: '3ba', 27: '6ba', 28: '5ba'}, 'floorSpace': {0: '10,565 sqft', 1: '4,997 sqft', 2: '3,419 sqft', 3: '5,676 sqft', 4: '16,570 sqft', 5: '1,805 sqft', 6: '24,491 sqft', 7: '5,300 sqft', 8: '12,953 sqft', 9: '1,632 sqft', 10: '8,152 sqft', 11: '3,371 sqft', 12: '7,019 sqft', 13: '6,745 sqft', 14: '3,230 sqft', 15: '1,680 sqft', 16: '9,991 sqft', 17: '13,895 sqft', 18: '7,200 sqft', 19: '5,181 sqft', 20: '14,763 sqft', 21: '2,912 sqft', 22: '3,658 sqft', 23: '10,387 sqft', 24: '12,310 sqft', 25: '11,850 sqft', 26: '2,562 sqft', 27: '5,663 sqft', 28: '4,196 sqft'}}

# %%
details = {}
index = 0
for region  in  soup.findAll('div',attrs={'data-testid': 'property-region'}):
    details.update({index:region.text.strip()}) 
    index = index + 1

listings_json['region'] = {}
listings_json['region']  = details
print(listings_json)
# Out:
# {'price': {0: '$8,899,000', 1: '$3,199,000', 2: '$1,499,000', 3: '$3,599,000', 4: '$32,000,000', 5: '$1,249,000', 6: '$25,000,000', 7: '$2,299,000', 8: '$10,980,000', 9: '$300,000', 10: '$6,749,000', 11: '$1,649,000', 12: '$6,750,000', 13: '$3,940,000', 14: '$1,777,000', 15: '$299,500', 16: '$4,599,000', 17: '$22,995,000', 18: '$90,000', 19: '$3,950,000', 20: '$3,049,000', 21: '$10,850,000', 22: '$1,995,000', 23: '$1,699,000', 24: '$11,900,000', 25: '$12,850,000', 26: '$14,495,000', 27: '$799,900', 28: '$6,250,000', 29: '$2,049,000'}, 'bedroom': {0: '6bd', 1: '5bd', 2: '4bd', 3: '5bd', 4: '7bd', 5: '3bd', 6: '8bd', 7: '5bd', 8: '6bd', 9: '2bd', 10: '6bd', 11: '3bd', 12: '6bd', 13: '5bd', 14: '4bd', 15: '3bd', 16: '6bd', 17: '7bd', 18: '6bd', 19: '5bd', 20: '8bd', 21: '5bd', 22: '5bd', 23: '8bd', 24: '7bd', 25: '7bd', 26: '4bd', 27: '5bd', 28: '4bd'}, 'bathroom': {0: '9ba', 1: '6ba', 2: '3ba', 3: '6ba', 4: '10ba', 5: '2ba', 6: '15ba', 7: '5ba', 8: '9ba', 9: '2ba', 10: '9ba', 11: '4ba', 12: '6ba', 13: '7ba', 14: '4ba', 15: '4ba', 16: '8ba', 17: '11ba', 18: '6ba', 19: '6ba', 20: '12ba', 21: '3ba', 22: '4ba', 23: '7ba', 24: '9ba', 25: '9ba', 26: '3ba', 27: '6ba', 28: '5ba'}, 'floorSpace': {0: '10,565 sqft', 1: '4,997 sqft', 2: '3,419 sqft', 3: '5,676 sqft', 4: '16,570 sqft', 5: '1,805 sqft', 6: '24,491 sqft', 7: '5,300 sqft', 8: '12,953 sqft', 9: '1,632 sqft', 10: '8,152 sqft', 11: '3,371 sqft', 12: '7,019 sqft', 13: '6,745 sqft', 14: '3,230 sqft', 15: '1,680 sqft', 16: '9,991 sqft', 17: '13,895 sqft', 18: '7,200 sqft', 19: '5,181 sqft', 20: '14,763 sqft', 21: '2,912 sqft', 22: '3,658 sqft', 23: '10,387 sqft', 24: '12,310 sqft', 25: '11,850 sqft', 26: '2,562 sqft', 27: '5,663 sqft', 28: '4,196 sqft'}, 'region': {0: 'The Oaks, Calabasas, CA', 1: 'Calabasas, CA', 2: 'Calabasas, CA', 3: 'Hidden Hills, CA', 4: 'The Oaks, Calabasas, CA', 5: 'Calabasas, CA', 6: 'Calabasas, CA', 7: 'Calabasas, CA', 8: 'The Oaks, Calabasas, CA', 9: 'Calabasas, CA', 10: 'Calabasas, CA', 11: 'Calabasas, CA', 12: 'Calabasas, CA', 13: 'The Oaks, Calabasas, CA', 14: 'Calabasas, CA', 15: 'Calabasas, CA', 16: 'Calabasas, CA', 17: 'Hidden Hills, CA', 18: 'Calabasas, CA', 19: 'Calabasas, CA', 20: 'The Oaks, Calabasas, CA', 21: 'The Oaks, Calabasas, CA', 22: 'Calabasas, CA', 23: 'Greater Mulwood, Calabasas, CA', 24: 'Calabasas, CA', 25: 'Hidden Hills, CA', 26: 'Hidden Hills, CA', 27: 'Calabasas, CA', 28: 'Hidden Hills, CA', 29: 'Calabasas, CA'}}

# %%
with open('house_details.json', 'w') as outfile:
    json.dump(listings_json, outfile, indent=4)

# %%
listings_table = pd.read_json("house_details.json")

# %%
listings_table
# Out:
#           price bedroom bathroom   floorSpace                          region
# 0    $8,899,000     6bd      9ba  10,565 sqft         The Oaks, Calabasas, CA
# 1    $3,199,000     5bd      6ba   4,997 sqft                   Calabasas, CA
# 2    $1,499,000     4bd      3ba   3,419 sqft                   Calabasas, CA
# 3    $3,599,000     5bd      6ba   5,676 sqft                Hidden Hills, CA
# 4   $32,000,000     7bd     10ba  16,570 sqft         The Oaks, Calabasas, CA
# 5    $1,249,000     3bd      2ba   1,805 sqft                   Calabasas, CA
# 6   $25,000,000     8bd     15ba  24,491 sqft                   Calabasas, CA
# 7    $2,299,000     5bd      5ba   5,300 sqft                   Calabasas, CA
# 8   $10,980,000     6bd      9ba  12,953 sqft         The Oaks, Calabasas, CA
# 9      $300,000     2bd      2ba   1,632 sqft                   Calabasas, CA
# 10   $6,749,000     6bd      9ba   8,152 sqft                   Calabasas, CA
# 11   $1,649,000     3bd      4ba   3,371 sqft                   Calabasas, CA
# 12   $6,750,000     6bd      6ba   7,019 sqft                   Calabasas, CA
# 13   $3,940,000     5bd      7ba   6,745 sqft         The Oaks, Calabasas, CA
# 14   $1,777,000     4bd      4ba   3,230 sqft                   Calabasas, CA
# 15     $299,500     3bd      4ba   1,680 sqft                   Calabasas, CA
# 16   $4,599,000     6bd      8ba   9,991 sqft                   Calabasas, CA
# 17  $22,995,000     7bd     11ba  13,895 sqft                Hidden Hills, CA
# 18      $90,000     6bd      6ba   7,200 sqft                   Calabasas, CA
# 19   $3,950,000     5bd      6ba   5,181 sqft                   Calabasas, CA
# 20   $3,049,000     8bd     12ba  14,763 sqft         The Oaks, Calabasas, CA
# 21  $10,850,000     5bd      3ba   2,912 sqft         The Oaks, Calabasas, CA
# 22   $1,995,000     5bd      4ba   3,658 sqft                   Calabasas, CA
# 23   $1,699,000     8bd      7ba  10,387 sqft  Greater Mulwood, Calabasas, CA
# 24  $11,900,000     7bd      9ba  12,310 sqft                   Calabasas, CA
# 25  $12,850,000     7bd      9ba  11,850 sqft                Hidden Hills, CA
# 26  $14,495,000     4bd      3ba   2,562 sqft                Hidden Hills, CA
# 27     $799,900     5bd      6ba   5,663 sqft                   Calabasas, CA
# 28   $6,250,000     4bd      5ba   4,196 sqft                Hidden Hills, CA
# 29   $2,049,000     NaN      NaN          NaN                   Calabasas, CA

# %%
# This code block will get you the price and the currency of the listed property

for scripts in soup.findAll('script',attrs={'type': 'application/ld+json'}):                            
    details_json = ast.literal_eval(scripts.text.strip())
    
product_json['price'] = {}
product_json['price']['amount'] = details_json['offers']['price']
product_json['price']['currency'] = details_json['offers']['priceCurrency']

print(product_json)
# Out:
# Traceback (most recent call last):
#
#   File "c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc540\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-152-1644e366e855>", line 4, in <module>
#     details_json = ast.literal_eval(scripts.text.strip())
#
#   File "C:\Users\safar\AppData\Local\Programs\Python\Python37-32\lib\ast.py", line 46, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "C:\Users\safar\AppData\Local\Programs\Python\Python37-32\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
divs = soup.findAll('div',attrs={'data-auto-test-id': 'home-details-overview'})
print(divs)
# Out:
# []

# %%
# This code block will get you the detailed description of the the listed property

for paragraph in soup.findAll('p', attrs={'id': 'propertyDescription'}):
    product_json['broad-description'] = paragraph.text.strip()
product_json['overview'] = []

# This code block will get you the important points regarding the listed property

for divs in soup.findAll('div',attrs={'data-auto-test-id': 'home-details-overview'}):
    for divs_second in divs.findAll('div'):
        for uls in divs_second.findAll('ul'):
            for lis in uls.findAll('li', text=True, recursive=False):
                product_json['overview'].append(lis.text.strip())

# Creates a json file with all the information that you extracted

with open('house_details.json', 'w') as outfile:
    json.dump(product_json, outfile, indent=4)

# Creates an html file in your local with the html content of the page you parsed.

with open('output_file.html', 'wb') as file:
    file.write(html)

print ('----------Extraction of data is complete. Check json file.----------')
# Out:
# ----------Extraction of data is complete. Check json file.----------
