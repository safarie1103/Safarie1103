# %%
from twitter import *

# %%
consumer_key = 'qIkdnrjuFNiRmyTYaR29jX5Yx'
consumer_secret = 'qnvlOFvnmAwkSdCT5tdaAFRfxLQ9NHBJ5ArPqZeqn0Y39Ednme'
token = '1258774419851350017-WnKXHaKVKyAxVPy9dHmQbrYmdg48TX'
token_secret = 'O5mHbsttf2uSD8IG1F8lG9aaUvFOaSlpW2J9hWGNQpvmt'

# %%
api = twitter.Api(consumer_key = '', consumer_secret='',
    access_token_key='',
    access_token_secret='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-63585767d44d> in <module>
# ----> 1 api = twitter.Api(consumer_key = 'qIkdnrjuFNiRmyTYaR29jX5Yx', consumer_secret='qnvlOFvnmAwkSdCT5tdaAFRfxLQ9NHBJ5ArPqZeqn0Y39Ednme',
#       2     access_token_key='1258774419851350017-WnKXHaKVKyAxVPy9dHmQbrYmdg48TX',
#       3     access_token_secret='O5mHbsttf2uSD8IG1F8lG9aaUvFOaSlpW2J9hWGNQpvmt')
#
# AttributeError: module 'twitter' has no attribute 'Api'

# %%
t = Twitter(
        auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# Get your "home" timeline
t.statuses.home_timeline()
# Out:
# []

# %%
t.search.tweets(q="corona")
# Out:
# {'statuses': [{'created_at': 'Fri May 08 21:19:27 +0000 2020',
#    'id': 1258869145707438085,
#    'id_str': '1258869145707438085',
#    'text': 'RT @RTL_LetsDance: „Die Nacht der Rosen“, wenn wir Corona bis zur nächsten Bachelor-Staffel nicht in den Griff bekommen: #LetsDance https:/…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'LetsDance', 'indices': [121, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RTL_LetsDance',
#       'name': 'Let‘s Dance',
#       'id': 1224697589892861952,
#       'id_str': '1224697589892861952',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
# ...

# %%
# ?twitter
