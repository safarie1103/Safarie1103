# %%
from twitter import *

# %%
#consumer_key = 'qIkdnrjuFNiRmyTYaR29jX5Yx'
#consumer_secret = 'qnvlOFvnmAwkSdCT5tdaAFRfxLQ9NHBJ5ArPqZeqn0Y39Ednme'
#token = '1258774419851350017-WnKXHaKVKyAxVPy9dHmQbrYmdg48TX'
#token_secret = 'O5mHbsttf2uSD8IG1F8lG9aaUvFOaSlpW2J9hWGNQpvmt'

# %%
import json
with open('../APIKeys//APIkeys.json') as f:
    keys = json.load(f)
    consumer_key =  keys['Twitter']['consumer_key']
    consumer_secret = keys['Twitter']['consumer_secret']
    token =  keys['Twitter']['token']
    token_secret =  keys['Twitter']['token_secret']

# %%
t = Twitter(
        auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# Get your "home" timeline
t.statuses.home_timeline()
# Out:
# []

# %%
t.search.tweets(q="corona")
# Out:
# {'statuses': [{'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726785022066688,
#    'id_str': '1261726785022066688',
#    'text': 'corona vai embora por favor, eu só quero ter de volta a minha rotina que eu tanto reclamava\n\njuro que nunca mais vo… https://t.co/WokNoYibJj',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WokNoYibJj',
#       'expanded_url': 'https://twitter.com/i/web/status/1261726785022066688',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1217904458551701511,
#     'id_str': '1217904458551701511',
#     'name': '𝑏𝑒𝑎⁷',
#     'screen_name': 'vanteshyun',
#     'location': '사랑해 태',
#     'description': "➛𝒚𝒐𝒖 𝒂𝒓𝒆 𝒂𝒍𝒍 𝒊 𝒉𝒂𝒗𝒆 𝒏𝒐𝒘, 𝒑𝒍𝒆𝒂𝒔𝒆 𝒅𝒐𝒏'𝒕 𝒍𝒆𝒂𝒗𝒆 𝒎𝒆 ⋆",
#     'url': 'https://t.co/38glgF6cwJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/38glgF6cwJ',
#         'expanded_url': 'https://taegguk.me',
#         'display_url': 'taegguk.me',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 752,
#     'friends_count': 1208,
#     'listed_count': 3,
#     'created_at': 'Thu Jan 16 20:20:35 +0000 2020',
#     'favourites_count': 952,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 246,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1260246821127020544/MVRt4Ihz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260246821127020544/MVRt4Ihz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1217904458551701511/1589301229',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726784741138436,
#    'id_str': '1261726784741138436',
#    'text': '@Merantiwood @ReedeJasper @nexitdenktank @sassenvanelsloo Gaat heel goed in Griekenland. \nTot corona.\nGelukkig hebb… https://t.co/1TqzaGYaDZ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Merantiwood',
#       'name': 'Merantiwood',
#       'id': 2773363301,
#       'id_str': '2773363301',
#       'indices': [0, 12]},
#      {'screen_name': 'ReedeJasper',
#       'name': 'Jasper De Reede',
#       'id': 889790299563859968,
#       'id_str': '889790299563859968',
#       'indices': [13, 25]},
#      {'screen_name': 'nexitdenktank',
#       'name': 'Nexit-Denktank',
#       'id': 1206197940030771201,
#       'id_str': '1206197940030771201',
#       'indices': [26, 40]},
#      {'screen_name': 'sassenvanelsloo',
#       'name': 'Sassen van Elsloo',
#       'id': 267097064,
#       'id_str': '267097064',
#       'indices': [41, 57]}],
#     'urls': [{'url': 'https://t.co/1TqzaGYaDZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1261726784741138436',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1261721540393144320,
#    'in_reply_to_status_id_str': '1261721540393144320',
#    'in_reply_to_user_id': 2773363301,
#    'in_reply_to_user_id_str': '2773363301',
#    'in_reply_to_screen_name': 'Merantiwood',
#    'user': {'id': 999722936415203328,
#     'id_str': '999722936415203328',
#     'name': 'Onverbetelijke Jan Rolle',
#     'screen_name': 'onverbetelijke',
#     'location': '',
#     'description': 'Eerlijk, Europa ja en recht op mening vrijheid. Altijd!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 22,
#     'friends_count': 33,
#     'listed_count': 0,
#     'created_at': 'Thu May 24 18:44:56 +0000 2018',
#     'favourites_count': 764,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8805,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/999724956111048710/5uieNRkB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/999724956111048710/5uieNRkB_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'nl'},
#   {'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726784271204352,
#    'id_str': '1261726784271204352',
#    'text': 'RT @10Souradip: Iss corona mei kisise bhi khudko dur karna muskil hai. Sabki chinta lagi rehti hai\nGod Bless Everyone!',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '10Souradip',
#       'name': 'SOURADIP 🙋\u200d♂️',
#       'id': 1197728161821184002,
#       'id_str': '1197728161821184002',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1179100070915932160,
#     'id_str': '1179100070915932160',
#     'name': 'Dr Aishwarya',
#     'screen_name': 'DrAishwarya10',
#     'location': 'India',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 110,
#     'friends_count': 52,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 01 18:26:01 +0000 2019',
#     'favourites_count': 895,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1104,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261570642563883009/ufUViXXG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261570642563883009/ufUViXXG_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1179100070915932160/1589616743',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 18:19:32 +0000 2020',
#     'id': 1261722971929903104,
#     'id_str': '1261722971929903104',
#     'text': 'Iss corona mei kisise bhi khudko dur karna muskil hai. Sabki chinta lagi rehti hai\nGod Bless Everyone!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'in', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1197728161821184002,
#      'id_str': '1197728161821184002',
#      'name': 'SOURADIP 🙋\u200d♂️',
#      'screen_name': '10Souradip',
#      'location': '',
#      'description': 'FAN OF SONU NIGAM',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 111,
#      'friends_count': 16,
#      'listed_count': 0,
#      'created_at': 'Fri Nov 22 04:07:23 +0000 2019',
#      'favourites_count': 3449,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 9262,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261644424465047555/FbiFcx2g_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261644424465047555/FbiFcx2g_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1197728161821184002/1581998645',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'in'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'in'},
#   {'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726782820139008,
#    'id_str': '1261726782820139008',
#    'text': 'RT @TRTDeutsch: Tausende Menschen haben heute in Stuttgart, Berlin, München und weiteren deutschen Städten gegen Corona-Auflagen der Bundes…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TRTDeutsch',
#       'name': 'TRT Deutsch',
#       'id': 1094919628097290240,
#       'id_str': '1094919628097290240',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1010171280518254594,
#     'id_str': '1010171280518254594',
#     'name': '💙Sven Ludwigsburg 💛',
#     'screen_name': 'Bruddler_',
#     'location': 'Färöer-Inseln',
#     'description': 'Pöhse sehr Pöhse!!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 410,
#     'friends_count': 349,
#     'listed_count': 1,
#     'created_at': 'Fri Jun 22 14:42:56 +0000 2018',
#     'favourites_count': 5386,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10397,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1246456425112535043/eZ512QXh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246456425112535043/eZ512QXh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1010171280518254594/1546300650',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 18:30:00 +0000 2020',
#     'id': 1261725604086534145,
#     'id_str': '1261725604086534145',
#     'text': 'Tausende Menschen haben heute in Stuttgart, Berlin, München und weiteren deutschen Städten gegen Corona-Auflagen de… https://t.co/8Tt8kWO1Z5',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8Tt8kWO1Z5',
#        'expanded_url': 'https://twitter.com/i/web/status/1261725604086534145',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1094919628097290240,
#      'id_str': '1094919628097290240',
#      'name': 'TRT Deutsch',
#      'screen_name': 'TRTDeutsch',
#      'location': 'Berlin',
#      'description': 'Die digitale Plattform für globale Berichte aus Politik, Wirtschaft und Kultur.',
#      'url': 'https://t.co/OgRNl2oNyL',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/OgRNl2oNyL',
#          'expanded_url': 'http://www.trtdeutsch.com',
#          'display_url': 'trtdeutsch.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 10698,
#      'friends_count': 3,
#      'listed_count': 25,
#      'created_at': 'Mon Feb 11 11:22:36 +0000 2019',
#      'favourites_count': 0,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 2018,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1217383244129296384/NqwLMTQR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217383244129296384/NqwLMTQR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1094919628097290240/1578902609',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'de'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'de'},
#   {'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726782304239616,
#    'id_str': '1261726782304239616',
#    'text': 'n vejo a hora desse corona vaza logo, ta loko',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254884742828363780,
#     'id_str': '1254884742828363780',
#     'name': '𝔭𝔞𝔩𝔩𝔬𝔪𝔞🦋',
#     'screen_name': 'maiaapallomaa',
#     'location': 'Paraty, Brasil',
#     'description': 'tt novo. @vascodagama /@tropaDSlimites2🇱🇷',
#     'url': 'https://t.co/rKWa4kEmwX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/rKWa4kEmwX',
#         'expanded_url': 'https://instagram.com/maiaa_palloma?igshid=15jlfxmfchmvm',
#         'display_url': 'instagram.com/maiaa_palloma?…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 881,
#     'friends_count': 882,
#     'listed_count': 0,
#     'created_at': 'Mon Apr 27 21:27:08 +0000 2020',
#     'favourites_count': 877,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 407,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1257554542767550464/HITyngzw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257554542767550464/HITyngzw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254884742828363780/1588388411',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726781444407297,
#    'id_str': '1261726781444407297',
#    'text': 'RT @AllyTheIronic: This young  patient I was seeing last night was dressed so nicely . Black polo neck, caramel coloured coat and straight…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AllyTheIronic',
#       'name': 'Ally(son)',
#       'id': 1194061644,
#       'id_str': '1194061644',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 818763022927859712,
#     'id_str': '818763022927859712',
#     'name': 'Buttercup',
#     'screen_name': 'TheeRorisang',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 431,
#     'friends_count': 126,
#     'listed_count': 1,
#     'created_at': 'Tue Jan 10 10:14:51 +0000 2017',
#     'favourites_count': 2276,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 36406,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1242800033604472834/nUGPLZWZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1242800033604472834/nUGPLZWZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/818763022927859712/1589279165',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 13:30:09 +0000 2020',
#     'id': 1261650143973171200,
#     'id_str': '1261650143973171200',
#     'text': 'This young  patient I was seeing last night was dressed so nicely . Black polo neck, caramel coloured coat and stra… https://t.co/crimuuvk3p',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/crimuuvk3p',
#        'expanded_url': 'https://twitter.com/i/web/status/1261650143973171200',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1194061644,
#      'id_str': '1194061644',
#      'name': 'Ally(son)',
#      'screen_name': 'AllyTheIronic',
#      'location': 'Port Elizabeth, South Africa',
#      'description': 'Herbivore. Eager-beaver. Sushi-lover. Perpetual pun-seeker. Raging cynic. Amateur pouter. Consistent mispronouncer. Husband hugger. Eternal idealist.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 417,
#      'friends_count': 477,
#      'listed_count': 1,
#      'created_at': 'Mon Feb 18 17:26:43 +0000 2013',
#      'favourites_count': 17934,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 5532,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1175070547249684482/l7k2MTSC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1175070547249684482/l7k2MTSC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1194061644/1568641399',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 30,
#     'favorite_count': 148,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 30,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:41 +0000 2020',
#    'id': 1261726781075316736,
#    'id_str': '1261726781075316736',
#    'text': 'RT @vhasslinger: Altenpfleger sollen wegen der starken Belastung in der Coronakrise einen Bonus von bis zu 1500 Euro erhalten. Krankenpfleg…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'vhasslinger',
#       'name': 'Volker Haßlinger',
#       'id': 134205494,
#       'id_str': '134205494',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2969405391,
#     'id_str': '2969405391',
#     'name': 'Birgit Scheeren-bleibt zuhause!',
#     'screen_name': 'scheerenberger',
#     'location': '',
#     'description': 'das 11te Gebot-Du sollst niemanden ertrinken lassen!\ndas 12te Gebot-Du sollst keinen Flüchtling ohne Hilfe lassen!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2784,
#     'friends_count': 5001,
#     'listed_count': 27,
#     'created_at': 'Fri Jan 09 09:29:50 +0000 2015',
#     'favourites_count': 372069,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 583852,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1043843588197683200/BbF6tvcT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1043843588197683200/BbF6tvcT_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2969405391/1493033535',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 17:58:49 +0000 2020',
#     'id': 1261717757504163840,
#     'id_str': '1261717757504163840',
#     'text': 'Altenpfleger sollen wegen der starken Belastung in der Coronakrise einen Bonus von bis zu 1500 Euro erhalten. Krank… https://t.co/2B3vLwZdmJ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/2B3vLwZdmJ',
#        'expanded_url': 'https://twitter.com/i/web/status/1261717757504163840',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 134205494,
#      'id_str': '134205494',
#      'name': 'Volker Haßlinger',
#      'screen_name': 'vhasslinger',
#      'location': 'Franken',
#      'description': 'Psychiatrische Pflege (BAPP, DFPP, DGPPN), Krisendienst Mittelfranken, Bündnis 90/Die Grünen',
#      'url': 'http://t.co/2f1CeA5VTC',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/2f1CeA5VTC',
#          'expanded_url': 'http://www.vhasslinger.de',
#          'display_url': 'vhasslinger.de',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 199,
#      'friends_count': 270,
#      'listed_count': 4,
#      'created_at': 'Sat Apr 17 19:01:47 +0000 2010',
#      'favourites_count': 2969,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 919,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '066990',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/831116400/vhh-fav3_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831116400/vhh-fav3_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134205494/1417800388',
#      'profile_link_color': '006699',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFCF56',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'de'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'de'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726780962091011,
#    'id_str': '1261726780962091011',
#    'text': 'RT @VogelvrijeHArts: "Hij zei: \'Ik kan toch niet doodgaan? Ik wil dit nog helemaal niet, ik ben pas 42.\'" \nCyriel (42) stierf door corona:…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'VogelvrijeHArts',
#       'name': 'Vogelvrije Huisarts',
#       'id': 124280192,
#       'id_str': '124280192',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1233431162091118592,
#     'id_str': '1233431162091118592',
#     'name': 'ChanoIDH',
#     'screen_name': 'ChanoIdh',
#     'location': '',
#     'description': 'Chano',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 30,
#     'friends_count': 100,
#     'listed_count': 0,
#     'created_at': 'Fri Feb 28 16:38:16 +0000 2020',
#     'favourites_count': 10647,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4409,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 18:17:30 +0000 2020',
#     'id': 1261722457767059456,
#     'id_str': '1261722457767059456',
#     'text': '"Hij zei: \'Ik kan toch niet doodgaan? Ik wil dit nog helemaal niet, ik ben pas 42.\'" \nCyriel (42) stierf door coron… https://t.co/7NYdhIwrK3',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7NYdhIwrK3',
#        'expanded_url': 'https://twitter.com/i/web/status/1261722457767059456',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 124280192,
#      'id_str': '124280192',
#      'name': 'Vogelvrije Huisarts',
#      'screen_name': 'VogelvrijeHArts',
#      'location': 'Amsterdam, Nederland',
#      'description': 'Huisarts, ex-tropenarts, gaf #NZa een pak slaag. Tweet over dit asociale zorgstelsel, #VWS, Zorgverzekeraars, economen. Verwar mijn humeur niet met de tweets 😎',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 14435,
#      'friends_count': 84,
#      'listed_count': 213,
#      'created_at': 'Thu Mar 18 21:52:58 +0000 2010',
#      'favourites_count': 8934,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 212,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/636174349108690944/e0_8CtDx_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/636174349108690944/e0_8CtDx_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/124280192/1451639982',
#      'profile_link_color': '038543',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 20,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'nl'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'nl'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726780865593348,
#    'id_str': '1261726780865593348',
#    'text': '#Eurovision Yes!!!! Corona didn’t beat that one https://t.co/jwKRgzofdw',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Eurovision', 'indices': [0, 11]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1261726774725091328,
#       'id_str': '1261726774725091328',
#       'indices': [48, 71],
#       'media_url': 'http://pbs.twimg.com/media/EYKN0RMWoAAciEL.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EYKN0RMWoAAciEL.jpg',
#       'url': 'https://t.co/jwKRgzofdw',
#       'display_url': 'pic.twitter.com/jwKRgzofdw',
#       'expanded_url': 'https://twitter.com/RoderichRoemhi1/status/1261726780865593348/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1261726774725091328,
#       'id_str': '1261726774725091328',
#       'indices': [48, 71],
#       'media_url': 'http://pbs.twimg.com/media/EYKN0RMWoAAciEL.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EYKN0RMWoAAciEL.jpg',
#       'url': 'https://t.co/jwKRgzofdw',
#       'display_url': 'pic.twitter.com/jwKRgzofdw',
#       'expanded_url': 'https://twitter.com/RoderichRoemhi1/status/1261726780865593348/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1040666267999510529,
#     'id_str': '1040666267999510529',
#     'name': 'Rodi Roemhild',
#     'screen_name': 'RoderichRoemhi1',
#     'location': 'Schweden',
#     'description': 'Evolutionary Biologist with broad interests, Bacteriologist, Optimist, ☀️, 🇪🇺  🇸🇪  🇩🇪 🇺🇸 Life is Good',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 123,
#     'friends_count': 102,
#     'listed_count': 0,
#     'created_at': 'Fri Sep 14 18:19:07 +0000 2018',
#     'favourites_count': 359,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 189,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1051033243473072128/NXDkjdrI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051033243473072128/NXDkjdrI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1040666267999510529/1539421007',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726780341321730,
#    'id_str': '1261726780341321730',
#    'text': 'RT @TRTDeutsch: Tausende Menschen haben heute in Stuttgart, Berlin, München und weiteren deutschen Städten gegen Corona-Auflagen der Bundes…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TRTDeutsch',
#       'name': 'TRT Deutsch',
#       'id': 1094919628097290240,
#       'id_str': '1094919628097290240',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1185837766149660672,
#     'id_str': '1185837766149660672',
#     'name': 'HÜTAİ',
#     'screen_name': 'hutai_hacettepe',
#     'location': 'Hacettepe University/Ankara',
#     'description': 'Türk-Alman İlişkileri Uygulama ve Araştırma Merkezi - Resmi Twitter Hesabı Forschungszentrum für türkisch-deutsche Beziehungen - Offiziell Twitter Seite',
#     'url': 'https://t.co/mIQCjzEE89',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/mIQCjzEE89',
#         'expanded_url': 'http://www.hutai.hacettepe.edu.tr',
#         'display_url': 'hutai.hacettepe.edu.tr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 267,
#     'friends_count': 39,
#     'listed_count': 2,
#     'created_at': 'Sun Oct 20 08:39:41 +0000 2019',
#     'favourites_count': 93,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 149,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1192662925229641728/zvvNZQ2-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1192662925229641728/zvvNZQ2-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1185837766149660672/1573189904',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 18:30:00 +0000 2020',
#     'id': 1261725604086534145,
#     'id_str': '1261725604086534145',
#     'text': 'Tausende Menschen haben heute in Stuttgart, Berlin, München und weiteren deutschen Städten gegen Corona-Auflagen de… https://t.co/8Tt8kWO1Z5',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8Tt8kWO1Z5',
#        'expanded_url': 'https://twitter.com/i/web/status/1261725604086534145',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1094919628097290240,
#      'id_str': '1094919628097290240',
#      'name': 'TRT Deutsch',
#      'screen_name': 'TRTDeutsch',
#      'location': 'Berlin',
#      'description': 'Die digitale Plattform für globale Berichte aus Politik, Wirtschaft und Kultur.',
#      'url': 'https://t.co/OgRNl2oNyL',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/OgRNl2oNyL',
#          'expanded_url': 'http://www.trtdeutsch.com',
#          'display_url': 'trtdeutsch.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 10698,
#      'friends_count': 3,
#      'listed_count': 25,
#      'created_at': 'Mon Feb 11 11:22:36 +0000 2019',
#      'favourites_count': 0,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 2018,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1217383244129296384/NqwLMTQR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217383244129296384/NqwLMTQR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1094919628097290240/1578902609',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
# ...
#        'display_url': 'idtoday.co/nasional/puan-…',
#        'indices': [36, 59]}]},
#     'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1134163908174917632,
#      'id_str': '1134163908174917632',
#      'name': 'Elin Moenik',
#      'screen_name': 'ElinMoenik2',
#      'location': 'Sabungan-Labuhanbatu selatan',
#      'description': 'BETY bidadari surgaku',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 215,
#      'friends_count': 1211,
#      'listed_count': 0,
#      'created_at': 'Thu May 30 18:25:22 +0000 2019',
#      'favourites_count': 116,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 9869,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1134205589158940672/ppMSNxZV_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1134205589158940672/ppMSNxZV_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1134163908174917632/1561646540',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726778848092167,
#    'id_str': '1261726778848092167',
#    'text': '@GayeUsluer Ulan Corona yap bir iyilik Nihat abine',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GayeUsluer',
#       'name': 'Gaye Usluer',
#       'id': 216471007,
#       'id_str': '216471007',
#       'indices': [0, 11]}],
#     'urls': []},
#    'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1261646222684827650,
#    'in_reply_to_status_id_str': '1261646222684827650',
#    'in_reply_to_user_id': 216471007,
#    'in_reply_to_user_id_str': '216471007',
#    'in_reply_to_screen_name': 'GayeUsluer',
#    'user': {'id': 873523759923200001,
#     'id_str': '873523759923200001',
#     'name': 'Mesut',
#     'screen_name': 'ozezmesut',
#     'location': 'İstanbul, Türkiye',
#     'description': 'Atatürkçü Sosyal demokrat kul hakkı yemez renkler sarı ve kırmızı 🌟🌟🌟🌟ve tabiki ay ve yıldız',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 51,
#     'friends_count': 46,
#     'listed_count': 0,
#     'created_at': 'Sat Jun 10 12:54:28 +0000 2017',
#     'favourites_count': 7447,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6899,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/992825076428001281/cad6DmQn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992825076428001281/cad6DmQn_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tr'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726778537672706,
#    'id_str': '1261726778537672706',
#    'text': 'RT @Shard31: @anildongre09 @NidhiAPardeshi @deepakdeshpand4 @DasShaktikanta @RBI @RBI @DasShaktikanta don’t think #PMCBankDepositors are af…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'PMCBankDepositors',
#       'indices': [114, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Shard31',
#       'name': 'Shardul Kadre',
#       'id': 426732309,
#       'id_str': '426732309',
#       'indices': [3, 11]},
#      {'screen_name': 'anildongre09',
#       'name': 'ANIL DONGRE',
#       'id': 186383501,
#       'id_str': '186383501',
#       'indices': [13, 26]},
#      {'screen_name': 'NidhiAPardeshi',
#       'name': 'Nidhi A Pardeshi',
#       'id': 1156832490,
#       'id_str': '1156832490',
#       'indices': [27, 42]},
#      {'screen_name': 'deepakdeshpand4',
#       'name': 'deepak deshpande',
#       'id': 1254325496,
#       'id_str': '1254325496',
#       'indices': [43, 59]},
#      {'screen_name': 'DasShaktikanta',
#       'name': 'Shaktikanta Das',
#       'id': 2966532212,
#       'id_str': '2966532212',
#       'indices': [60, 75]},
#      {'screen_name': 'RBI',
#       'name': 'ReserveBankOfIndia',
#       'id': 478432912,
#       'id_str': '478432912',
#       'indices': [76, 80]},
#      {'screen_name': 'RBI',
#       'name': 'ReserveBankOfIndia',
#       'id': 478432912,
#       'id_str': '478432912',
#       'indices': [81, 85]},
#      {'screen_name': 'DasShaktikanta',
#       'name': 'Shaktikanta Das',
#       'id': 2966532212,
#       'id_str': '2966532212',
#       'indices': [86, 101]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 751575816576860160,
#     'id_str': '751575816576860160',
#     'name': 'Manjeet sudan',
#     'screen_name': 'manjeet_sudan',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 43,
#     'friends_count': 76,
#     'listed_count': 0,
#     'created_at': 'Sat Jul 09 00:36:53 +0000 2016',
#     'favourites_count': 7119,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12212,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Apr 10 10:00:38 +0000 2020',
#     'id': 1248551457080528896,
#     'id_str': '1248551457080528896',
#     'text': '@anildongre09 @NidhiAPardeshi @deepakdeshpand4 @DasShaktikanta @RBI @RBI @DasShaktikanta don’t think… https://t.co/WKtsHPbUip',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'anildongre09',
#        'name': 'ANIL DONGRE',
#        'id': 186383501,
#        'id_str': '186383501',
#        'indices': [0, 13]},
#       {'screen_name': 'NidhiAPardeshi',
#        'name': 'Nidhi A Pardeshi',
#        'id': 1156832490,
#        'id_str': '1156832490',
#        'indices': [14, 29]},
#       {'screen_name': 'deepakdeshpand4',
#        'name': 'deepak deshpande',
#        'id': 1254325496,
#        'id_str': '1254325496',
#        'indices': [30, 46]},
#       {'screen_name': 'DasShaktikanta',
#        'name': 'Shaktikanta Das',
#        'id': 2966532212,
#        'id_str': '2966532212',
#        'indices': [47, 62]},
#       {'screen_name': 'RBI',
#        'name': 'ReserveBankOfIndia',
#        'id': 478432912,
#        'id_str': '478432912',
#        'indices': [63, 67]},
#       {'screen_name': 'RBI',
#        'name': 'ReserveBankOfIndia',
#        'id': 478432912,
#        'id_str': '478432912',
#        'indices': [68, 72]},
#       {'screen_name': 'DasShaktikanta',
#        'name': 'Shaktikanta Das',
#        'id': 2966532212,
#        'id_str': '2966532212',
#        'indices': [73, 88]}],
#      'urls': [{'url': 'https://t.co/WKtsHPbUip',
#        'expanded_url': 'https://twitter.com/i/web/status/1248551457080528896',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [102, 125]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1248069873835507713,
#     'in_reply_to_status_id_str': '1248069873835507713',
#     'in_reply_to_user_id': 186383501,
#     'in_reply_to_user_id_str': '186383501',
#     'in_reply_to_screen_name': 'anildongre09',
#     'user': {'id': 426732309,
#      'id_str': '426732309',
#      'name': 'Shardul Kadre',
#      'screen_name': 'Shard31',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13,
#      'friends_count': 65,
#      'listed_count': 0,
#      'created_at': 'Fri Dec 02 16:33:00 +0000 2011',
#      'favourites_count': 47,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 57,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/775950306374848513/9v7ecibg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/775950306374848513/9v7ecibg_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726778130923521,
#    'id_str': '1261726778130923521',
#    'text': 'Hier für alle Bildungsinteressierte die Thüringer Verordnung zur Abminderung der Corona-Pandemie im Schulbereich. S… https://t.co/bbkqRwkBVn',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bbkqRwkBVn',
#       'expanded_url': 'https://twitter.com/i/web/status/1261726778130923521',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 827151378195824640,
#     'id_str': '827151378195824640',
#     'name': 'Torsten Wolf',
#     'screen_name': 'TorstenWolf_MdL',
#     'location': 'Jena, Deutschland',
#     'description': 'Mitglied des Thüringer Landtages, Bildungspolitischer Sprecher, Wahlkreis Jena I',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 407,
#     'friends_count': 249,
#     'listed_count': 12,
#     'created_at': 'Thu Feb 02 13:47:11 +0000 2017',
#     'favourites_count': 915,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 963,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/827156437843529732/GPxTGskI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827156437843529732/GPxTGskI_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'de'}],
#  'search_metadata': {'completed_in': 0.138,
#   'max_id': 1261726785022066688,
#   'max_id_str': '1261726785022066688',
#   'next_results': '?max_id=1261726778130923520&q=corona&include_entities=1',
#   'query': 'corona',
#   'refresh_url': '?since_id=1261726785022066688&q=corona&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
t.search.tweets(q="corona virus")
# Out:
# {'statuses': [{'created_at': 'Sat May 16 18:34:45 +0000 2020',
#    'id': 1261726801186955264,
#    'id_str': '1261726801186955264',
#    'text': 'RT @bancadipiacenza: Hai un ContOnline Amici Fedeli o un Conto Amici Fedeli? Abbiamo stipulato accordi per garantire l’assistenza ai tuoi a…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'bancadipiacenza',
#       'name': '@Banca di Piacenza',
#       'id': 928210643022503936,
#       'id_str': '928210643022503936',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1037928510,
#     'id_str': '1037928510',
#     'name': 'Pierangelo Badenchini',
#     'screen_name': 'PBadenkini',
#     'location': 'Villò',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 25,
#     'friends_count': 19,
#     'listed_count': 0,
#     'created_at': 'Wed Dec 26 19:58:09 +0000 2012',
#     'favourites_count': 1588,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 445,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/975812988270776321/wyVs7xm9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/975812988270776321/wyVs7xm9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1037928510/1521487540',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri May 15 14:54:43 +0000 2020',
#     'id': 1261309038698147842,
#     'id_str': '1261309038698147842',
#     'text': 'Hai un ContOnline Amici Fedeli o un Conto Amici Fedeli? Abbiamo stipulato accordi per garantire l’assistenza ai tuo… https://t.co/MQTVReUIoF',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MQTVReUIoF',
#        'expanded_url': 'https://twitter.com/i/web/status/1261309038698147842',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 928210643022503936,
#      'id_str': '928210643022503936',
#      'name': '@Banca di Piacenza',
#      'screen_name': 'bancadipiacenza',
#      'location': 'Piacenza, Emilia Romagna',
#      'description': '© Tutti i diritti riservati - Libera la riproduzione, citando la fonte',
#      'url': 'https://t.co/NznFDnMpZi',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/NznFDnMpZi',
#          'expanded_url': 'http://www.bancadipiacenza.it',
#          'display_url': 'bancadipiacenza.it',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 817,
#      'friends_count': 2,
#      'listed_count': 0,
#      'created_at': 'Wed Nov 08 10:40:37 +0000 2017',
#      'favourites_count': 263,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 633,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/928238351630716929/fRs4bnbu_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/928238351630716929/fRs4bnbu_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/928210643022503936/1511966731',
#      'profile_link_color': '002C51',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'it'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'it'},
#   {'created_at': 'Sat May 16 18:34:43 +0000 2020',
#    'id': 1261726793515532289,
#    'id_str': '1261726793515532289',
#    'text': 'Festival exit postponed due to Corona virus. #NoviSad #Exit2020 #Serbia https://t.co/K5yIo8ATAB',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'NoviSad', 'indices': [45, 53]},
#      {'text': 'Exit2020', 'indices': [54, 63]},
#      {'text': 'Serbia', 'indices': [64, 71]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/K5yIo8ATAB',
#       'expanded_url': 'https://twitter.com/n1infobg/status/1261717440913903617',
#       'display_url': 'twitter.com/n1infobg/statu…',
#       'indices': [72, 95]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1872764503,
#     'id_str': '1872764503',
#     'name': 'Jessica Bruinekool',
#     'screen_name': 'Jessicab1985_6',
#     'location': 'Amersfoort, Nederland',
#     'description': "official twitter account! Living in the Netherlands.😍❤️ Serbia.🇷🇸🇳🇱🇰🇷 love #CharmedOG #Castle #Spicegirls #NTIDST.  don't follow me with a scam account!",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 132,
#     'friends_count': 1200,
#     'listed_count': 1,
#     'created_at': 'Mon Sep 16 19:18:52 +0000 2013',
#     'favourites_count': 18571,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3274,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1259931464394825737/uwxdH9It_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1259931464394825737/uwxdH9It_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1872764503/1486324164',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1261717440913903617,
#    'quoted_status_id_str': '1261717440913903617',
#    'quoted_status': {'created_at': 'Sat May 16 17:57:34 +0000 2020',
#     'id': 1261717440913903617,
#     'id_str': '1261717440913903617',
#     'text': 'Festival Egzit odložen, organizatori u otvorenom pismu zatražili pomoć države https://t.co/HUn9Iy2p9P',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/HUn9Iy2p9P',
#        'expanded_url': 'http://rs.n1info.com/Showbiz/a600286/Festival-Egzit-odlozen-organizatori-u-otvorenom-pismu-zatrazili-pomoc-drzave.html',
#        'display_url': 'rs.n1info.com/Showbiz/a60028…',
#        'indices': [78, 101]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2709060385,
#      'id_str': '2709060385',
#      'name': 'TV N1 Beograd',
#      'screen_name': 'N1infoBG',
#      'location': 'Belgrade, Republic of Serbia',
#      'description': 'CNN exclusive channel affiliate - News from Serbia / Vesti iz Srbije',
#      'url': 'http://t.co/n6B9aiX2SZ',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/n6B9aiX2SZ',
#          'expanded_url': 'http://n1info.com',
#          'display_url': 'n1info.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 121822,
#      'friends_count': 785,
#      'listed_count': 286,
#      'created_at': 'Tue Aug 05 11:05:47 +0000 2014',
#      'favourites_count': 373,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 177625,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/786181074154053632/viUyLenc_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/786181074154053632/viUyLenc_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2709060385/1453108030',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:43 +0000 2020',
#    'id': 1261726792550952960,
#    'id_str': '1261726792550952960',
#    'text': "@martinmemarti11 @birmingham_live Don't think it was anything to do with sexual harassment. More likely it's to do with Corona virus issues.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'martinmemarti11',
#       'name': 'Martin',
#       'id': 1215407231216295937,
#       'id_str': '1215407231216295937',
#       'indices': [0, 16]},
#      {'screen_name': 'birmingham_live',
#       'name': 'Birmingham Live',
#       'id': 12870772,
#       'id_str': '12870772',
#       'indices': [17, 33]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1261718034244349952,
#    'in_reply_to_status_id_str': '1261718034244349952',
#    'in_reply_to_user_id': 1215407231216295937,
#    'in_reply_to_user_id_str': '1215407231216295937',
#    'in_reply_to_screen_name': 'martinmemarti11',
#    'user': {'id': 740063555119157248,
#     'id_str': '740063555119157248',
#     'name': 'Steve Ford',
#     'screen_name': 'SteveFo48989645',
#     'location': '',
#     'description': 'the most considerate kind hearted person I know.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9,
#     'friends_count': 63,
#     'listed_count': 0,
#     'created_at': 'Tue Jun 07 06:11:16 +0000 2016',
#     'favourites_count': 83,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 129,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/741384802713141249/NNgXisqj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741384802713141249/NNgXisqj_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:42 +0000 2020',
#    'id': 1261726788826222592,
#    'id_str': '1261726788826222592',
#    'text': 'I want to get a sandwich from the Ferry Building because I miss bread but effort&gt;cold weather&gt;weird people talking to me&gt;corona virus nahh',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 933919810148220928,
#     'id_str': '933919810148220928',
#     'name': 'クリ☆ (꒪˙꒳˙꒪ )',
#     'screen_name': 'kriistarr',
#     'location': 'A 3 star island',
#     'description': '来星⭐️ Here is a reference I don’t understand/Welcome to one of the worst parts of the internet',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 36,
#     'friends_count': 46,
#     'listed_count': 0,
#     'created_at': 'Fri Nov 24 04:46:48 +0000 2017',
#     'favourites_count': 516,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 726,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1230629755520737286/-wDwq5yZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1230629755520737286/-wDwq5yZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/933919810148220928/1562404519',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:42 +0000 2020',
#    'id': 1261726786813116418,
#    'id_str': '1261726786813116418',
#    'text': '@WaltDisneyWorld Won’t be able to come to this until we are back to normal and no corona virus.  😞',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WaltDisneyWorld',
#       'name': 'Walt Disney World',
#       'id': 15220473,
#       'id_str': '15220473',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1261431484872683520,
#    'in_reply_to_status_id_str': '1261431484872683520',
#    'in_reply_to_user_id': 15220473,
#    'in_reply_to_user_id_str': '15220473',
#    'in_reply_to_screen_name': 'WaltDisneyWorld',
#    'user': {'id': 2738347889,
#     'id_str': '2738347889',
#     'name': 'Jmk',
#     'screen_name': 'JMK_2018',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 12,
#     'friends_count': 53,
#     'listed_count': 0,
#     'created_at': 'Sat Aug 09 18:47:49 +0000 2014',
#     'favourites_count': 2170,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1317,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1105250005235965952/i8F8NHCK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105250005235965952/i8F8NHCK_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:40 +0000 2020',
#    'id': 1261726777350684672,
#    'id_str': '1261726777350684672',
#    'text': 'RT @monark: Sou só eu que esta CAGANDO pro corona virus?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'monark',
#       'name': '♔Monark',
#       'id': 242967720,
#       'id_str': '242967720',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3173658931,
#     'id_str': '3173658931',
#     'name': 'gang gang bro it hurts',
#     'screen_name': 'Francisszzzz',
#     'location': 'Brasil',
#     'description': 'queimá pra chegar',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 299,
#     'friends_count': 224,
#     'listed_count': 3,
#     'created_at': 'Sat Apr 25 23:09:04 +0000 2015',
#     'favourites_count': 13550,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 23190,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254997571782803458/mdhn6pMv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254997571782803458/mdhn6pMv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3173658931/1522978056',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Mar 03 12:47:56 +0000 2020',
#     'id': 1234822819256643587,
#     'id_str': '1234822819256643587',
#     'text': 'Sou só eu que esta CAGANDO pro corona virus?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 242967720,
#      'id_str': '242967720',
#      'name': '♔Monark',
#      'screen_name': 'monark',
#      'location': 'Brasil',
#      'description': 'Flow Podcast toda, Quarta, Quinta e Sexta. https://t.co/UoOlW2lbir\n\nVivendo pelo principio.',
#      'url': 'https://t.co/NTkDckxiu0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/NTkDckxiu0',
#          'expanded_url': 'https://www.youtube.com/user/RandonsPlays',
#          'display_url': 'youtube.com/user/RandonsPl…',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/UoOlW2lbir',
#          'expanded_url': 'http://twitch.tv/FlowPodcast',
#          'display_url': 'twitch.tv/FlowPodcast',
#          'indices': [43, 66]}]}},
#      'protected': False,
#      'followers_count': 813943,
#      'friends_count': 9132,
#      'listed_count': 738,
#      'created_at': 'Wed Jan 26 00:43:15 +0000 2011',
#      'favourites_count': 4738,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 15524,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/846497829996675072/dKtqI8hY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/846497829996675072/dKtqI8hY_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/242967720/1569443419',
#      'profile_link_color': '89C9FA',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 266,
#     'favorite_count': 3011,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 266,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 16 18:34:39 +0000 2020',
#    'id': 1261726776683835392,
#    'id_str': '1261726776683835392',
#    'text': 'RT @laneeoficial: Eu não gosto de corona vírus não viu, Brasil? 😂 https://t.co/saGXbzeYlH',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'laneeoficial',
#       'name': 'Flay',
#       'id': 1214339573305815040,
#       'id_str': '1214339573305815040',
#       'indices': [3, 16]}],
#     'urls': [],
#     'media': [{'id': 1249690267365642245,
#       'id_str': '1249690267365642245',
#       'indices': [66, 89],
#       'media_url': 'http://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#       'url': 'https://t.co/saGXbzeYlH',
#       'display_url': 'pic.twitter.com/saGXbzeYlH',
#       'expanded_url': 'https://twitter.com/laneeoficial/status/1249690274391040002/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1024, 'h': 921, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 612, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 921, 'resize': 'fit'}},
#       'source_status_id': 1249690274391040002,
#       'source_status_id_str': '1249690274391040002',
#       'source_user_id': 1214339573305815040,
#       'source_user_id_str': '1214339573305815040'}]},
#    'extended_entities': {'media': [{'id': 1249690267365642245,
#       'id_str': '1249690267365642245',
#       'indices': [66, 89],
#       'media_url': 'http://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#       'url': 'https://t.co/saGXbzeYlH',
#       'display_url': 'pic.twitter.com/saGXbzeYlH',
#       'expanded_url': 'https://twitter.com/laneeoficial/status/1249690274391040002/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1024, 'h': 921, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 612, 'resize': 'fit'},
#        'large': {'w': 1024, 'h': 921, 'resize': 'fit'}},
#       'source_status_id': 1249690274391040002,
#       'source_status_id_str': '1249690274391040002',
#       'source_user_id': 1214339573305815040,
#       'source_user_id_str': '1214339573305815040'}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1261724337226289152,
#     'id_str': '1261724337226289152',
#     'name': 'Flay',
#     'screen_name': 'laneeoficialz',
#     'location': '',
#     'description': 'Cantora da banda: @laneemara Fã clube dedicado a: @laneeoficial',
#     'url': 'https://t.co/KtRxmjH4j6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KtRxmjH4j6',
#         'expanded_url': 'https://instagram.com/laneeoficialz?igshid=173t2lbljzrvt',
#         'display_url': 'instagram.com/laneeoficialz?…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 17,
#     'listed_count': 0,
#     'created_at': 'Sat May 16 18:25:13 +0000 2020',
#     'favourites_count': 4,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261725127919755266/Yo_hiWJ5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261725127919755266/Yo_hiWJ5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1261724337226289152/1589653694',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Apr 13 13:25:54 +0000 2020',
#     'id': 1249690274391040002,
#     'id_str': '1249690274391040002',
#     'text': 'Eu não gosto de corona vírus não viu, Brasil? 😂 https://t.co/saGXbzeYlH',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1249690267365642245,
#        'id_str': '1249690267365642245',
#        'indices': [48, 71],
#        'media_url': 'http://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#        'url': 'https://t.co/saGXbzeYlH',
#        'display_url': 'pic.twitter.com/saGXbzeYlH',
#        'expanded_url': 'https://twitter.com/laneeoficial/status/1249690274391040002/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1024, 'h': 921, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 612, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 921, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1249690267365642245,
#        'id_str': '1249690267365642245',
#        'indices': [48, 71],
#        'media_url': 'http://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EVfKrVGXkAUWnf2.jpg',
#        'url': 'https://t.co/saGXbzeYlH',
#        'display_url': 'pic.twitter.com/saGXbzeYlH',
#        'expanded_url': 'https://twitter.com/laneeoficial/status/1249690274391040002/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1024, 'h': 921, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 612, 'resize': 'fit'},
#         'large': {'w': 1024, 'h': 921, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1214339573305815040,
#      'id_str': '1214339573305815040',
#      'name': 'Flay',
#      'screen_name': 'laneeoficial',
#      'location': 'Nova Floresta, Paraíba',
#      'description': 'Perfil Oficial | BBB20 | Cantora da dupla Lane & Mara | Contato: comercial@flayoficial.com.br',
#      'url': 'https://t.co/88SG3t97Lx',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/88SG3t97Lx',
#          'expanded_url': 'http://instagram.com/flay',
#          'display_url': 'instagram.com/flay',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 450808,
#      'friends_count': 862,
#      'listed_count': 62,
#      'created_at': 'Tue Jan 07 00:15:14 +0000 2020',
#      'favourites_count': 9326,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5925,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1257267638004338689/RWb8B29Q_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257267638004338689/RWb8B29Q_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1214339573305815040/1588111286',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22938,
#     'favorite_count': 198681,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 22938,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 16 18:34:39 +0000 2020',
#    'id': 1261726776096690176,
#    'id_str': '1261726776096690176',
#    'text': 'RT @ukreloaded: Either the U.K has gotten it wrong?\n\nOr Russia are lying through their teeth?\n\nRussia - 272,043 Cases Of Corona Virus - 2,5…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ukreloaded',
#       'name': 'James Gray',
#       'id': 754635115368685568,
#       'id_str': '754635115368685568',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1174777712466124801,
#     'id_str': '1174777712466124801',
#     'name': 'DTrend',
#     'screen_name': 'DanielleTrent5',
#     'location': 'England, United Kingdom',
#     'description': 'hardworking, love my country,  and am a proud leaver!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 244,
#     'friends_count': 349,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 19 20:10:18 +0000 2019',
#     'favourites_count': 7662,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1758,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1220472695139307525/xL552zQQ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220472695139307525/xL552zQQ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 16:24:45 +0000 2020',
#     'id': 1261694085204709377,
#     'id_str': '1261694085204709377',
#     'text': 'Either the U.K has gotten it wrong?\n\nOr Russia are lying through their teeth?\n\nRussia - 272,043 Cases Of Corona Vir… https://t.co/MokYaKVs86',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MokYaKVs86',
#        'expanded_url': 'https://twitter.com/i/web/status/1261694085204709377',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 754635115368685568,
#      'id_str': '754635115368685568',
#      'name': 'James Gray',
#      'screen_name': 'ukreloaded',
#      'location': 'United Kingdom',
#      'description': 'Just sharing my views & listening to others\nAppreciate all followers & I will follow back ASAP',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13427,
#      'friends_count': 11022,
#      'listed_count': 23,
#      'created_at': 'Sun Jul 17 11:13:26 +0000 2016',
#      'favourites_count': 64742,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 9,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1247667341044912128/2KZ31a7w_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247667341044912128/2KZ31a7w_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/754635115368685568/1585605645',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 50,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:39 +0000 2020',
#    'id': 1261726773701730306,
#    'id_str': '1261726773701730306',
#    'text': '@simoesrochaa corona virus nem existe mano',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'simoesrochaa',
#       'name': 'Bernardo Simoes',
#       'id': 993849661101395969,
#       'id_str': '993849661101395969',
#       'indices': [0, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1261726607041007618,
#    'in_reply_to_status_id_str': '1261726607041007618',
#    'in_reply_to_user_id': 993849661101395969,
#    'in_reply_to_user_id_str': '993849661101395969',
#    'in_reply_to_screen_name': 'simoesrochaa',
#    'user': {'id': 2390202090,
#     'id_str': '2390202090',
#     'name': 'Ângelo',
#     'screen_name': 'Angelorh0102',
#     'location': '',
#     'description': 'é',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 312,
#     'friends_count': 301,
#     'listed_count': 0,
#     'created_at': 'Sat Mar 15 02:03:18 +0000 2014',
#     'favourites_count': 2934,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7852,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1247744205964734474/7gVlvie8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247744205964734474/7gVlvie8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2390202090/1583720664',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 16 18:34:38 +0000 2020',
#    'id': 1261726772221132800,
#    'id_str': '1261726772221132800',
#    'text': 'morrer por corona vírus? você vai é viver eternamente como meu filho https://t.co/QwrCWZqadC',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/QwrCWZqadC',
#       'expanded_url': 'https://twitter.com/loucapattzstew/status/1261326778418761729',
#       'display_url': 'twitter.com/loucapattzstew…',
#       'indices': [69, 92]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 761262093173723136,
#     'id_str': '761262093173723136',
#     'name': 'Barbosa',
#     'screen_name': '_gabicbarbosa',
#     'location': 'Joinville, Brasil',
#     'description': 'de acordo c minha prima: rainha das chatas',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 629,
#     'friends_count': 427,
#     'listed_count': 0,
#     'created_at': 'Thu Aug 04 18:06:41 +0000 2016',
#     'favourites_count': 29004,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 9622,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1246957137668067334/gOUoyGfy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246957137668067334/gOUoyGfy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/761262093173723136/1562297296',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1261326778418761729,
#    'quoted_status_id_str': '1261326778418761729',
#    'quoted_status': {'created_at': 'Fri May 15 16:05:12 +0000 2020',
#     'id': 1261326778418761729,
#     'id_str': '1261326778418761729',
#     'text': 'Se Carlisle Cullen fosse Ministro da saúde isso não estaria acontecendo https://t.co/7Z6QCBoHBO',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1261326164121059330,
#        'id_str': '1261326164121059330',
#        'indices': [72, 95],
#        'media_url': 'http://pbs.twimg.com/media/EYEhdqZXgAI3chp.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EYEhdqZXgAI3chp.jpg',
#        'url': 'https://t.co/7Z6QCBoHBO',
#        'display_url': 'pic.twitter.com/7Z6QCBoHBO',
#        'expanded_url': 'https://twitter.com/loucapattzstew/status/1261326778418761729/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 564, 'h': 438, 'resize': 'fit'},
#         'medium': {'w': 564, 'h': 438, 'resize': 'fit'},
#         'small': {'w': 564, 'h': 438, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1261326164121059330,
#        'id_str': '1261326164121059330',
#        'indices': [72, 95],
#        'media_url': 'http://pbs.twimg.com/media/EYEhdqZXgAI3chp.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EYEhdqZXgAI3chp.jpg',
#        'url': 'https://t.co/7Z6QCBoHBO',
#        'display_url': 'pic.twitter.com/7Z6QCBoHBO',
# ...
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 06:18:34 +0000 2020',
#     'id': 1261541531523190784,
#     'id_str': '1261541531523190784',
#     'text': 'Its hard to fight Corona Virus \nBefore you fight poverty\n\nBefore you give me water to\nWash my hands\nGive me water t… https://t.co/eB2FXoPRGR',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/eB2FXoPRGR',
#        'expanded_url': 'https://twitter.com/i/web/status/1261541531523190784',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2471480189,
#      'id_str': '2471480189',
#      'name': '🇰🇪 I AM MWANIKI™🇰🇪',
#      'screen_name': 'Jc_Mwaniki',
#      'location': 'Kenya🇰🇪',
#      'description': '🇰🇪God fearing🇰🇪 Love God//God first//Language teacher//Media personality// Tutor//Instrumentalist//ICT tutor// language tutor//🇰🇪  #KOTLoyals 🌐',
#      'url': 'https://t.co/yqncrF5SSW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/yqncrF5SSW',
#          'expanded_url': 'https://www.instagram.com/jc_mwaniki/?_rdc=1&_rdr',
#          'display_url': 'instagram.com/jc_mwaniki/?_r…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 28028,
#      'friends_count': 24354,
#      'listed_count': 12,
#      'created_at': 'Wed Apr 09 11:20:23 +0000 2014',
#      'favourites_count': 12802,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10753,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1258842828345675777/MAZJwpjS_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1258842828345675777/MAZJwpjS_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2471480189/1589535228',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 254,
#     'favorite_count': 704,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 254,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:34 +0000 2020',
#    'id': 1261726751689932800,
#    'id_str': '1261726751689932800',
#    'text': 'RT @nafees_mall: Former President #PPP Minority Khi @Mushtaq_Mattu is being interviewed Regarding Corona Virus \nOn  Gawahi Channel(Christia…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'PPP', 'indices': [34, 38]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'nafees_mall',
#       'name': 'Nafees Mall',
#       'id': 1158292448235458560,
#       'id_str': '1158292448235458560',
#       'indices': [3, 15]},
#      {'screen_name': 'Mushtaq_Mattu',
#       'name': 'Mushtaq Matto',
#       'id': 1225484525200867329,
#       'id_str': '1225484525200867329',
#       'indices': [52, 66]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 723762263686012928,
#     'id_str': '723762263686012928',
#     'name': 'خليل احمد عبدالعزيز',
#     'screen_name': 'KHALIL_DASRAT12',
#     'location': 'jeddah saudi arabia',
#     'description': 'Secretary General PPP #Jeddah\n#Ex_President #PYO Taif\n(saudi Arab)\nworker of PPP.... Jiyala Bhuttoism',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3590,
#     'friends_count': 432,
#     'listed_count': 2,
#     'created_at': 'Sat Apr 23 06:35:45 +0000 2016',
#     'favourites_count': 349013,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 155496,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1206611901209350144/DeoV1Nh3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1206611901209350144/DeoV1Nh3_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723762263686012928/1483383902',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 17:36:43 +0000 2020',
#     'id': 1261712194263228416,
#     'id_str': '1261712194263228416',
#     'text': 'Former President #PPP Minority Khi @Mushtaq_Mattu is being interviewed Regarding Corona Virus \nOn  Gawahi Channel(C… https://t.co/grblnQinBm',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'PPP', 'indices': [17, 21]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Mushtaq_Mattu',
#        'name': 'Mushtaq Matto',
#        'id': 1225484525200867329,
#        'id_str': '1225484525200867329',
#        'indices': [35, 49]}],
#      'urls': [{'url': 'https://t.co/grblnQinBm',
#        'expanded_url': 'https://twitter.com/i/web/status/1261712194263228416',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1158292448235458560,
#      'id_str': '1158292448235458560',
#      'name': 'Nafees Mall',
#      'screen_name': 'nafees_mall',
#      'location': 'Punjab, Pakistan',
#      'description': 'A Law Student, Social Activist, #PPP worker, Born For #PPP, Work For My Honorable Chairman @BBhuttoZardari , Bibi @BakhtawarBZ &  Bibi @AseefaBZ, @PPPPunjab_SM',
#      'url': 'https://t.co/vydxfi9Nc6',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/vydxfi9Nc6',
#          'expanded_url': 'http://www.ppp.org',
#          'display_url': 'ppp.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2143,
#      'friends_count': 882,
#      'listed_count': 2,
#      'created_at': 'Mon Aug 05 08:23:34 +0000 2019',
#      'favourites_count': 18416,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 11515,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261293118965665793/4IfL-k_H_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261293118965665793/4IfL-k_H_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1158292448235458560/1586622778',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:33 +0000 2020',
#    'id': 1261726749198614532,
#    'id_str': '1261726749198614532',
#    'text': 'Mano eu acabei de descobrir q minha avó teve corona vírus, ela ficou em isolamento, mas ela usou máscara em casa, p… https://t.co/agxEHGL4UN',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/agxEHGL4UN',
#       'expanded_url': 'https://twitter.com/i/web/status/1261726749198614532',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1082118305844989953,
#     'id_str': '1082118305844989953',
#     'name': 'kayky, k, a, y, k, y',
#     'screen_name': 'kmcpontes',
#     'location': 'Marte ',
#     'description': 'eu so queria ser rico😞✌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 120,
#     'friends_count': 587,
#     'listed_count': 0,
#     'created_at': 'Mon Jan 07 03:34:43 +0000 2019',
#     'favourites_count': 3634,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1077,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1205673207090614274/-Yh3clSf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1205673207090614274/-Yh3clSf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1082118305844989953/1573394081',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 16 18:34:32 +0000 2020',
#    'id': 1261726743867478017,
#    'id_str': '1261726743867478017',
#    'text': '@CMOTamilNadu sir tayavu cencu 10th exam ippotaikku niruttunka corona virus romba spread akuthu so please once agai… https://t.co/Yur1wgmjRw',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CMOTamilNadu',
#       'name': 'Edappadi K Palaniswami',
#       'id': 844890761409777664,
#       'id_str': '844890761409777664',
#       'indices': [0, 13]}],
#     'urls': [{'url': 'https://t.co/Yur1wgmjRw',
#       'expanded_url': 'https://twitter.com/i/web/status/1261726743867478017',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 844890761409777664,
#    'in_reply_to_user_id_str': '844890761409777664',
#    'in_reply_to_screen_name': 'CMOTamilNadu',
#    'user': {'id': 1101128156147142662,
#     'id_str': '1101128156147142662',
#     'name': 'Karthikaramar',
#     'screen_name': 'karthikaramar',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 151,
#     'listed_count': 0,
#     'created_at': 'Thu Feb 28 14:33:05 +0000 2019',
#     'favourites_count': 99,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 130,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1179946552241967104/sw8-bFGy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179946552241967104/sw8-bFGy_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.079,
#   'max_id': 1261726801186955264,
#   'max_id_str': '1261726801186955264',
#   'next_results': '?max_id=1261726743867478016&q=corona%20virus&include_entities=1',
#   'query': 'corona+virus',
#   'refresh_url': '?since_id=1261726801186955264&q=corona%20virus&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
t.search.tweets(q="china")
# Out:
# {'statuses': [{'created_at': 'Sat May 16 18:34:50 +0000 2020',
#    'id': 1261726819327397889,
#    'id_str': '1261726819327397889',
#    'text': '@proceso Solo que en China empezó mucho antes que en México!',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'proceso',
#       'name': 'Proceso',
#       'id': 41156599,
#       'id_str': '41156599',
#       'indices': [0, 8]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1261491607838343168,
#    'in_reply_to_status_id_str': '1261491607838343168',
#    'in_reply_to_user_id': 41156599,
#    'in_reply_to_user_id_str': '41156599',
#    'in_reply_to_screen_name': 'proceso',
#    'user': {'id': 131928432,
#     'id_str': '131928432',
#     'name': 'pablo flores garcia',
#     'screen_name': 'elpagos',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 16,
#     'listed_count': 0,
#     'created_at': 'Sun Apr 11 19:41:09 +0000 2010',
#     'favourites_count': 50,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 90,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/800710819109539841/iormDpP7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/800710819109539841/iormDpP7_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   {'created_at': 'Sat May 16 18:34:50 +0000 2020',
#    'id': 1261726819054694403,
#    'id_str': '1261726819054694403',
#    'text': 'RT @DimensionC: @newsbusters @ComfortablySmug They should also have a Chinese Commnist Party apparatchik on every week to fact check the cl…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DimensionC',
#       'name': 'L. John Whorfin ⭐️⭐️⭐️ 🦅🇺🇸',
#       'id': 262057350,
#       'id_str': '262057350',
#       'indices': [3, 14]},
#      {'screen_name': 'newsbusters',
#       'name': 'NewsBusters',
#       'id': 45190383,
#       'id_str': '45190383',
#       'indices': [16, 28]},
#      {'screen_name': 'ComfortablySmug',
#       'name': 'Comfortably Smug',
#       'id': 17060573,
#       'id_str': '17060573',
#       'indices': [29, 45]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 205971568,
#     'id_str': '205971568',
#     'name': 'Liz V',
#     'screen_name': 'ShoreEJV',
#     'location': 'Near the beach, New Jersey',
#     'description': 'Retired, worked in NYC for 35+ years and live on the Jersey Shore. Enjoy photography and watching the NJ Devils. Love gardening & growing yummy Jersey tomatoes.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2409,
#     'friends_count': 2346,
#     'listed_count': 50,
#     'created_at': 'Fri Oct 22 00:41:36 +0000 2010',
#     'favourites_count': 2851,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 130801,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2714238519/154dd660702b433650766510e8f2cc86_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2714238519/154dd660702b433650766510e8f2cc86_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/205971568/1419625038',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 15:46:33 +0000 2020',
#     'id': 1261684472329592833,
#     'id_str': '1261684472329592833',
#     'text': '@newsbusters @ComfortablySmug They should also have a Chinese Commnist Party apparatchik on every week to fact chec… https://t.co/MANvqHijOc',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'newsbusters',
#        'name': 'NewsBusters',
#        'id': 45190383,
#        'id_str': '45190383',
#        'indices': [0, 12]},
#       {'screen_name': 'ComfortablySmug',
#        'name': 'Comfortably Smug',
#        'id': 17060573,
#        'id_str': '17060573',
#        'indices': [13, 29]}],
#      'urls': [{'url': 'https://t.co/MANvqHijOc',
#        'expanded_url': 'https://twitter.com/i/web/status/1261684472329592833',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': 1261676325523390466,
#     'in_reply_to_status_id_str': '1261676325523390466',
#     'in_reply_to_user_id': 45190383,
#     'in_reply_to_user_id_str': '45190383',
#     'in_reply_to_screen_name': 'newsbusters',
#     'user': {'id': 262057350,
#      'id_str': '262057350',
#      'name': 'L. John Whorfin ⭐️⭐️⭐️ 🦅🇺🇸',
#      'screen_name': 'DimensionC',
#      'location': 'Planet Ten',
#      'description': 'May I pass along my congratulations for your great interdimensional breakthrough. I am sure, in the miserable annals of the Earth, you will be duly enshrined.',
#      'url': 'https://t.co/dW0eHCbuAd',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/dW0eHCbuAd',
#          'expanded_url': 'https://youtu.be/pd56CIFSMI4',
#          'display_url': 'youtu.be/pd56CIFSMI4',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 261,
#      'friends_count': 677,
#      'listed_count': 0,
#      'created_at': 'Mon Mar 07 07:41:31 +0000 2011',
#      'favourites_count': 24504,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 15665,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1260808512612909057/5d-sG5N1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260808512612909057/5d-sG5N1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/262057350/1582709978',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726818371067906,
#    'id_str': '1261726818371067906',
#    'text': '@abey_saaayli or blame it on China.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'abey_saaayli',
#       'name': '🌸🌸🌸🥀',
#       'id': 1131083735921823744,
#       'id_str': '1131083735921823744',
#       'indices': [0, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1261694782365106177,
#    'in_reply_to_status_id_str': '1261694782365106177',
#    'in_reply_to_user_id': 1131083735921823744,
#    'in_reply_to_user_id_str': '1131083735921823744',
#    'in_reply_to_screen_name': 'abey_saaayli',
#    'user': {'id': 102356650,
#     'id_str': '102356650',
#     'name': 'Dipen.Prajapati',
#     'screen_name': 'BeingDipen',
#     'location': 'Ahmedabad India ',
#     'description': 'busy figuring out so called life..!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 353,
#     'friends_count': 571,
#     'listed_count': 26,
#     'created_at': 'Wed Jan 06 12:28:42 +0000 2010',
#     'favourites_count': 38394,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 46244,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1229113603875393537/VGpeFlp2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229113603875393537/VGpeFlp2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/102356650/1539014882',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726817486069760,
#    'id_str': '1261726817486069760',
#    'text': 'RT @rottenbanana101: Next time you buy a made in China product remember this photo and pray they never make it here . Imagine how painful t…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rottenbanana101',
#       'name': 'Orange Peel',
#       'id': 1182796388792459264,
#       'id_str': '1182796388792459264',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 733461970406412289,
#     'id_str': '733461970406412289',
#     'name': 'AmericaFirst2020',
#     'screen_name': 'Darren_D76',
#     'location': '',
#     'description': 'Support the betterment of the USA & Life for ALL its citizens. Proudly support our Constitution.  Vote out corruption, deceit & fraud.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 641,
#     'friends_count': 1241,
#     'listed_count': 0,
#     'created_at': 'Fri May 20 00:58:55 +0000 2016',
#     'favourites_count': 73629,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 30738,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1013746162812235776/C1e-RAhP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013746162812235776/C1e-RAhP_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 17:27:01 +0000 2020',
#     'id': 1261709755883622400,
#     'id_str': '1261709755883622400',
#     'text': 'Next time you buy a made in China product remember this photo and pray they never make it here . Imagine how painfu… https://t.co/JU2HU3Hb1h',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/JU2HU3Hb1h',
#        'expanded_url': 'https://twitter.com/i/web/status/1261709755883622400',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1182796388792459264,
#      'id_str': '1182796388792459264',
#      'name': 'Orange Peel',
#      'screen_name': 'rottenbanana101',
#      'location': '',
#      'description': 'Ban communism, Socialism and Totalitarianism everywhere. And Winnie the Pooh. Pro civil society. Law and order. Chinese Fentanyl kills. MAGA.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6207,
#      'friends_count': 6811,
#      'listed_count': 3,
#      'created_at': 'Fri Oct 11 23:13:47 +0000 2019',
#      'favourites_count': 11795,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 31954,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1182798927063605248/TRlQmpDp_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1182798927063605248/TRlQmpDp_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1182796388792459264/1570836215',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1171157293552979970,
#     'quoted_status_id_str': '1171157293552979970',
#     'quoted_status': {'created_at': 'Mon Sep 09 20:23:52 +0000 2019',
#      'id': 1171157293552979970,
#      'id_str': '1171157293552979970',
#      'text': 'CCP IS EVIL, STOP APPEASING RED CHINA! \n\nThis Chinese journalist was released free of charge after 6 years in jail.… https://t.co/E0DEhpoO56',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/E0DEhpoO56',
#         'expanded_url': 'https://twitter.com/i/web/status/1171157293552979970',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 915528910049222657,
#       'id_str': '915528910049222657',
#       'name': 'Boycott China Hegemony',
#       'screen_name': 'BoycottHegemony',
#       'location': 'World',
#       'description': 'I keep track of China Hegemony around the world. #FreeChina #AntiCCP #AntiCommunism #ChinaHegemony #BoycottHegemony #HumanRights Cover @TheEconomist',
#       'url': 'https://t.co/NkkIjFgjYl',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/NkkIjFgjYl',
#           'expanded_url': 'http://bit.ly/AsianAllianceAgainstChiNazi',
#           'display_url': 'bit.ly/AsianAllianceA…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 10679,
#       'friends_count': 5712,
#       'listed_count': 85,
#       'created_at': 'Wed Oct 04 10:47:56 +0000 2017',
#       'favourites_count': 67369,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 70353,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1066387963234312192/mEGfg6No_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1066387963234312192/mEGfg6No_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/915528910049222657/1580402783',
#       'profile_link_color': '1B95E0',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 1924,
#      'favorite_count': 2505,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 63,
#     'favorite_count': 59,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1171157293552979970,
#    'quoted_status_id_str': '1171157293552979970',
#    'retweet_count': 63,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726817175719936,
#    'id_str': '1261726817175719936',
#    'text': 'RT @JuliaDavisNews: Russian hopes and dreams: “The United States may give Ukraine to Russia in an exchange for an alliance against China.”…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JuliaDavisNews',
#       'name': 'Julia Davis',
#       'id': 105327432,
#       'id_str': '105327432',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 597512137,
#     'id_str': '597512137',
#     'name': 'Lori ♌️',
#     'screen_name': 'irishchick814',
#     'location': 'Philly Burbs',
#     'description': 'NOT liberal or conservative, just a pissed off American who spends way too much time on Twitter because of psycho POTUS🤪 #Biden2020 🇺🇸 NOT A BOT‼️',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4424,
#     'friends_count': 4834,
#     'listed_count': 17,
#     'created_at': 'Sat Jun 02 15:39:26 +0000 2012',
#     'favourites_count': 380822,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 24551,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '009AB9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261692834115174404/2iHRbwEc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261692834115174404/2iHRbwEc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/597512137/1576876788',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 16:41:55 +0000 2020',
#     'id': 1261698404020883456,
#     'id_str': '1261698404020883456',
#     'text': 'Russian hopes and dreams: “The United States may give Ukraine to Russia in an exchange for an alliance against Chin… https://t.co/YymtCkIITS',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/YymtCkIITS',
#        'expanded_url': 'https://twitter.com/i/web/status/1261698404020883456',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 105327432,
#      'id_str': '105327432',
#      'name': 'Julia Davis',
#      'screen_name': 'JuliaDavisNews',
#      'location': 'United States',
#      'description': 'Columnist @TheDailyBeast, Russian Media Analyst, featured expert @AtlanticCouncil @DisinfoPortal, member @TheEmmys, @SAGAFTRA, @FLEOAORG, @WomenInFilm',
#      'url': 'https://t.co/q6VafM7SCB',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/q6VafM7SCB',
#          'expanded_url': 'https://www.thedailybeast.com/author/julia-davis',
#          'display_url': 'thedailybeast.com/author/julia-d…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 159781,
#      'friends_count': 1450,
#      'listed_count': 1889,
#      'created_at': 'Sat Jan 16 01:34:50 +0000 2010',
#      'favourites_count': 106456,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 82909,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F71B1B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1173814137878646784/Gu54B4pc_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1173814137878646784/Gu54B4pc_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/105327432/1515339180',
#      'profile_link_color': '395A61',
#      'profile_sidebar_border_color': '1AFF05',
#      'profile_sidebar_fill_color': 'FFD9F7',
#      'profile_text_color': '0E0F0F',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1260556712660131842,
#     'quoted_status_id_str': '1260556712660131842',
#     'quoted_status': {'created_at': 'Wed May 13 13:05:14 +0000 2020',
#      'id': 1260556712660131842,
#      'id_str': '1260556712660131842',
#      'text': 'Trump’s Confident He’s Wrapping Up the ‘Russia Hoax,’ and Russia’s Confident He’s in Their Pocket.\n\nThe upending of… https://t.co/XVw5HNCLRu',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/XVw5HNCLRu',
#         'expanded_url': 'https://twitter.com/i/web/status/1260556712660131842',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 105327432,
#       'id_str': '105327432',
#       'name': 'Julia Davis',
#       'screen_name': 'JuliaDavisNews',
#       'location': 'United States',
#       'description': 'Columnist @TheDailyBeast, Russian Media Analyst, featured expert @AtlanticCouncil @DisinfoPortal, member @TheEmmys, @SAGAFTRA, @FLEOAORG, @WomenInFilm',
#       'url': 'https://t.co/q6VafM7SCB',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/q6VafM7SCB',
#           'expanded_url': 'https://www.thedailybeast.com/author/julia-davis',
#           'display_url': 'thedailybeast.com/author/julia-d…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 159781,
#       'friends_count': 1450,
#       'listed_count': 1889,
#       'created_at': 'Sat Jan 16 01:34:50 +0000 2010',
#       'favourites_count': 106456,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 82909,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F71B1B',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1173814137878646784/Gu54B4pc_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1173814137878646784/Gu54B4pc_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/105327432/1515339180',
#       'profile_link_color': '395A61',
#       'profile_sidebar_border_color': '1AFF05',
#       'profile_sidebar_fill_color': 'FFD9F7',
#       'profile_text_color': '0E0F0F',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 642,
#      'favorite_count': 872,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 322,
#     'favorite_count': 389,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1260556712660131842,
#    'quoted_status_id_str': '1260556712660131842',
#    'retweet_count': 322,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726816399736835,
#    'id_str': '1261726816399736835',
#    'text': "RT @ChinaDaily: #GlamorChina Aerial photo shows villagers transplanting rice seedlings on the terraced fields in Xuan'en county, Central Ch…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'GlamorChina', 'indices': [16, 28]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ChinaDaily',
#       'name': 'China Daily',
#       'id': 87775422,
#       'id_str': '87775422',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260200587402063872,
#     'id_str': '1260200587402063872',
#     'name': 'MASTER OF THE GALAXY',
#     'screen_name': 'THEREALDENAR',
#     'location': 'Miami, FL',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 23,
#     'friends_count': 532,
#     'listed_count': 0,
#     'created_at': 'Tue May 12 13:30:25 +0000 2020',
#     'favourites_count': 10,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1160,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1260200819481358340/ys0uJfAi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260200819481358340/ys0uJfAi_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260200587402063872/1589292421',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 18:30:01 +0000 2020',
#     'id': 1261725607592779776,
#     'id_str': '1261725607592779776',
#     'text': "#GlamorChina Aerial photo shows villagers transplanting rice seedlings on the terraced fields in Xuan'en county, Ce… https://t.co/rhoZrYQB09",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'GlamorChina', 'indices': [0, 12]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/rhoZrYQB09',
#        'expanded_url': 'https://twitter.com/i/web/status/1261725607592779776',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.onesight.com/" rel="nofollow">ospublisher</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 87775422,
#      'id_str': '87775422',
#      'name': 'China Daily',
#      'screen_name': 'ChinaDaily',
#      'location': 'Beijing, China',
#      'description': 'Inspiring constructive dialogue between China and the US. Join the conversation!',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4372718,
#      'friends_count': 540,
#      'listed_count': 6359,
#      'created_at': 'Thu Nov 05 20:30:10 +0000 2009',
#      'favourites_count': 52,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 123385,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'EBEBEB',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1246468667396612096/qPFdslyM_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246468667396612096/qPFdslyM_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/87775422/1587882597',
#      'profile_link_color': '0E5CB5',
#      'profile_sidebar_border_color': 'DFDFDF',
#      'profile_sidebar_fill_color': 'F3F3F3',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 13,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726816294907905,
#    'id_str': '1261726816294907905',
#    'text': "@desertfox61I @narendramodi @DrSJaishankar @PMOIndia @MEAIndia Just hour's before, Russia has little rationale for… https://t.co/0zJxQjVlIE",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'desertfox61I',
#       'name': 'gab.ai/TheCol🇮🇳',
#       'id': 2578308889,
#       'id_str': '2578308889',
#       'indices': [0, 13]},
#      {'screen_name': 'narendramodi',
#       'name': 'Narendra Modi',
#       'id': 18839785,
#       'id_str': '18839785',
#       'indices': [14, 27]},
#      {'screen_name': 'DrSJaishankar',
#       'name': 'Dr. S. Jaishankar',
#       'id': 859363899291742210,
#       'id_str': '859363899291742210',
#       'indices': [28, 42]},
#      {'screen_name': 'PMOIndia',
#       'name': 'PMO India',
#       'id': 471741741,
#       'id_str': '471741741',
#       'indices': [43, 52]},
#      {'screen_name': 'MEAIndia',
#       'name': 'Anurag Srivastava',
#       'id': 441636351,
#       'id_str': '441636351',
#       'indices': [53, 62]}],
#     'urls': [{'url': 'https://t.co/0zJxQjVlIE',
#       'expanded_url': 'https://twitter.com/i/web/status/1261726816294907905',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1261713576542081024,
#    'in_reply_to_status_id_str': '1261713576542081024',
#    'in_reply_to_user_id': 2578308889,
#    'in_reply_to_user_id_str': '2578308889',
#    'in_reply_to_screen_name': 'desertfox61I',
#    'user': {'id': 3369674594,
#     'id_str': '3369674594',
#     'name': 'DharmvirJangra',
#     'screen_name': 'dharmvirjangra9',
#     'location': 'CKD, home bjp.org',
#     'description': 'State Member IT&SM @BJP4Haryana Prabhari Ch Dadri\nIdeology @narendramodi\nBlsdBy @BSKoshyari @nstomar\n@KailashOnline @Shehzad_Ind @RuchiraKamboj @nsitharamanoffc',
#     'url': 'https://t.co/0x9uza7Oo7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0x9uza7Oo7',
#         'expanded_url': 'https://www.facebook.com/dharmvir.baundwal',
#         'display_url': 'facebook.com/dharmvir.baund…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14232,
#     'friends_count': 9977,
#     'listed_count': 24,
#     'created_at': 'Fri Aug 28 10:46:55 +0000 2015',
#     'favourites_count': 162048,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 212239,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1258581478679605248/OjlEWGgj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1258581478679605248/OjlEWGgj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3369674594/1580534855',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726815346806784,
#    'id_str': '1261726815346806784',
#    'text': "RT @bopinion: China's Communist Party leaders appear to overestimate their ability to rule Hong Kong by force, @ClaraDFMarques writes https…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'bopinion',
#       'name': 'Bloomberg Opinion',
#       'id': 227682918,
#       'id_str': '227682918',
#       'indices': [3, 12]},
#      {'screen_name': 'ClaraDFMarques',
#       'name': 'ClaraFerreiraMarques',
#       'id': 108557666,
#       'id_str': '108557666',
#       'indices': [111, 126]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1206612751918878721,
#     'id_str': '1206612751918878721',
#     'name': 'John',
#     'screen_name': 'John88217885',
#     'location': '',
#     'description': 'Help Hong Kong\n#FollowBackHongKong\n#HongKongProtest  #StandWithHongKong #FreeHongKong #HongKong\n#科勞手足 \n#互科手足\n#HKPoliceTerrorists\n#IMNOTCHINA\n#CHINESEVIRUS',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21,
#     'friends_count': 31,
#     'listed_count': 0,
#     'created_at': 'Mon Dec 16 16:31:41 +0000 2019',
#     'favourites_count': 7436,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7599,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 02:39:37 +0000 2020',
#     'id': 1261486430825652226,
#     'id_str': '1261486430825652226',
#     'text': "China's Communist Party leaders appear to overestimate their ability to rule Hong Kong by force, @ClaraDFMarques wr… https://t.co/iXc5WXRodc",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ClaraDFMarques',
#        'name': 'ClaraFerreiraMarques',
#        'id': 108557666,
#        'id_str': '108557666',
#        'indices': [97, 112]}],
#      'urls': [{'url': 'https://t.co/iXc5WXRodc',
#        'expanded_url': 'https://twitter.com/i/web/status/1261486430825652226',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 227682918,
#      'id_str': '227682918',
#      'name': 'Bloomberg Opinion',
#      'screen_name': 'bopinion',
#      'location': 'Worldwide',
#      'description': 'Opinions on business, economics and much more from the editors and columnists at Bloomberg Opinion.',
#      'url': 'https://t.co/eY4AY2rZeQ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eY4AY2rZeQ',
#          'expanded_url': 'http://bloomberg.com/opinion',
#          'display_url': 'bloomberg.com/opinion',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 263762,
#      'friends_count': 464,
#      'listed_count': 4470,
#      'created_at': 'Fri Dec 17 14:20:58 +0000 2010',
#      'favourites_count': 8070,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 166194,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/991778099397320705/6LWXR6MS_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/991778099397320705/6LWXR6MS_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/227682918/1525292911',
#      'profile_link_color': '0072FF',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1032,
#     'favorite_count': 1077,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1032,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:49 +0000 2020',
#    'id': 1261726814831067137,
#    'id_str': '1261726814831067137',
#    'text': 'RT @Kaalateetham: Dear Rahul Kanwal\n\nDo you actually believe in the numbers published by China?\n\nIf No: you would be considered dumb to twe…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Kaalateetham',
#       'name': 'ಶರಣ Dr Jagadish J Hiremath',
#       'id': 68636682,
#       'id_str': '68636682',
# ...
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 295,
#     'favorite_count': 294,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 295,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:48 +0000 2020',
#    'id': 1261726810619777025,
#    'id_str': '1261726810619777025',
#    'text': 'RT @ericgarland: Hey, if Obama left us empty shelves where did all those masks and ventilators Mike Pompeo sent to China come from?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ericgarland',
#       'name': 'Eric Garland',
#       'id': 16912124,
#       'id_str': '16912124',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2815269150,
#     'id_str': '2815269150',
#     'name': 'Lauren Milicov',
#     'screen_name': 'laurmili1',
#     'location': 'California, USA',
#     'description': "🎵Love is my religion.🎵 @ZiggyMarley. And blue is my favorite color. #ThankYouFrontliners #RidinWithBiden \nLet's go.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 483,
#     'friends_count': 3782,
#     'listed_count': 3,
#     'created_at': 'Wed Sep 17 17:22:57 +0000 2014',
#     'favourites_count': 7319,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 53005,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/738811974599856128/FJy5Umla_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/738811974599856128/FJy5Umla_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat May 16 17:51:38 +0000 2020',
#     'id': 1261715950774206465,
#     'id_str': '1261715950774206465',
#     'text': 'Hey, if Obama left us empty shelves where did all those masks and ventilators Mike Pompeo sent to China come from?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 16912124,
#      'id_str': '16912124',
#      'name': 'Eric Garland',
#      'screen_name': 'ericgarland',
#      'location': 'USA',
#      'description': 'Strategic analyst. Here for the Endgame and the next chapter beyond.',
#      'url': 'https://t.co/JvuqJnsIdV',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JvuqJnsIdV',
#          'expanded_url': 'https://premosocial.com/gametheorytoday',
#          'display_url': 'premosocial.com/gametheorytoday',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 225343,
#      'friends_count': 1723,
#      'listed_count': 2621,
#      'created_at': 'Wed Oct 22 20:19:50 +0000 2008',
#      'favourites_count': 35543,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 97358,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/990905364588544006/bV8OemO9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/990905364588544006/bV8OemO9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16912124/1587413001',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 665,
#     'favorite_count': 1769,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 665,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat May 16 18:34:47 +0000 2020',
#    'id': 1261726810213146625,
#    'id_str': '1261726810213146625',
#    'text': 'RT @SheepKnowMore: Why would the most senior Democrat in congress, Nancy Pelosi, block an investigation into the origin/source of #Covid19…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Covid19', 'indices': [130, 138]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SheepKnowMore',
#       'name': 'Define Projection',
#       'id': 1250477466617090048,
#       'id_str': '1250477466617090048',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 812843862117023744,
#     'id_str': '812843862117023744',
#     'name': 'Brenda Ortego',
#     'screen_name': 'brendavortego',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 52,
#     'friends_count': 47,
#     'listed_count': 0,
#     'created_at': 'Sun Dec 25 02:14:13 +0000 2016',
#     'favourites_count': 25256,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12854,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon May 04 17:38:42 +0000 2020',
#     'id': 1257364039648399366,
#     'id_str': '1257364039648399366',
#     'text': 'Why would the most senior Democrat in congress, Nancy Pelosi, block an investigation into the origin/source of… https://t.co/wCrpIUOKz0',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/wCrpIUOKz0',
#        'expanded_url': 'https://twitter.com/i/web/status/1257364039648399366',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1250477466617090048,
#      'id_str': '1250477466617090048',
#      'name': 'Define Projection',
#      'screen_name': 'SheepKnowMore',
#      'location': '',
#      'description': "There's a plan. I trust it. So should you.",
#      'url': 'https://t.co/fcXWWk5E2O',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/fcXWWk5E2O',
#          'expanded_url': 'https://youtu.be/KVeDKuHPDK8',
#          'display_url': 'youtu.be/KVeDKuHPDK8',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 46101,
#      'friends_count': 776,
#      'listed_count': 161,
#      'created_at': 'Wed Apr 15 17:34:29 +0000 2020',
#      'favourites_count': 917,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 723,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1250992390053249025/21m9306K_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250992390053249025/21m9306K_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250477466617090048/1589043333',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1257345456356708353,
#     'quoted_status_id_str': '1257345456356708353',
#     'quoted_status': {'created_at': 'Mon May 04 16:24:51 +0000 2020',
#      'id': 1257345456356708353,
#      'id_str': '1257345456356708353',
#      'text': 'Exclusive– Congressman: Nancy Pelosi Blocking Investigation into Chinese Coronavirus Origins, Tax Money to Wuhan La… https://t.co/mss26fdk10',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/mss26fdk10',
#         'expanded_url': 'https://twitter.com/i/web/status/1257345456356708353',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 29082715,
#       'id_str': '29082715',
#       'name': 'John Lichtenberger',
#       'screen_name': 'AdvertisingLaw',
#       'location': 'Roxbury, NJ',
#       'description': '#Christian | #lawyer (Ret.) Tweets on Christianity, law, politics, conservativism, tech, social media. Author/publisher (Ret.) advertising law, #FTC. #MAGA #KAG',
#       'url': 'http://t.co/hXKXiDJHvP',
#       'entities': {'url': {'urls': [{'url': 'http://t.co/hXKXiDJHvP',
#           'expanded_url': 'http://www.lawpublish.com/',
#           'display_url': 'lawpublish.com',
#           'indices': [0, 22]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 38298,
#       'friends_count': 38658,
#       'listed_count': 1555,
#       'created_at': 'Sun Apr 05 22:31:06 +0000 2009',
#       'favourites_count': 26147,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 127062,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'C0DEED',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/217569881/ACS-LO-FF_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/217569881/ACS-LO-FF_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29082715/1404271641',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 146,
#      'favorite_count': 123,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 2577,
#     'favorite_count': 3120,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1257345456356708353,
#    'quoted_status_id_str': '1257345456356708353',
#    'retweet_count': 2577,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.131,
#   'max_id': 1261726819327397889,
#   'max_id_str': '1261726819327397889',
#   'next_results': '?max_id=1261726810213146624&q=china&include_entities=1',
#   'query': 'china',
#   'refresh_url': '?since_id=1261726819327397889&q=china&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
