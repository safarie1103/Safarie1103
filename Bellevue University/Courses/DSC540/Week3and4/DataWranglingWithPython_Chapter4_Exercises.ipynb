# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xlrd

# %%
df = pd.read_excel("Sample - Superstore.xls")
print(df.dtypes)
print(df.describe())
print(df.columns)
df.head(10)
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7       90032    West  TEC-PH-10002275       Technology       Phones
# 8       90032    West  OFF-BI-10003910  Office Supplies      Binders
# 9       90032    West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700
#
# [10 rows x 21 columns]

# %%
df.drop('Row ID',axis=1,inplace=True)

# %%
df.shape
# Out:
# (9994, 20)

# %%
df_subset = df.loc[[i for i in range(5,10)],['Customer ID','Customer Name','City','Postal Code','Sales']]
df_subset
# Out:
#   Customer ID    Customer Name         City  Postal Code    Sales
# 5    BH-11710  Brosina Hoffman  Los Angeles        90032   48.860
# 6    BH-11710  Brosina Hoffman  Los Angeles        90032    7.280
# 7    BH-11710  Brosina Hoffman  Los Angeles        90032  907.152
# 8    BH-11710  Brosina Hoffman  Los Angeles        90032   18.504
# 9    BH-11710  Brosina Hoffman  Los Angeles        90032  114.900

# %%
df_subset = df.loc[[i for i in range(100,200)],['Sales','Profit']]
df_subset.describe()
# Out:
#              Sales       Profit
# count   100.000000   100.000000
# mean    262.957220     0.347574
# std     858.983762   170.744869
# min       1.788000 -1359.992000
# 25%      21.327000     1.635900
# 50%      66.960000     9.653600
# 75%     177.095000    23.458800
# max    8159.952000   585.552000

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
for state in df['State'].unique():
    if(state == 'Texas'):
        print(state)
# Out:
# Texas

# %%
df['State'].nunique()
# Out:
# 49

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# Conditional Selection and Boolean Filtering

# %%
df_subset = df.loc[[i for i in range(100)],['Ship Mode','State','Sales']]
df_subset
# Out:
#          Ship Mode       State     Sales
# 0     Second Class    Kentucky  261.9600
# 1     Second Class    Kentucky  731.9400
# 2     Second Class  California   14.6200
# 3   Standard Class     Florida  957.5775
# 4   Standard Class     Florida   22.3680
# ..             ...         ...       ...
# 95  Standard Class      Oregon    5.6820
# 96    Second Class    New York   96.5300
# 97     First Class  California   51.3120
# 98  Standard Class   Minnesota   77.8800
# 99  Standard Class    Illinois   64.6240
#
# [100 rows x 3 columns]

# %%
df_subset['Sales']>100 # Returns Boolean DataFrame
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Sales, Length: 100, dtype: bool

# %%
df_subset[df_subset['Sales']>100]
# Out:
#          Ship Mode           State      Sales
# 0     Second Class        Kentucky   261.9600
# 1     Second Class        Kentucky   731.9400
# 3   Standard Class         Florida   957.5775
# 7   Standard Class      California   907.1520
# 9   Standard Class      California   114.9000
# 10  Standard Class      California  1706.1840
# 11  Standard Class      California   911.4240
# 13  Standard Class      Washington   407.9760
# 16  Standard Class       Wisconsin   665.8800
# 19    Second Class      California   213.4800
# 24  Standard Class            Utah  1044.6300
# 27  Standard Class    Pennsylvania  3083.4300
# 29  Standard Class    Pennsylvania   124.2000
# 35     First Class           Texas  1097.5440
# 36     First Class           Texas   190.9200
# 37  Standard Class           Texas   113.3280
# 38  Standard Class           Texas   532.3992
# 39  Standard Class           Texas   212.0580
# 40  Standard Class           Texas   371.1680
# 41  Standard Class        Illinois   147.1680
# 46    Second Class        Michigan   211.9600
# 54  Standard Class        New York  1029.9500
# 55     First Class        New York   208.5600
# 57     First Class        New York   319.4100
# 64  Standard Class      California   146.7300
# 66  Standard Class        Illinois   213.1150
# 67  Standard Class         Arizona  1113.0240
# 68  Standard Class         Arizona   167.9680
# 72  Standard Class       Tennessee   831.9360
# 79     First Class         Alabama   208.1600
# 83  Standard Class  North Carolina   200.9840
# 84     First Class        Illinois   230.3760
# 85    Second Class  South Carolina   301.9600
# 88    Second Class           Texas   158.3680

# %%
df_subset[(df_subset['State'] != 'Colorado') & (df_subset['Sales'] > 100)]
# Out:
#          Ship Mode           State      Sales
# 0     Second Class        Kentucky   261.9600
# 1     Second Class        Kentucky   731.9400
# 3   Standard Class         Florida   957.5775
# 7   Standard Class      California   907.1520
# 9   Standard Class      California   114.9000
# 10  Standard Class      California  1706.1840
# 11  Standard Class      California   911.4240
# 13  Standard Class      Washington   407.9760
# 16  Standard Class       Wisconsin   665.8800
# 19    Second Class      California   213.4800
# 24  Standard Class            Utah  1044.6300
# 27  Standard Class    Pennsylvania  3083.4300
# 29  Standard Class    Pennsylvania   124.2000
# 35     First Class           Texas  1097.5440
# 36     First Class           Texas   190.9200
# 37  Standard Class           Texas   113.3280
# 38  Standard Class           Texas   532.3992
# 39  Standard Class           Texas   212.0580
# 40  Standard Class           Texas   371.1680
# 41  Standard Class        Illinois   147.1680
# 46    Second Class        Michigan   211.9600
# 54  Standard Class        New York  1029.9500
# 55     First Class        New York   208.5600
# 57     First Class        New York   319.4100
# 64  Standard Class      California   146.7300
# 66  Standard Class        Illinois   213.1150
# 67  Standard Class         Arizona  1113.0240
# 68  Standard Class         Arizona   167.9680
# 72  Standard Class       Tennessee   831.9360
# 79     First Class         Alabama   208.1600
# 83  Standard Class  North Carolina   200.9840
# 84     First Class        Illinois   230.3760
# 85    Second Class  South Carolina   301.9600
# 88    Second Class           Texas   158.3680

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E'] 
column_headings = ['Age', 'Height', 'Weight']

# %%
df1 = pd.DataFrame(data=matrix_data,index = row_labels, columns = column_headings)
print('\nThe dataframe\n','-'*25,sep="-")
print(df1)
# Out:
# The dataframe
# --------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
print('\nAfter Resetting Index\n','-'*25,sep="-")
print(df1.reset_index())
# Out:
# After Resetting Index
# --------------------------
#   index  Age  Height  Weight
# 0     A   22      66     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152

# %%
print('\nAfter Resetting Index with DROP option=True\n','-'*25,sep="-")
print(df1.reset_index(drop=True))
# Out:
# After Resetting Index with DROP option=True
# --------------------------
#    Age  Height  Weight
# 0   22      66     140
# 1   42      70     148
# 2   30      62     125
# 3   35      68     160
# 4   25      62     152

# %%
print("\nAdding new column 'Profession'\n",'-'*25,sep="-")
df1['Profession'] = 'Student Teacher Engineer Doctor Nurse'.split()
print(df1)
# Out:
# Adding new column 'Profession'
# --------------------------
#    Age  Height  Weight Profession
# A   22      66     140    Student
# B   42      70     148    Teacher
# C   30      62     125   Engineer
# D   35      68     160     Doctor
# E   25      62     152      Nurse

# %%
print("\nSetting column 'Profession' as index\n",'-'*25,sep="-")
print(df1.set_index('Profession'))
# Out:
# Setting column 'Profession' as index
# --------------------------
#             Age  Height  Weight
# Profession
# Student      22      66     140
# Teacher      42      70     148
# Engineer     30      62     125
# Doctor       35      68     160
# Nurse        25      62     152

# %%
df_subset = df.loc[[i for i in range(10)],['Ship Mode','State','Sales']]

# %%
byState = df_subset.groupby('State')
byState

# %%
print("\nGrouping by 'State' column and listing mean sales\n",'-'*50, sep='') 
print(byState.mean())
# Out:
# Grouping by 'State' column and listing mean sales
# --------------------------------------------------
#                  Sales
# State
# California  185.219333
# Florida     489.972750
# Kentucky    496.950000

# %%
print("\nGrouping by 'State' column and listing total sum of sales\n",'-'*50, sep='') 
print(byState.sum())
# Out:
# Grouping by 'State' column and listing total sum of sales
# --------------------------------------------------
#                 Sales
# State
# California  1111.3160
# Florida      979.9455
# Kentucky     993.9000

# %%
pd.DataFrame(byState.describe().loc['California'])
# Out:
#              California
# Sales count    6.000000
#       mean   185.219333
#       std    355.889307
#       min      7.280000
#       25%     15.591000
#       50%     33.682000
#       75%     98.390000
#       max    907.152000

# %%
df_subset.groupby('Ship Mode').describe().loc[['Second Class','Standard Class']]
# Out:
#                Sales                                                           \
#                count        mean         std    min      25%     50%      75%
# Ship Mode
# Second Class     3.0  336.173333  364.373037  14.62  138.290  261.96  496.950
# Standard Class   7.0  296.663071  435.947552   7.28   20.436   48.86  511.026
#
#
#                      max
# Ship Mode
# Second Class    731.9400
# Standard Class  957.5775

# %%
byStateCity=df.groupby(['State','City']) 
byStateCity.describe()['Sales']
# Out:
#                       count         mean         std       min        25%  \
# State     City
# Alabama   Auburn        6.0   294.471667  361.914543     3.760     8.8050
#           Decatur      13.0   259.601538  385.660903    14.940    23.9200
#           Florence      5.0   399.470000  796.488863     4.980     7.2700
#           Hoover        4.0   131.462500  230.646923     7.160    13.3925
#           Huntsville   10.0   248.437000  419.576667     3.620    26.8700
# ...                     ...          ...         ...       ...        ...
# Wisconsin Superior      9.0   144.414444  213.394065     5.560    17.1200
#           Waukesha      1.0    54.500000         NaN    54.500    54.5000
#           Wausau        4.0    79.370000  111.450605    12.390    20.0325
#           West Allis    2.0   125.240000  165.067007     8.520    66.8800
# Wyoming   Cheyenne      1.0  1603.136000         NaN  1603.136  1603.1360
#
#                            50%        75%       max
# State     City
# Alabama   Auburn       182.030   456.4075   900.080
#           Decatur       44.950   239.9200  1215.920
#           Florence      12.480   152.7600  1819.860
#           Hoover        20.725   138.7950   477.240
#           Huntsville    81.920   171.8075  1319.960
# ...                        ...        ...       ...
# Wisconsin Superior      47.400   125.9900   629.100
#           Waukesha      54.500    54.5000    54.500
#           Wausau        29.605    88.9425   245.880
#           West Allis   125.240   183.6000   241.960
# Wyoming   Cheyenne    1603.136  1603.1360  1603.136
#
# [604 rows x 8 columns]

# %%
df_missing=pd.read_excel("Sample - Superstore.xls",sheet_name="Missing") 
df_missing
# Out:
#               Customer      Product     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman          NaN  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman       Phones   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       Phones       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli      Binders    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann      Binders    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann  Accessories    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman          NaN    77.880       2.0       0.0      NaN
# 8                  NaN  Accessories    13.980       2.0       0.0   6.1512
# 9         Kunst Miller      Binders    25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper   146.730       3.0       0.0  68.9631

# %%
df_missing.isnull()
# Out:
#     Customer  Product  Sales  Quantity  Discount  Profit
# 0      False     True  False     False     False   False
# 1      False    False  False     False     False   False
# 2      False    False  False     False     False   False
# 3      False    False   True     False     False   False
# 4      False    False  False     False     False   False
# 5      False    False  False      True     False   False
# 6      False    False  False     False     False   False
# 7      False     True  False     False     False    True
# 8       True    False  False     False     False   False
# 9      False    False  False     False     False   False
# 10     False    False  False     False     False   False

# %%
for column in df_missing.columns:
    miss = df_missing[column].isnull().sum()
    if miss > 0:
        print("{} has {} missing value(s)".format(column,miss))
    else:
        print("{} has NO missing value".format(column))
# Out:
# Customer has 1 missing value(s)
# Product has 2 missing value(s)
# Sales has 1 missing value(s)
# Quantity has 1 missing value(s)
# Discount has NO missing value
# Profit has 1 missing value(s)

# %%
df_missing.fillna('FILL')
# Out:
#               Customer      Product    Sales Quantity  Discount   Profit
# 0      Brosina Hoffman         FILL  1706.18        9       0.2  85.3092
# 1      Brosina Hoffman       Phones  911.424        4       0.2  68.3568
# 2   Zuschuss Donatelli          Art     8.56        2       0.0   2.4824
# 3   Zuschuss Donatelli       Phones     FILL        3       0.2   16.011
# 4   Zuschuss Donatelli      Binders    22.72        4       0.2    7.384
# 5        Eric Hoffmann      Binders   11.648     FILL       0.2   4.2224
# 6        Eric Hoffmann  Accessories    90.57        3       0.0  11.7741
# 7         Ruben Ausman         FILL    77.88        2       0.0     FILL
# 8                 FILL  Accessories    13.98        2       0.0   6.1512
# 9         Kunst Miller      Binders   25.824        6       0.2   9.3612
# 10        Kunst Miller        Paper   146.73        3       0.0  68.9631

# %%
df_missing[['Customer','Product']].fillna('FILL')
# Out:
#               Customer      Product
# 0      Brosina Hoffman         FILL
# 1      Brosina Hoffman       Phones
# 2   Zuschuss Donatelli          Art
# 3   Zuschuss Donatelli       Phones
# 4   Zuschuss Donatelli      Binders
# 5        Eric Hoffmann      Binders
# 6        Eric Hoffmann  Accessories
# 7         Ruben Ausman         FILL
# 8                 FILL  Accessories
# 9         Kunst Miller      Binders
# 10        Kunst Miller        Paper

# %%
df_missing
# Out:
#               Customer      Product     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman          NaN  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman       Phones   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       Phones       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli      Binders    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann      Binders    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann  Accessories    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman          NaN    77.880       2.0       0.0      NaN
# 8                  NaN  Accessories    13.980       2.0       0.0   6.1512
# 9         Kunst Miller      Binders    25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper   146.730       3.0       0.0  68.9631

# %%
df_missing['Sales'].fillna(method='ffill')
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3        8.560
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing['Sales'].fillna(method='bfill')
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3       22.720
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing['Sales'].fillna(df_missing.mean()['Sales'])
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3      301.552
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing.dropna(axis=0)
# Out:
#               Customer      Product    Sales  Quantity  Discount   Profit
# 1      Brosina Hoffman       Phones  911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art    8.560       2.0       0.0   2.4824
# 4   Zuschuss Donatelli      Binders   22.720       4.0       0.2   7.3840
# 6        Eric Hoffmann  Accessories   90.570       3.0       0.0  11.7741
# 9         Kunst Miller      Binders   25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper  146.730       3.0       0.0  68.9631

# %%
df_missing.dropna(axis=1)
# Out:
#     Discount
# 0        0.2
# 1        0.2
# 2        0.0
# 3        0.2
# 4        0.2
# 5        0.2
# 6        0.0
# 7        0.0
# 8        0.0
# 9        0.2
# 10       0.0

# %%
df_missing.dropna(axis=1,thresh=10) # Number of NaN'a
# Out:
#               Customer     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman    77.880       2.0       0.0      NaN
# 8                  NaN    13.980       2.0       0.0   6.1512
# 9         Kunst Miller    25.824       6.0       0.2   9.3612
# 10        Kunst Miller   146.730       3.0       0.0  68.9631

# %%
df_missing.dropna(axis=1,thresh=10,inplace=True) # make it permanent
df_missing
# Out:
#               Customer     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman    77.880       2.0       0.0      NaN
# 8                  NaN    13.980       2.0       0.0   6.1512
# 9         Kunst Miller    25.824       6.0       0.2   9.3612
# 10        Kunst Miller   146.730       3.0       0.0  68.9631

# %%
df_sample = df[['Customer Name','State','Sales','Profit']].sample(n=50).copy() 
df_sample['Sales'].iloc[5]=-1000.0 
df_sample['Sales'].iloc[15]=-500.0 
# To plot the boxplot, use the following code: 
df_sample.plot.box() 
plt.title("Boxplot of sales and profit", fontsize=15) 
plt.xticks(fontsize=15) 
plt.yticks(fontsize=15) 
plt.grid(True)
# Out:
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc540\week3and4\venv\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_1 = df[['Customer Name','State','Sales','Profit']].sample(n=4)
df_2 = df[['Customer Name','State','Sales','Profit']].sample(n=4)
df_3 = df[['Customer Name','State','Sales','Profit']].sample(n=4)

# %%
df_cat1 = pd.concat([df_1,df_2,df_3], axis = 0)
df_cat1
# Out:
#            Customer Name           State    Sales    Profit
# 2954        Eugene Moren         Arizona  671.984   50.3988
# 6246    Katrina Bavinger      Washington   13.980    6.0114
# 1934    Lindsay Williams      California  244.550  114.9385
# 1488    Corinna Mitchell      California   42.600   16.6140
# 684       Grant Thornton  North Carolina  167.440   14.6510
# 6058       Kristina Nunn        New York   36.400   17.4720
# 7730   Tamara Willingham      Washington  291.136  -25.4744
# 2806  Michelle Huthwaite      Washington    9.420    0.4710
# 3496     Cathy Armstrong      California  513.024   12.8256
# 2778    Saphhira Shifley         Florida   23.680    6.2160
# 174     Jennifer Braxton        Illinois   52.448 -131.1200
# 2816       Daniel Raglin   Massachusetts   60.740   15.1850

# %%
df_cat2 = pd.concat([df_1,df_2,df_3], axis = 1)
df_cat2
# Out:
#          Customer Name       State    Sales    Profit       Customer Name  \
# 174                NaN         NaN      NaN       NaN                 NaN
# 684                NaN         NaN      NaN       NaN      Grant Thornton
# 1488  Corinna Mitchell  California   42.600   16.6140                 NaN
# 1934  Lindsay Williams  California  244.550  114.9385                 NaN
# 2778               NaN         NaN      NaN       NaN                 NaN
# 2806               NaN         NaN      NaN       NaN  Michelle Huthwaite
# 2816               NaN         NaN      NaN       NaN                 NaN
# 2954      Eugene Moren     Arizona  671.984   50.3988                 NaN
# 3496               NaN         NaN      NaN       NaN                 NaN
# 6058               NaN         NaN      NaN       NaN       Kristina Nunn
# 6246  Katrina Bavinger  Washington   13.980    6.0114                 NaN
# 7730               NaN         NaN      NaN       NaN   Tamara Willingham
#
#                State    Sales   Profit     Customer Name          State  \
# 174              NaN      NaN      NaN  Jennifer Braxton       Illinois
# 684   North Carolina  167.440  14.6510               NaN            NaN
# 1488             NaN      NaN      NaN               NaN            NaN
# 1934             NaN      NaN      NaN               NaN            NaN
# 2778             NaN      NaN      NaN  Saphhira Shifley        Florida
# 2806      Washington    9.420   0.4710               NaN            NaN
# 2816             NaN      NaN      NaN     Daniel Raglin  Massachusetts
# 2954             NaN      NaN      NaN               NaN            NaN
# 3496             NaN      NaN      NaN   Cathy Armstrong     California
# 6058        New York   36.400  17.4720               NaN            NaN
# 6246             NaN      NaN      NaN               NaN            NaN
# 7730      Washington  291.136 -25.4744               NaN            NaN
#
#         Sales    Profit
# 174    52.448 -131.1200
# 684       NaN       NaN
# 1488      NaN       NaN
# 1934      NaN       NaN
# 2778   23.680    6.2160
# 2806      NaN       NaN
# 2816   60.740   15.1850
# 2954      NaN       NaN
# 3496  513.024   12.8256
# 6058      NaN       NaN
# 6246      NaN       NaN
# 7730      NaN       NaN

# %%
df_1=df[['Ship Date','Ship Mode','Customer Name']][0:4] 
df_1
# Out:
#    Ship Date       Ship Mode    Customer Name
# 0 2016-11-11    Second Class      Claire Gute
# 1 2016-11-11    Second Class      Claire Gute
# 2 2016-06-16    Second Class  Darrin Van Huff
# 3 2015-10-18  Standard Class   Sean O'Donnell

# %%
df_2=df[['Customer Name','Product Name','Quantity']][0:4] 
df_2
# Out:
#      Customer Name                                       Product Name  \
# 0      Claire Gute                  Bush Somerset Collection Bookcase
# 1      Claire Gute  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...
# 3   Sean O'Donnell      Bretford CR4500 Series Slim Rectangular Table
#
#    Quantity
# 0         2
# 1         3
# 2         2
# 3         5

# %%
pd.merge(df_1,df_2,on='Customer Name',how='inner')
# Out:
#    Ship Date       Ship Mode    Customer Name  \
# 0 2016-11-11    Second Class      Claire Gute
# 1 2016-11-11    Second Class      Claire Gute
# 2 2016-11-11    Second Class      Claire Gute
# 3 2016-11-11    Second Class      Claire Gute
# 4 2016-06-16    Second Class  Darrin Van Huff
# 5 2015-10-18  Standard Class   Sean O'Donnell
#
#                                         Product Name  Quantity
# 0                  Bush Somerset Collection Bookcase         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 2                  Bush Somerset Collection Bookcase         2
# 3  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 4  Self-Adhesive Address Labels for Typewriters b...         2
# 5      Bretford CR4500 Series Slim Rectangular Table         5

# %%
pd.merge(df_1,df_2,on='Customer Name',how='inner').drop_duplicates()
# Out:
#    Ship Date       Ship Mode    Customer Name  \
# 0 2016-11-11    Second Class      Claire Gute
# 1 2016-11-11    Second Class      Claire Gute
# 4 2016-06-16    Second Class  Darrin Van Huff
# 5 2015-10-18  Standard Class   Sean O'Donnell
#
#                                         Product Name  Quantity
# 0                  Bush Somerset Collection Bookcase         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 4  Self-Adhesive Address Labels for Typewriters b...         2
# 5      Bretford CR4500 Series Slim Rectangular Table         5

# %%
# Extract another small table called df_3 to show the concept of an outer join: 
df_3=df[['Customer Name','Product Name','Quantity']][2:6]

# %%
df_1
# Out:
#                  Ship Date       Ship Mode
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class

# %%
df_3
# Out:
#      Customer Name                                       Product Name  \
# 2  Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...
# 3   Sean O'Donnell      Bretford CR4500 Series Slim Rectangular Table
# 4   Sean O'Donnell                     Eldon Fold 'N Roll Cart System
# 5  Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...
#
#    Quantity
# 2         2
# 3         5
# 4         2
# 5         7

# %%
# Perform an inner join on df_1 and df_3 by using the following command: 
pd.merge(df_1,df_3,on='Customer Name',how='inner')
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0  Darrin Van Huff 2016-06-16    Second Class
# 1   Sean O'Donnell 2015-10-18  Standard Class
# 2   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0  Self-Adhesive Address Labels for Typewriters b...         2
# 1      Bretford CR4500 Series Slim Rectangular Table         5
# 2                     Eldon Fold 'N Roll Cart System         2

# %%
# Perform an outer join on df_1 and df_3 by using the following command: 
pd.merge(df_1,df_3,on='Customer Name',how='outer') # Outer is like union
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 2  Darrin Van Huff 2016-06-16    Second Class
# 3   Sean O'Donnell 2015-10-18  Standard Class
# 4   Sean O'Donnell 2015-10-18  Standard Class
# 5  Brosina Hoffman        NaT             NaN
#
#                                         Product Name  Quantity
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2  Self-Adhesive Address Labels for Typewriters b...       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table       5.0
# 4                     Eldon Fold 'N Roll Cart System       2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...       7.0

# %%
pd.merge(df_1,df_3,on='Customer Name',how='outer').drop_duplicates()
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 2  Darrin Van Huff 2016-06-16    Second Class
# 3   Sean O'Donnell 2015-10-18  Standard Class
# 4   Sean O'Donnell 2015-10-18  Standard Class
# 5  Brosina Hoffman        NaT             NaN
#
#                                         Product Name  Quantity
# 0                                                NaN       NaN
# 2  Self-Adhesive Address Labels for Typewriters b...       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table       5.0
# 4                     Eldon Fold 'N Roll Cart System       2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...       7.0

# %%
df_1=df[['Customer Name','Ship Date','Ship Mode']][0:4] 
df_1.set_index(['Customer Name'],inplace=True) 
df_1
# Out:
#                  Ship Date       Ship Mode
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class

# %%
df_2=df[['Customer Name','Product Name','Quantity']][2:6] 
df_2.set_index(['Customer Name'],inplace=True) 
df_2
# Out:
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...         7

# %%
df_1.join(df_2,how='left').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %%
df_1.join(df_2,how='inner').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2

# %%
df_1.join(df_2,how='outer').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Brosina Hoffman        NaT             NaN
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...       7.0
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %%
df.sample(n=5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3717    3718  CA-2016-142370 2016-09-19 2016-09-23  Standard Class
# 1704    1705  CA-2016-106306 2016-03-08 2016-03-08        Same Day
# 457      458  US-2016-157945 2016-09-26 2016-10-01  Standard Class
# 2202    2203  CA-2015-138002 2015-09-06 2015-09-12  Standard Class
# 175      176  US-2014-100853 2014-09-14 2014-09-19  Standard Class
#
#      Customer ID     Customer Name      Segment        Country      City  ...  \
# 3717    TP-21130  Theone Pippenger     Consumer  United States  Columbus  ...
# 1704    PG-18820   Patrick Gardner     Consumer  United States  Glendale  ...
# 457     NF-18385  Natalie Fritzler     Consumer  United States   Decatur  ...
# 2202    BT-11305     Beth Thompson  Home Office  United States   Seattle  ...
# 175     JB-15400  Jennifer Braxton    Corporate  United States   Chicago  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# 3717       31907    South  OFF-SU-10003002  Office Supplies     Supplies
# 1704       85301     West  OFF-BI-10003676  Office Supplies      Binders
# 457        62521  Central  FUR-CH-10002331        Furniture       Chairs
# 2202       98103     West  OFF-BI-10002160  Office Supplies      Binders
# 175        60623  Central  OFF-LA-10003148  Office Supplies       Labels
#
#                                            Product Name    Sales  Quantity  \
# 3717                                     Letter Slitter    5.040         2
# 1704  GBC Standard Recycled Report Covers, Clear Pla...    9.702         3
# 457   Hon 4700 Series Mobuis Mid-Back Task Chairs wi...  747.558         3
# 2202                          Acco Hanging Data Binders    6.096         2
# 175                                            Avery 51   20.160         4
#
#       Discount   Profit
# 3717       0.0   0.1512
# 1704       0.7  -7.1148
# 457        0.3 -96.1146
# 2202       0.2   2.1336
# 175        0.2   6.5520
#
# [5 rows x 21 columns]

# %%
df.sample(frac=0.1)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3712    3713  CA-2017-166198 2017-04-21 2017-04-24     First Class
# 9976    9977  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 3743    3744  CA-2016-137848 2016-01-15 2016-01-21  Standard Class
# 1338    1339  CA-2017-100524 2017-03-31 2017-04-02    Second Class
# 7453    7454  CA-2017-134796 2017-06-25 2017-07-01  Standard Class
# ...      ...             ...        ...        ...             ...
# 305      306  CA-2014-130960 2014-12-30 2015-01-04  Standard Class
# 9869    9870  CA-2014-114195 2014-11-01 2014-11-03     First Class
# 3264    3265  CA-2016-122518 2016-03-04 2016-03-08    Second Class
# 9020    9021  CA-2014-100706 2014-12-16 2014-12-18    Second Class
# 6925    6926  CA-2015-137925 2015-11-30 2015-12-04  Standard Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 3712    JW-15955   Joni Wasserman     Consumer  United States        Seattle
# 9976    AP-10720       Anne Pryor  Home Office  United States    Los Angeles
# 3743    WB-21850    William Brown     Consumer  United States  New York City
# 1338    CM-12115     Chad McGuire     Consumer  United States  New York City
# 7453    FM-14380      Fred McMath     Consumer  United States    Bolingbrook
# ...          ...              ...          ...            ...            ...
# 305     KB-16600      Ken Brennan    Corporate  United States         Taylor
# 9869    EA-14035    Erin Ashbrook    Corporate  United States          Mason
# 3264    RF-19345   Randy Ferguson    Corporate  United States          Miami
# 9020    LE-16810  Laurel Elliston     Consumer  United States    Springfield
# 6925    JL-15235        Janet Lee     Consumer  United States  New York City
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 3712  ...       98103     West  TEC-AC-10000521       Technology  Accessories
# 9976  ...       90032     West  TEC-PH-10002496       Technology       Phones
# 3743  ...       10011     East  OFF-BI-10002225  Office Supplies      Binders
# 1338  ...       10011     East  TEC-PH-10002549       Technology       Phones
# 7453  ...       60440  Central  TEC-PH-10003505       Technology       Phones
# ...   ...         ...      ...              ...              ...          ...
# 305   ...       48180  Central  OFF-AR-10003651  Office Supplies          Art
# 9869  ...       45040     East  OFF-BI-10000494  Office Supplies      Binders
# 3264  ...       33180    South  OFF-LA-10001641  Office Supplies       Labels
# 9020  ...       22153    South  FUR-FU-10002268        Furniture  Furnishings
# 6925  ...       10035     East  FUR-BO-10001608        Furniture    Bookcases
#
#                                            Product Name    Sales  Quantity  \
# 3712    Verbatim Slim CD and DVD Storage Cases, 50/Pack   11.540         1
# 9976                                       Cisco SPA301  249.584         2
# 3743  Square Ring Data Binders, Rigid 75 Pt. Covers,...   49.536         3
# 1338               Polycom SoundPoint IP 450 VoIP phone  677.580         3
# 7453                               Geemarc AmpliPOWER60  148.480         2
# ...                                                 ...      ...       ...
# 305                                          Newell 350    9.840         3
# 9869       Acco Economy Flexible Poly Round Ring Binder    3.132         2
# 3264                                          Avery 518   10.080         4
# 9020                              Ultra Door Push Plate   29.460         6
# 6925                         Hon Metal Bookcases, Black  681.408        12
#
#       Discount    Profit
# 3712       0.0    3.4620
# 9976       0.2   31.1980
# 3743       0.2   17.3376
# 1338       0.0  176.1708
# 7453       0.2   16.7040
# ...        ...       ...
# 305        0.0    2.8536
# 9869       0.7   -2.6100
# 3264       0.2    3.5280
# 9020       0.0    9.7218
# 6925       0.2   42.5880
#
# [999 rows x 21 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.sample(frac=.1,replace=True)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2438    2439  CA-2014-164210 2014-11-18 2014-11-20    Second Class
# 8747    8748  CA-2017-128076 2017-02-02 2017-02-07  Standard Class
# 778      779  CA-2015-144267 2015-08-21 2015-08-23     First Class
# 1600    1601  CA-2017-158876 2017-11-19 2017-11-21    Second Class
# 3680    3681  CA-2015-132626 2015-07-09 2015-07-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 4959    4960  CA-2016-166226 2016-11-18 2016-11-22  Standard Class
# 3270    3271  CA-2014-115980 2014-07-15 2014-07-19  Standard Class
# 8968    8969  CA-2014-166730 2014-12-30 2015-01-01     First Class
# 3102    3103  CA-2017-119578 2017-12-22 2017-12-27    Second Class
# 5673    5674  CA-2017-127922 2017-10-27 2017-11-03  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 2438    PW-19240       Pierre Wener     Consumer  United States
# 8747    BO-11350      Bill Overfelt    Corporate  United States
# 778     NZ-18565      Nick Zandusky  Home Office  United States
# 1600    AB-10150        Aimee Bixby     Consumer  United States
# 3680    BT-11680     Brian Thompson     Consumer  United States
# ...          ...                ...          ...            ...
# 4959    TC-21535      Tracy Collins  Home Office  United States
# 3270    VW-21775    Victoria Wilson    Corporate  United States
# 8968    DD-13570  Dorothy Dickinson     Consumer  United States
# 3102    JG-15310        Jason Gross    Corporate  United States
# 5673    SH-19975      Sally Hughsby    Corporate  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 2438     Louisville  ...       80027     West  OFF-PA-10002259
# 8747      San Diego  ...       92105     West  OFF-BI-10003638
# 778   San Francisco  ...       94110     West  OFF-PA-10000157
# 1600     Carrollton  ...       75007  Central  FUR-FU-10001967
# 3680        Clinton  ...       20735     East  OFF-LA-10000476
# ...             ...  ...         ...      ...              ...
# 4959    Los Angeles  ...       90008     West  TEC-PH-10003357
# 3270    Sioux Falls  ...       57103  Central  OFF-FA-10000304
# 8968        Memphis  ...       38109    South  OFF-ST-10002554
# 3102     Providence  ...        2908     East  FUR-BO-10003660
# 5673         Dallas  ...       75081  Central  OFF-PA-10001204
#
#              Category Sub-Category  \
# 2438  Office Supplies        Paper
# 8747  Office Supplies      Binders
# 778   Office Supplies        Paper
# 1600        Furniture  Furnishings
# 3680  Office Supplies       Labels
# ...               ...          ...
# 4959       Technology       Phones
# 3270  Office Supplies    Fasteners
# 8968  Office Supplies      Storage
# 3102        Furniture    Bookcases
# 5673  Office Supplies        Paper
#
#                                            Product Name    Sales  Quantity  \
# 2438  Geographics Note Cards, Blank, White, 8 1/2" x...   35.808         4
# 8747                         GBC Durable Plastic Covers   30.960         2
# 778                                           Xerox 191   59.940         3
# 1600                  Telescoping Adjustable Floor Lamp   15.992         2
# 3680  Avery 05222 Permanent Self-Adhesive File Folde...   12.390         3
# ...                                                 ...      ...       ...
# 4959      Grandstream GXP2100 Mainstream Business Phone   61.192         1
# 3270                                 Advantus Push Pins    6.540         3
# 8968                        Tennsco Industrial Shelving   39.128         1
# 3102   Bush Cubix Collection Bookcases, Fully Assembled  220.980         1
# 5673                                         Xerox 1972    8.448         2
#
#       Discount   Profit
# 2438       0.2  12.5328
# 8747       0.2  10.0620
# 778        0.0  28.1718
# 1600       0.6 -13.9930
# 3680       0.0   5.6994
# ...        ...      ...
# 4959       0.2   6.1192
# 3270       0.0   2.6814
# 8968       0.2  -8.8038
# 3102       0.0  50.8254
# 5673       0.2   2.6400
#
# [999 rows x 21 columns]

# %%
df['Customer Name'].value_counts()[:10]
# Out:
# William Brown          37
# Matt Abelman           34
# John Lee               34
# Paul Prost             34
# Seth Vernon            32
# Chloris Kastensmidt    32
# Edward Hooks           32
# Jonathan Doherty       32
# Arthur Prichep         31
# Emily Phan             31
# Name: Customer Name, dtype: int64

# %%
df_sample = df.sample(n=100) 
df_sample.pivot_table(values=['Sales','Quantity','Profit'],index=['Region','State'],aggfunc='mean')
# Out:
#                             Profit  Quantity       Sales
# Region  State
# Central Illinois        -29.281150  3.166667  212.980500
#         Michigan         89.575562  3.375000  277.385000
#         Minnesota        21.990000  2.000000   43.980000
#         Missouri         23.550000  6.000000   94.200000
#         Texas             2.062711  3.666667   87.504444
# East    Massachusetts   109.754400  2.000000  391.980000
#         New Hampshire    64.518000  3.000000  322.590000
#         New Jersey       98.105000  7.000000  196.210000
#         New York         36.047246  3.846154  310.204923
#         Ohio             -1.463000  3.750000   22.488500
#         Pennsylvania    -20.426400  1.500000   74.988000
# South   Arkansas          9.102000  6.000000   22.200000
#         Florida           4.308080  2.800000   96.638000
#         Georgia           2.707200  3.000000    5.640000
#         Kentucky         14.400000  8.000000   30.000000
#         North Carolina   48.290200  7.000000  146.104000
#         South Carolina   32.981700  3.000000  113.730000
#         Tennessee         5.162800  4.000000   19.029333
#         Virginia          9.563100  2.500000   19.650000
# West    Arizona         -99.789333  3.666667  175.610500
#         California       72.234336  4.720000  256.099600
#         New Mexico       99.432000  4.000000  883.840000
#         Oregon           47.960000  5.000000  239.800000
#         Utah             79.891200  3.000000  166.440000
#         Washington       68.335900  5.000000  188.630000

# %%
df_sample = df.sample(n=100) 
df_sample = df_sample.pivot_table(values=['Sales','Quantity','Profit'],index=['Region','State'],aggfunc='sum')
df_sample
# Out:
#                            Profit  Quantity      Sales
# Region  State
# Central Illinois          72.2516        11   393.7360
#         Indiana            2.8322         1     5.7800
#         Michigan          75.4506         9   241.4300
#         Missouri         220.4853         3   449.9700
#         Oklahoma          16.4052         2    33.4800
#         Texas           -228.4737        37  1339.1518
#         Wisconsin         62.7228         9   507.3200
# East    Connecticut      184.8714         9   458.2200
#         Delaware          85.0860         5   186.4200
#         Maryland          88.6140         7   622.7520
#         New Jersey       621.9744         4  2591.5600
#         New York         485.8198        29  1914.8460
#         Ohio             -71.3664         9   135.4760
#         Pennsylvania     -16.5832        18   355.6480
#         Rhode Island    2591.9568         9  5399.9100
# South   Alabama            1.0904         2     3.7600
#         Florida           24.2794        10   433.4880
#         Georgia          162.9733        13   333.5500
#         Louisiana         24.8540        10   264.9500
#         Mississippi       39.7750         9    81.5000
#         North Carolina     5.8653         7    52.1360
#         Tennessee          4.5873         3    40.7760
#         Virginia          47.9385         5   177.5500
# West    Arizona          -35.8074        10   251.8800
#         California       825.3679        96  3899.4560
#         Colorado          50.0980         2   801.5680
#         Montana         1379.9770         5  2999.9500
#         Nevada            25.5798         3    75.7920
#         New Mexico        21.7728         7    45.3600
#         Oregon            -3.0940         2    35.3600
#         Utah             270.9409        11  1185.6900
#         Washington       124.9548        13   847.1580

# %%
df_sample = df_sample.reset_index()

# %%
fig,ax = plt.subplots()
x = df_sample['State']
y = df_sample['Profit']
ax.plot(x,y, 2)
# Out:
# [<matplotlib.lines.Line2D at 0x1348db90>,
#  <matplotlib.lines.Line2D at 0x1348dc50>]

# %%
df_sample=df[['Customer Name','State','Sales','Quantity']].sample(n=15) 
df_sample
# Out:
#             Customer Name          State     Sales  Quantity
# 2060         Greg Guthrie     California    80.300         5
# 9626          Maya Herman          Texas     9.248         2
# 3119              Jim Epp        Florida   249.584         2
# 9654        Harold Pawlan        Arizona     4.938         2
# 2198  Chloris Kastensmidt   Pennsylvania    15.552         3
# 9123        Eric Hoffmann   Pennsylvania    78.759         9
# 4507           Ben Ferrer     California    20.340         1
# 7698           Ben Ferrer  Massachusetts    73.850         1
# 7690      Ricardo Sperren       Virginia   872.940         3
# 2896         Kunst Miller       New York    49.650         5
# 3472      Sylvia Foulston           Ohio    18.544         2
# 1046     Zuschuss Carroll        Florida  1363.960         5
# 96         Parhena Norris       New York    96.530         7
# 8083     Kristen Hastings         Oregon    14.301         7
# 3647       Vicky Freymann     California    15.520         4

# %%
df_sample.sort_values(by='Sales')

# %%
df_sample.sort_values(by=['State','Sales'])

# %%
def categorize_sales(price): 
    if price < 50: 
        return "Low" 
    elif price < 200: 
        return "Medium" 
    else: 
        return "High"

# %%
df_sample=df[['Customer Name','State','Sales']].sample(n=100) 
df_sample.head(10)

# %%
df_sample['Sales Price Category']=df_sample['Sales'].apply(categorize_sales) 
df_sample.head(10)

# %%
df_sample['Customer Name Length']=df_sample['Customer Name'].apply(len) 
df_sample.head(10)

# %%
df_sample['Discounted Price']=df_sample['Sales'].apply(lambda x:0.85*x if x>200 else x) 
df_sample.head(10)

# %%
# Out:
#             Customer Name          State     Sales  Quantity
# 9654        Harold Pawlan        Arizona     4.938         2
# 9626          Maya Herman          Texas     9.248         2
# 8083     Kristen Hastings         Oregon    14.301         7
# 3647       Vicky Freymann     California    15.520         4
# 2198  Chloris Kastensmidt   Pennsylvania    15.552         3
# 3472      Sylvia Foulston           Ohio    18.544         2
# 4507           Ben Ferrer     California    20.340         1
# 2896         Kunst Miller       New York    49.650         5
# 7698           Ben Ferrer  Massachusetts    73.850         1
# 9123        Eric Hoffmann   Pennsylvania    78.759         9
# 2060         Greg Guthrie     California    80.300         5
# 96         Parhena Norris       New York    96.530         7
# 3119              Jim Epp        Florida   249.584         2
# 7690      Ricardo Sperren       Virginia   872.940         3
# 1046     Zuschuss Carroll        Florida  1363.960         5

# %%
df_sample.sort_values(by=['State','Sales'])
# Out:
#             Customer Name          State     Sales  Quantity
# 9654        Harold Pawlan        Arizona     4.938         2
# 3647       Vicky Freymann     California    15.520         4
# 4507           Ben Ferrer     California    20.340         1
# 2060         Greg Guthrie     California    80.300         5
# 3119              Jim Epp        Florida   249.584         2
# 1046     Zuschuss Carroll        Florida  1363.960         5
# 7698           Ben Ferrer  Massachusetts    73.850         1
# 2896         Kunst Miller       New York    49.650         5
# 96         Parhena Norris       New York    96.530         7
# 3472      Sylvia Foulston           Ohio    18.544         2
# 8083     Kristen Hastings         Oregon    14.301         7
# 2198  Chloris Kastensmidt   Pennsylvania    15.552         3
# 9123        Eric Hoffmann   Pennsylvania    78.759         9
# 9626          Maya Herman          Texas     9.248         2
# 7690      Ricardo Sperren       Virginia   872.940         3

# %%
def categorize_sales(price): 
    if price < 50: 
        return "Low" 
    elif price < 200: 
        return "Medium" 
    else: 
        return "High"

# %%
df_sample=df[['Customer Name','State','Sales']].sample(n=100) 
df_sample.head(10)
# Out:
#          Customer Name          State     Sales
# 1270     Sibella Parks       Illinois   102.336
# 4532     Tanja Norvell     California   122.352
# 8576        Tony Sayre  New Hampshire   102.300
# 5260        Sam Zeldin          Texas   196.776
# 7568         Rob Lucas     California    26.460
# 5948  Claudia Bergmann    Mississippi    42.680
# 7632  Katherine Hughes       Kentucky  1207.840
# 9272       Harry Marie       New York   631.960
# 3885      Clytie Kelty       Illinois    12.128
# 5104      Gene McClure   Pennsylvania    16.776

# %%
df_sample['Sales Price Category']=df_sample['Sales'].apply(categorize_sales) 
df_sample.head(10)
# Out:
#          Customer Name          State     Sales Sales Price Category
# 1270     Sibella Parks       Illinois   102.336               Medium
# 4532     Tanja Norvell     California   122.352               Medium
# 8576        Tony Sayre  New Hampshire   102.300               Medium
# 5260        Sam Zeldin          Texas   196.776               Medium
# 7568         Rob Lucas     California    26.460                  Low
# 5948  Claudia Bergmann    Mississippi    42.680                  Low
# 7632  Katherine Hughes       Kentucky  1207.840                 High
# 9272       Harry Marie       New York   631.960                 High
# 3885      Clytie Kelty       Illinois    12.128                  Low
# 5104      Gene McClure   Pennsylvania    16.776                  Low

# %%
df_sample['Customer Name Length']=df_sample['Customer Name'].apply(len) 
df_sample.head(10)
# Out:
#          Customer Name          State     Sales Sales Price Category  \
# 1270     Sibella Parks       Illinois   102.336               Medium
# 4532     Tanja Norvell     California   122.352               Medium
# 8576        Tony Sayre  New Hampshire   102.300               Medium
# 5260        Sam Zeldin          Texas   196.776               Medium
# 7568         Rob Lucas     California    26.460                  Low
# 5948  Claudia Bergmann    Mississippi    42.680                  Low
# 7632  Katherine Hughes       Kentucky  1207.840                 High
# 9272       Harry Marie       New York   631.960                 High
# 3885      Clytie Kelty       Illinois    12.128                  Low
# 5104      Gene McClure   Pennsylvania    16.776                  Low
#
#       Customer Name Length
# 1270                    13
# 4532                    13
# 8576                    10
# 5260                    10
# 7568                     9
# 5948                    16
# 7632                    16
# 9272                    11
# 3885                    12
# 5104                    12

# %%
df_sample['Discounted Price']=df_sample['Sales'].apply(lambda x:0.85*x if x>200 else x) 
df_sample.head(10)
# Out:
#          Customer Name          State     Sales Sales Price Category  \
# 1270     Sibella Parks       Illinois   102.336               Medium
# 4532     Tanja Norvell     California   122.352               Medium
# 8576        Tony Sayre  New Hampshire   102.300               Medium
# 5260        Sam Zeldin          Texas   196.776               Medium
# 7568         Rob Lucas     California    26.460                  Low
# 5948  Claudia Bergmann    Mississippi    42.680                  Low
# 7632  Katherine Hughes       Kentucky  1207.840                 High
# 9272       Harry Marie       New York   631.960                 High
# 3885      Clytie Kelty       Illinois    12.128                  Low
# 5104      Gene McClure   Pennsylvania    16.776                  Low
#
#       Customer Name Length  Discounted Price
# 1270                    13           102.336
# 4532                    13           122.352
# 8576                    10           102.300
# 5260                    10           196.776
# 7568                     9            26.460
# 5948                    16            42.680
# 7632                    16          1026.664
# 9272                    11           537.166
# 3885                    12            12.128
# 5104                    12            16.776
