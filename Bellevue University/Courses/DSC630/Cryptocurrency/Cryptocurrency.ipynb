# %%
import cbpro
import pandas as pd
import plotly.graph_objects as go
from cryptocompy import coin

# %%
public_client = cbpro.PublicClient()

df=pd.DataFrame(public_client.get_product_historic_rates('ETH-USD', granularity=3600,start='2020-02-17 01:00:00',end='2020-02-29'))
df.columns=['Date','Low','High','Open','Close','Volume']
df['Date']=pd.to_datetime(df['Date'],unit='s')

df.sort_values(by='Date')
# Out:
#                    Date     Low    High    Open   Close        Volume
# 287 2020-02-17 01:00:00  253.82  259.08  255.62  254.73   6861.416073
# 286 2020-02-17 02:00:00  250.80  254.83  254.71  252.62   9713.079667
# 285 2020-02-17 03:00:00  246.50  253.57  252.66  249.79   9665.817915
# 284 2020-02-17 04:00:00  242.36  249.71  249.69  246.03  21630.709527
# 283 2020-02-17 05:00:00  245.82  252.00  246.03  249.88  10740.712166
# ..                  ...     ...     ...     ...     ...           ...
# 4   2020-02-28 20:00:00  222.01  226.36  222.33  223.64  11416.442049
# 3   2020-02-28 21:00:00  223.30  226.87  223.51  226.12   6015.952386
# 2   2020-02-28 22:00:00  225.68  230.00  226.10  229.90   9813.059207
# 1   2020-02-28 23:00:00  226.53  231.70  229.90  227.37   5870.127166
# 0   2020-02-29 00:00:00  227.04  232.20  227.13  229.81   6230.373932
#
# [288 rows x 6 columns]

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="cc63bba0-978a-40dc-bef5-550d33e10ab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc63bba0-978a-40dc-bef5-550d33e10ab3")) {                    Plotly.newPlot(                        "cc63bba0-978a-40dc-bef5-550d33e10ab3",                        [{"close": [229.81, 227.37, 229.9, 226.12, 223.64, 222.41, 221.4, 222.85, 223.77, 227.07, 224.19, 223.29, 217.56, 220.47, 221.31, 219.45, 223.65, 224.0, 226.15, 227.32, 229.0, 229.85, 232.16, 233.11, 230.3, 227.63, 228.25, 226.37, 232.62, 234.68, 233.61, 235.97, 236.67, 231.14, 230.16, 228.92, 226.73, 226.76, 227.83, 223.81, 227.9, 225.32, 223.67, 221.3, 218.24, 218.59, 216.98, 218.07, 216.33, 223.5, 225.14, 223.6, 227.91, 229.45, 231.66, 222.14, 221.69, 226.01, 2
# ...

# %%
finance_charts = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')


finance_charts.head()
# Out:
#          Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0  2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1  2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2  2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3  2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4  2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
#
#    AAPL.Adjusted          dn        mavg          up   direction
# 0     122.905254  106.741052  117.927667  129.114281  Increasing
# 1     123.760965  107.842423  118.940333  130.038244  Increasing
# 2     123.501363  108.894245  119.889167  130.884089  Decreasing
# 3     124.510914  109.785449  120.763500  131.741551  Increasing
# 4     127.876074  110.372516  121.720167  133.067817  Increasing

# %%
fig = go.Figure(data=[go.Candlestick(x=finance_charts['Date'],
                open=finance_charts['AAPL.Open'],
                high=finance_charts['AAPL.High'],
                low=finance_charts['AAPL.Low'],
                close=finance_charts['AAPL.Close'])])

fig.show()
# Out:
# <div>                            <div id="122f153c-6e2d-45ff-99f0-e7d5031e9d1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("122f153c-6e2d-45ff-99f0-e7d5031e9d1f")) {                    Plotly.newPlot(                        "122f153c-6e2d-45ff-99f0-e7d5031e9d1f",                        [{"close": [127.83000200000001, 128.720001, 128.449997, 129.5, 133.0, 132.169998, 128.78999299999998, 130.419998, 128.46000700000002, 129.08999599999999, 129.360001, 128.53999299999998, 126.410004, 126.599998, 127.139999, 124.510002, 122.239998, 124.449997, 123.589996, 124.949997, 127.040001, 128.470001, 127.5, 125.900002, 127.209999, 126.690002, 123.379997, 124.239998, 123.25, 126.370003, 124.43, 124.25, 125.32, 127.349998, 126.010002, 125.599998, 126.559998, 127
# ...

# %%
coin_data = coin.get_coin_snapshot("ETH","TUSD")
df = pd.DataFrame(coin_data["Exchanges"])
df["VOLUME24HOUR"] = pd.to_numeric(df["VOLUME24HOUR"])
df["VOLUME24HOURTO"] = pd.to_numeric(df["VOLUME24HOURTO"])
df["MEANPRICE"] = df["VOLUME24HOURTO"] / df["VOLUME24HOUR"]
df = df[
    [
        "MARKET",
        "LOW24HOUR",
        "HIGH24HOUR",
        "PRICE",
        "VOLUME24HOUR",
        "VOLUME24HOURTO",
        "MEANPRICE",
    ]
]
df.sort_values(by="VOLUME24HOUR", ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-28-e5cd6bd11a14> in <module>
# ----> 1 coin_data = coin.get_coin_snapshot("ETH","TUSD")
#       2 df = pd.DataFrame(coin_data["Exchanges"])
#       3 df["VOLUME24HOUR"] = pd.to_numeric(df["VOLUME24HOUR"])
#       4 df["VOLUME24HOURTO"] = pd.to_numeric(df["VOLUME24HOURTO"])
#       5 df["MEANPRICE"] = df["VOLUME24HOURTO"] / df["VOLUME24HOUR"]
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\cryptocompy\coin.py in get_coin_snapshot(fsym, tsym)
#      97         # load data
#      98         url = build_url('coinsnapshot', fsym=fsym, tsym=tsym)
# ---> 99         data = load_data(url)['Data']
#     100
#     101         return data
#
# ...
