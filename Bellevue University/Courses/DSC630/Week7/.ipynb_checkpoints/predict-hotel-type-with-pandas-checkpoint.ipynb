# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import random

# %%
del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-b7ec48e0f2bf> in <module>
# ----> 1 del df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Data exploration

# %%
filename = 'data/train.csv'
p = 0.01  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped

df = pd.read_csv(
         filename,parse_dates=['date_time','srch_ci', 'srch_co'],
         nrows=50000
)
df.columns
# Out:
# Index(['date_time', 'site_name', 'posa_continent', 'user_location_country',
#        'user_location_region', 'user_location_city',
#        'orig_destination_distance', 'user_id', 'is_mobile', 'is_package',
#        'channel', 'srch_ci', 'srch_co', 'srch_adults_cnt', 'srch_children_cnt',
#        'srch_rm_cnt', 'srch_destination_id', 'srch_destination_type_id',
#        'is_booking', 'cnt', 'hotel_continent', 'hotel_country', 'hotel_market',
#        'hotel_cluster'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date_time                  50000 non-null  datetime64[ns]
#  1   site_name                  50000 non-null  int64
#  2   posa_continent             50000 non-null  int64
#  3   user_location_country      50000 non-null  int64
#  4   user_location_region       50000 non-null  int64
#  5   user_location_city         50000 non-null  int64
#  6   orig_destination_distance  30998 non-null  float64
#  7   user_id                    50000 non-null  int64
#  8   is_mobile                  50000 non-null  int64
#  9   is_package                 50000 non-null  int64
#  10  channel                    50000 non-null  int64
#  11  srch_ci                    49971 non-null  datetime64[ns]
#  12  srch_co                    49971 non-null  datetime64[ns]
#  13  srch_adults_cnt            50000 non-null  int64
#  14  srch_children_cnt          50000 non-null  int64
#  15  srch_rm_cnt                50000 non-null  int64
#  16  srch_destination_id        50000 non-null  int64
#  17  srch_destination_type_id   50000 non-null  int64
#  18  is_booking                 50000 non-null  int64
#  19  cnt                        50000 non-null  int64
#  20  hotel_continent            50000 non-null  int64
#  21  hotel_country              50000 non-null  int64
#  22  hotel_market               50000 non-null  int64
#  23  hotel_cluster              50000 non-null  int64
# dtypes: datetime64[ns](3), float64(1), int64(20)
# memory usage: 9.2 MB

# %%
df.head()
# Out:
#             date_time  site_name  posa_continent  user_location_country  \
# 0 2014-08-11 07:46:59          2               3                     66
# 1 2014-08-11 08:22:12          2               3                     66
# 2 2014-08-11 08:24:33          2               3                     66
# 3 2014-08-09 18:05:16          2               3                     66
# 4 2014-08-09 18:08:18          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                  2234.2641
# 2                   348               48862                  2234.2641
# 3                   442               35390                   913.1932
# 4                   442               35390                   913.6259
#
#    user_id  is_mobile  is_package  ...  srch_destination_id  \
# 0       12          0           1  ...                 8250
# 1       12          0           1  ...                 8250
# 2       12          0           0  ...                 8250
# 3       93          0           0  ...                14984
# 4       93          0           0  ...                14984
#
#   srch_destination_type_id is_booking  cnt  hotel_continent  hotel_country  \
# 0                        1          0    3                2             50
# 1                        1          1    1                2             50
# 2                        1          0    1                2             50
# 3                        1          0    1                2             50
# 4                        1          0    1                2             50
#
#    hotel_market  hotel_cluster  hotel_nights  src_total_cnt
# 0           628              1           4.0              2
# 1           628              1           4.0              2
# 2           628              1           4.0              2
# 3          1457             80           5.0              2
# 4          1457             21           5.0              2
#
# [5 rows x 26 columns]

# %%
sns.countplot(x='hotel_continent', data=df)
# Out:
# <AxesSubplot:xlabel='hotel_continent', ylabel='count'>

# %%
sns.countplot(x='posa_continent', data=df)
# Out:
# <AxesSubplot:xlabel='posa_continent', ylabel='count'>

# %%
sns.countplot(x='hotel_continent', hue='posa_continent', data=df)
# Out:
# <AxesSubplot:xlabel='hotel_continent', ylabel='count'>

# %%
# how many people by continent are booking from mobile
sns.countplot(x='posa_continent', hue='is_mobile', data = df)
# Out:
# <AxesSubplot:xlabel='posa_continent', ylabel='count'>

# %%
# Difference between user and destination country
sns.distplot(df['user_location_country'], label="User country")
sns.distplot(df['hotel_country'], label="Hotel country")
plt.legend()
# Out:
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
# get number of booked nights as difference between check in and check out
hotel_nights = df['srch_co'] - df['srch_ci'] 
hotel_nights = (hotel_nights / np.timedelta64(1, 'D')).astype(float) # convert to float to avoid NA problems
df['hotel_nights'] = hotel_nights
plt.figure(figsize=(11, 9))
ax = sns.boxplot(x='hotel_continent', y='hotel_nights', data=df)
lim = ax.set(ylim=(0, 15))

# %%
plt.figure(figsize=(11, 9))
sns.countplot(x="hotel_nights", data=df)
# Out:
# <AxesSubplot:xlabel='hotel_nights', ylabel='count'>

# %%
# distribution of the total number of people per cluster
src_total_cnt = df.srch_adults_cnt + df.srch_children_cnt
df['src_total_cnt'] = src_total_cnt
ax = sns.kdeplot(df['hotel_cluster'], df['src_total_cnt'], cmap="Purples_d")
lim = ax.set(ylim=(0.5, 4.5))
# Out:
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# plot all columns countplots
import numpy as np
rows = df.columns.size//3 - 1
fig, axes = plt.subplots(nrows=rows, ncols=3, figsize=(12,18))
fig.tight_layout()
i = 0
j = 0
for col in df.columns:
    if j >= 3:
        j = 0
        i += 1
    # avoid to plot by date    
    if df[col].dtype == np.int64:
        sns.countplot(x=col, data=df, ax=axes[i][j])
        j += 1

# %%
# Plot 

fig, (axis1,axis2) = plt.subplots(2,1,figsize=(15,10))

bookings_df = df[df["is_booking"] == 1]

# What are the most countries the customer travel from?
sns.countplot('user_location_country',data=bookings_df.sort_values(by=['user_location_country']),ax=axis1,palette="Set3")

# What are the most countries the customer travel to?
sns.countplot('hotel_country',data=bookings_df.sort_values(by=['hotel_country']),ax=axis2,palette="Set3")

# Combine both plots
# fig, (axis1) = plt.subplots(1,1,figsize=(15,5))

# sns.distplot(bookings_df["hotel_country"], kde=False, rug=False, bins=25, ax=axis1)
# sns.distplot(bookings_df["user_location_country"], kde=False, rug=False, bins=25, ax=axis1)
# Out:
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='hotel_country', ylabel='count'>

# %%
aggs = df.groupby(['srch_destination_id','hotel_cluster'])['is_booking'].agg(['sum','count']).reset_index()
aggs
# Out:
#        srch_destination_id  hotel_cluster  sum  count
# 0                       11             94    1      2
# 1                       14             20    1      3
# 2                       14             75    0      2
# 3                       16              7    1      2
# 4                       19             20    0      1
# ...                    ...            ...  ...    ...
# 16076                64871             46    0      2
# 16077                64999             54    0      1
# 16078                65035             10    1      7
# 16079                65035             35    0      1
# 16080                65035             36    0      1
#
# [16081 rows x 4 columns]

# %%
CLICK_WEIGHT = 0.05
agg = aggs.groupby(['srch_destination_id','hotel_cluster']).sum().reset_index()
agg['count'] -= agg['sum']
agg = agg.rename(columns={'sum':'bookings','count':'clicks'})
agg['relevance'] = agg['bookings'] + CLICK_WEIGHT * agg['clicks']
agg.head()
# Out:
#    srch_destination_id  hotel_cluster  bookings  clicks  relevance
# 0                   11             94         1       1       1.05
# 1                   14             20         1       2       1.10
# 2                   14             75         0       2       0.10
# 3                   16              7         1       1       1.05
# 4                   19             20         0       1       0.05

# %%
def most_popular(group, n_max=5):
    relevance = group['relevance'].values
    hotel_cluster = group['hotel_cluster'].values
    most_popular = hotel_cluster[np.argsort(relevance)[::-1]][:n_max]
    return np.array_str(most_popular)[1:-1] # remove square brackets

# %%
most_pop = agg.groupby(['srch_destination_id']).apply(most_popular)
most_pop = pd.DataFrame(most_pop).rename(columns={0:'hotel_cluster'})
most_pop.head()
# Out:
#                       hotel_cluster
# srch_destination_id
# 11                               94
# 14                            20 75
# 16                                7
# 19                      40 61 30 20
# 21                   44 46 82 57 30

# %%
plt.scatter(agg['hotel_cluster'],agg['relevance'])
plt.title('hotel_cluster vs. relevance')
plt.xlabel('hotel_cluster')
plt.ylabel('relevance)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Out:
#        srch_destination_id  hotel_cluster
# 23                   12193             94
# 574                   8278             94
# 635                   8278             94
# 1110                 62134             94
# 1296                  8273             94
# ...                    ...            ...
# 49434                12812             94
# 49435                12812             94
# 49735                 8249             94
# 49820                 3093             94
# 49821                 3093             94
#
# [408 rows x 2 columns]

# %%
train = pd.read_csv('data/train.csv',
                    dtype={'is_booking':bool,'srch_destination_id':np.int32, 'hotel_cluster':np.int32},
                    usecols=['srch_destination_id','is_booking','hotel_cluster'],
                    chunksize=1000000)
aggs = []
print('-'*38)
for chunk in train:
    agg = chunk.groupby(['srch_destination_id',
                         'hotel_cluster'])['is_booking'].agg(['sum','count'])
    agg.reset_index(inplace=True)
    aggs.append(agg)
    print('.',end='')
print('')
aggs = pd.concat(aggs, axis=0)
aggs.head()
# Out:
# --------------------------------------
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-108-48b60c72207d> in <module>
#       7 for chunk in train:
#       8     agg = chunk.groupby(['srch_destination_id',
# ----> 9                          'hotel_cluster'])['is_booking'].agg(['sum','count'])
#      10     agg.reset_index(inplace=True)
#      11     aggs.append(agg)
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     244             # but not the class list / tuple itself.
#     245             func = maybe_mangle_lambdas(func)
# --> 246             ret = self._aggregate_multiple_funcs(func)
#     247             if relabeling:
#     248                 ret.columns = columns
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg)
#     317                 obj._reset_cache()
#     318                 obj._selection = name
# --> 319             results[base.OutputKey(label=name, position=idx)] = obj.aggregate(func)
#     320
#     321         if any(isinstance(x, DataFrame) for x in results.values()):
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     238
#     239         if isinstance(func, str):
# --> 240             return getattr(self, func)(*args, **kwargs)
#     241
#     242         elif isinstance(func, abc.Iterable):
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\groupby.py in sum(self, numeric_only, min_count)
#    1538     def sum(self, numeric_only: bool = True, min_count: int = 0):
#    1539         return self._agg_general(
# -> 1540             numeric_only=numeric_only, min_count=min_count, alias="add", npfunc=np.sum
#    1541         )
#    1542
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     998         try:
#     999             return self._cython_agg_general(
# -> 1000                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1001             )
#    1002         except DataError:
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1032
#    1033             result, agg_names = self.grouper.aggregate(
# -> 1034                 obj._values, how, min_count=min_count
#    1035             )
#    1036
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in aggregate(self, values, how, axis, min_count)
#     583     ) -> Tuple[np.ndarray, Optional[List[str]]]:
#     584         return self._cython_operation(
# --> 585             "aggregate", values, how, axis, min_count=min_count
#     586         )
#     587
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     506         if vdim == 1:
#     507             values = values[:, None]
# --> 508             out_shape = (self.ngroups, arity)
#     509         else:
#     510             if axis > 0:
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in ngroups(self)
#     295     @cache_readonly
#     296     def ngroups(self) -> int:
# --> 297         return len(self.result_index)
#     298
#     299     @property
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in result_index(self)
#     308             return self.groupings[0].result_index.rename(self.names[0])
#     309
# --> 310         codes = self.reconstructed_codes
#     311         levels = [ping.result_index for ping in self.groupings]
#     312         result = MultiIndex(
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in reconstructed_codes(self)
#     300     def reconstructed_codes(self) -> List[np.ndarray]:
#     301         codes = self.codes
# --> 302         comp_ids, obs_ids, _ = self.group_info
#     303         return decons_obs_group_ids(comp_ids, obs_ids, self.shape, codes, xnull=True)
#     304
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in group_info(self)
#     269     @cache_readonly
#     270     def group_info(self):
# --> 271         comp_ids, obs_group_ids = self._get_compressed_codes()
#     272
#     273         ngroups = len(obs_group_ids)
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in _get_compressed_codes(self)
#     288         if len(all_codes) > 1:
#     289             group_index = get_group_index(all_codes, self.shape, sort=True, xnull=True)
# --> 290             return compress_group_index(group_index, sort=self.sort)
#     291
#     292         ping = self.groupings[0]
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\sorting.py in compress_group_index(group_index, sort)
#     541
#     542     if sort and len(obs_group_ids) > 0:
# --> 543         obs_group_ids, comp_ids = _reorder_by_uniques(obs_group_ids, comp_ids)
#     544
#     545     return comp_ids, obs_group_ids
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\sorting.py in _reorder_by_uniques(uniques, labels)
#     557
#     558     # move labels to right locations (ie, unsort ascending labels)
# --> 559     labels = algorithms.take_nd(reverse_indexer, labels, allow_fill=False)
#     560     np.putmask(labels, mask, -1)
#     561
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1699             # (s.t. df.values is c-contiguous and df._mgr.blocks[0] is its
#    1700             # f-contiguous transpose)
# -> 1701             out = np.empty(out_shape, dtype=dtype, order="F")
#    1702         else:
#    1703             out = np.empty(out_shape, dtype=dtype)
#
# MemoryError: Unable to allocate 7.63 MiB for an array with shape (1000000,) and data type int64

# %%
train = pd.read_csv('data/train.csv',chunksize=100000)
aggs = []
print('-'*38)
for chunk in train:
    agg = chunk.groupby(['srch_destination_id',
                         'hotel_cluster'])['is_booking'].agg(['sum','count'])
    agg.reset_index(inplace=True)
    aggs.append(agg)
    print('.',end='')
print('')
aggs = pd.concat(aggs, axis=0)
aggs.head()

# %%
aggs.describe()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-54-a811274b9f63> in <module>
# ----> 1 aggs.describe()
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10082             if datetime_is_numeric:
#   10083                 default_include.append("datetime")
# > 10084             data = self.select_dtypes(include=default_include)
#   10085             if len(data.columns) == 0:
#   10086                 data = self
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3601             keep_these &= ~self.dtypes.isin(excluded_dtypes)
#    3602
# -> 3603         return self.iloc[:, keep_these.values]
#    3604
#    3605     def insert(self, loc, column, value, allow_duplicates=False) -> None:
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1447             pass
#    1448
# -> 1449         return self._getitem_tuple_same_dim(tup)
#    1450
#    1451     def _get_list_axis(self, key, axis: int):
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
#     749
# --> 750             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     751             # We should never have retval.ndim < self.ndim, as that should
#     752             #  be handled by the _getitem_lowerdim call above.
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1481         if com.is_bool_indexer(key):
#    1482             self._validate_key(key, axis)
# -> 1483             return self._getbool_axis(key, axis=axis)
#    1484
#    1485         # a list of integers
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     896         key = check_bool_indexer(labels, key)
#     897         inds = key.nonzero()[0]
# --> 898         return self.obj._take_with_is_copy(inds, axis=axis)
#     899
#     900
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3358         See the docstring of `take` for full explanation of the parameters.
#    3359         """
# -> 3360         result = self.take(indices=indices, axis=axis)
#    3361         # Maybe set copy if we didn't actually change the index.
#    3362         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3346
#    3347         new_data = self._mgr.take(
# -> 3348             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3349         )
#    3350         return self._constructor(new_data).__finalize__(self, method="take")
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1446         new_labels = self.axes[axis].take(indexer)
#    1447         return self.reindex_indexer(
# -> 1448             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1449         )
#    1450
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1280
#    1281         if axis == 0:
# -> 1282             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1283         else:
#    1284             new_blocks = [
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#    1408                             blocks.append(nb)
#    1409                     else:
# -> 1410                         nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#    1411                         blocks.append(nb)
#    1412
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1253
#    1254         new_values = algos.take_nd(
# -> 1255             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1256         )
#    1257
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1701             out = np.empty(out_shape, dtype=dtype, order="F")
#    1702         else:
# -> 1703             out = np.empty(out_shape, dtype=dtype)
#    1704
#    1705     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 111. MiB for an array with shape (4, 3632017) and data type int64

# %% [markdown]
# Next we aggregate again to compute the total number of bookings over all chunks.
#
# Compute the number of clicks by subtracting the number of bookings from total row counts.
#
# Compute the 'relevance' of a hotel cluster with a weighted sum of bookings and clicks.

# %%
CLICK_WEIGHT = 0.05
agg = aggs.groupby(['srch_destination_id','hotel_cluster']).sum().reset_index()
agg['count'] -= agg['sum']
agg = agg.rename(columns={'sum':'bookings','count':'clicks'})
agg['relevance'] = agg['bookings'] + CLICK_WEIGHT * agg['clicks']
agg.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_func_and_vals(self, kind, how, values, is_numeric)
#     420         try:
# --> 421             func = self._get_cython_function(kind, how, values, is_numeric)
#     422         except NotImplementedError:
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_function(self, kind, how, values, is_numeric)
#     395             raise NotImplementedError(
# --> 396                 f"function is not implemented for this dtype: "
#     397                 f"[how->{how},dtype->{dtype_str}]"
#
# NotImplementedError: function is not implemented for this dtype: [how->add,dtype->int64]
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-55-3c80347c670d> in <module>
#       1 CLICK_WEIGHT = 0.05
# ----> 2 agg = aggs.groupby(['srch_destination_id','hotel_cluster']).sum().reset_index()
#       3 agg['count'] -= agg['sum']
#       4 agg = agg.rename(columns={'sum':'bookings','count':'clicks'})
#       5 agg['relevance'] = agg['bookings'] + CLICK_WEIGHT * agg['clicks']
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\groupby.py in sum(self, numeric_only, min_count)
#    1538     def sum(self, numeric_only: bool = True, min_count: int = 0):
#    1539         return self._agg_general(
# -> 1540             numeric_only=numeric_only, min_count=min_count, alias="add", npfunc=np.sum
#    1541         )
#    1542
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     998         try:
#     999             return self._cython_agg_general(
# -> 1000                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1001             )
#    1002         except DataError:
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1018     ) -> DataFrame:
#    1019         agg_blocks, agg_items = self._cython_agg_blocks(
# -> 1020             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1021         )
#    1022         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1047             try:
#    1048                 result, _ = self.grouper.aggregate(
# -> 1049                     block.values, how, axis=1, min_count=min_count
#    1050                 )
#    1051             except NotImplementedError:
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in aggregate(self, values, how, axis, min_count)
#     583     ) -> Tuple[np.ndarray, Optional[List[str]]]:
#     584         return self._cython_operation(
# --> 585             "aggregate", values, how, axis, min_count=min_count
#     586         )
#     587
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     518             out_shape = (self.ngroups,) + values.shape[1:]
#     519
# --> 520         func, values = self._get_cython_func_and_vals(kind, how, values, is_numeric)
#     521
#     522         if how == "rank":
#
# c:\users\safar\documents\github\safarie1103\bellevue university\courses\dsc630\venv\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_func_and_vals(self, kind, how, values, is_numeric)
#     423             if is_numeric:
#     424                 try:
# --> 425                     values = ensure_float64(values)
#     426                 except TypeError:
#     427                     if lib.infer_dtype(values, skipna=False) == "complex":
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# MemoryError: Unable to allocate 55.4 MiB for an array with shape (3632017, 2) and data type float64

# %% [markdown]
# ### Find most popular hotel clusters by destination
#
# Define a function to get most popular hotels for a destination group.
#
# Previous version used nlargest() Series method to get indices of largest elements.
# But as @benjamin points out [in his fork](https://www.kaggle.com/benjaminabel/expedia-hotel-recommendations/pandas-version-of-most-popular-hotels/comments) the method is rather slow.
# I have updated this notebook with a version that runs faster.

# %%
def most_popular(group, n_max=5):
    relevance = group['relevance'].values
    hotel_cluster = group['hotel_cluster'].values
    most_popular = hotel_cluster[np.argsort(relevance)[::-1]][:n_max]
    return np.array_str(most_popular)[1:-1] # remove square brackets

# %% [markdown]
# Get most popular hotel clusters for all destinations.

# %%
most_pop = agg.groupby(['srch_destination_id']).apply(most_popular)
most_pop = pd.DataFrame(most_pop).rename(columns={0:'hotel_cluster'})
most_pop.head()

# %% [markdown]
# ### Predict for test data
# Read in the test data and merge most popular hotel clusters.

# %%
test = pd.read_csv('data/test.csv',
                    dtype={'srch_destination_id':np.int32},
                    usecols=['srch_destination_id'],)

# %%
test = test.merge(most_pop, how='left',left_on='srch_destination_id',right_index=True)
test.head()

# %% [markdown]
# Check hotel_cluster column in test for null values.

# %%
test.hotel_cluster.isnull().sum()

# %% [markdown]
# Looks like there's about 14k new destinations in test. Let's fill nas with hotel clusters that are most popular overall.

# %%
most_pop_all = agg.groupby('hotel_cluster')['relevance'].sum().nlargest(5).index
most_pop_all = np.array_str(most_pop_all)[1:-1]
most_pop_all

# %%
test.hotel_cluster.fillna(most_pop_all,inplace=True)

# %% [markdown]
# Save the submission.

# %%
test.hotel_cluster.to_csv('predicted_with_pandas.csv',header=True, index_label='id')
