# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import random
train_file = "data/train.csv"
test_file = "data/test.csv"
random.seed(300)

# %%
#Ran once to get the total number of records
#n = sum(1 for line in open(train_file)) - 1

#print(n)
#n = 37670293

# %%
# Get first 1000 rows to get basic info
df = pd.read_csv(train_file, nrows=1000)

# %%
### feature information
print(df.columns)
print(len(df.columns))
# Out:
# Index(['date_time', 'site_name', 'posa_continent', 'user_location_country',
#        'user_location_region', 'user_location_city',
#        'orig_destination_distance', 'user_id', 'is_mobile', 'is_package',
#        'channel', 'srch_ci', 'srch_co', 'srch_adults_cnt', 'srch_children_cnt',
#        'srch_rm_cnt', 'srch_destination_id', 'srch_destination_type_id',
#        'is_booking', 'cnt', 'hotel_continent', 'hotel_country', 'hotel_market',
#        'hotel_cluster'],
#       dtype='object')
# 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date_time                  1000 non-null   object
#  1   site_name                  1000 non-null   int64
#  2   posa_continent             1000 non-null   int64
#  3   user_location_country      1000 non-null   int64
#  4   user_location_region       1000 non-null   int64
#  5   user_location_city         1000 non-null   int64
#  6   orig_destination_distance  268 non-null    float64
#  7   user_id                    1000 non-null   int64
#  8   is_mobile                  1000 non-null   int64
#  9   is_package                 1000 non-null   int64
#  10  channel                    1000 non-null   int64
#  11  srch_ci                    1000 non-null   object
#  12  srch_co                    1000 non-null   object
# ...

# %%
df.head()
# Out:
#              date_time  site_name  posa_continent  user_location_country  \
# 0  2014-08-11 07:46:59          2               3                     66
# 1  2014-08-11 08:22:12          2               3                     66
# 2  2014-08-11 08:24:33          2               3                     66
# 3  2014-08-09 18:05:16          2               3                     66
# 4  2014-08-09 18:08:18          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                  2234.2641
# 2                   348               48862                  2234.2641
# 3                   442               35390                   913.1932
# 4                   442               35390                   913.6259
#
#    user_id  is_mobile  is_package  ...  srch_children_cnt srch_rm_cnt  \
# ...

# %%
df.describe()
# Out:
#         site_name  posa_continent  user_location_country  \
# count  1000.00000      1000.00000            1000.000000
# mean     19.36100         2.16700              50.865000
# std      10.30577         0.74274              56.595334
# min       2.00000         0.00000               3.000000
# 25%      13.00000         2.00000              23.000000
# 50%      24.00000         2.00000              23.000000
# 75%      25.00000         3.00000              66.000000
# max      37.00000         4.00000             205.000000
#
#        user_location_region  user_location_city  orig_destination_distance  \
# count           1000.000000         1000.000000                 268.000000
# mean             193.805000        19680.638000                1860.755094
# std              243.919765        16541.209223                2271.610410
# min               12.000000         1493.000000                   3.337900
# ...

# %% [markdown]
# ### Hotels  are grouped together based on historical price, customer star ratings, geographical locations relative to city center, etc are represented by hotel cluster. So in the table below, srch_destination_id 8250 has 3 cluster 1 hotels, one of which was booked 8 8/11 at 8:22:12. checkin date from 8/29 to 9/2. Two searches resulted in click(not booked)

# %%
df[['date_time','srch_destination_id','hotel_cluster','is_booking','srch_ci','srch_co']].head(20)
# Out:
#              date_time  srch_destination_id  hotel_cluster  is_booking  \
# 0  2014-08-11 07:46:59                 8250              1       False
# 1  2014-08-11 08:22:12                 8250              1        True
# 2  2014-08-11 08:24:33                 8250              1       False
# 3  2014-08-09 18:05:16                14984             80       False
# 4  2014-08-09 18:08:18                14984             21       False
# 5  2014-08-09 18:13:12                14984             92       False
# 6  2014-07-16 09:42:23                 8267             41       False
# 7  2014-07-16 09:45:48                 8267             41       False
# 8  2014-07-16 09:52:11                 8267             69       False
# 9  2014-07-16 09:55:24                 8267             70       False
# 10 2014-07-16 10:00:06                 8267             98       False
# 11 2014-07-16 10:02:58                 8267             10       False
# ...

# %% [markdown]
# #### Now read in 50,000 records

# %%
# Set data types for better  memory management.
dtype = {'site_name':np.int32,
'posa_continent':np.int32,
'user_location_country':np.int32,
'user_location_region':np.int32,
'user_location_city':np.int32,
'orig_destination_distance':np.float32,
'user_id':np.int32,
'is_mobile':np.int32,
'is_package':np.int32,
'channel':np.int32,
'srch_adults_cnt':np.int32,
'srch_children_cnt':np.int32,
'srch_rm_cnt':np.int32,
'srch_destination_id':np.int32,
'srch_destination_type_id':np.int32,
'is_booking':bool,
'cnt':np.int32,
'hotel_continent':np.int32,
'hotel_country':np.int32,
'hotel_market':np.int32,
'hotel_cluster':np.int32}

# Set to datetime type for date calculations calculations
parse_dates=['date_time','srch_ci', 'srch_co']

# %%
df = pd.read_csv('data/train.csv',dtype=dtype,parse_dates = parse_dates,nrows=50000)

# %%
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
pd.concat([total, percent], axis=1, keys=['Total', 'Percent']).transpose()
# Out:
#          orig_destination_distance  srch_ci  srch_co  channel  site_name  \
# Total                    19002.000   29.000   29.000      0.0        0.0
# Percent                     38.004    0.058    0.058      0.0        0.0
#
#          posa_continent  user_location_country  user_location_region  \
# Total               0.0                    0.0                   0.0
# Percent             0.0                    0.0                   0.0
#
#          user_location_city  user_id  ...  srch_adults_cnt  srch_children_cnt  \
# Total                   0.0      0.0  ...              0.0                0.0
# Percent                 0.0      0.0  ...              0.0                0.0
#
#          srch_rm_cnt  srch_destination_id  srch_destination_type_id  \
# Total            0.0                  0.0                       0.0
# Percent          0.0                  0.0                       0.0
#
#          is_booking  cnt  hotel_continent  hotel_country  date_time
# ...

# %%
df = df.dropna(subset=['srch_ci', 'srch_co'])
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
pd.concat([total, percent], axis=1, keys=['Total', 'Percent']).transpose()
# Out:
#          orig_destination_distance  hotel_cluster  hotel_market  site_name  \
# Total                 18997.000000            0.0           0.0        0.0
# Percent                  38.016049            0.0           0.0        0.0
#
#          posa_continent  user_location_country  user_location_region  \
# Total               0.0                    0.0                   0.0
# Percent             0.0                    0.0                   0.0
#
#          user_location_city  user_id  is_mobile  ...  srch_adults_cnt  \
# Total                   0.0      0.0        0.0  ...              0.0
# Percent                 0.0      0.0        0.0  ...              0.0
#
#          srch_children_cnt  srch_rm_cnt  srch_destination_id  \
# Total                  0.0          0.0                  0.0
# Percent                0.0          0.0                  0.0
#
#          srch_destination_type_id  is_booking  cnt  hotel_continent  \
# ...

# %% [markdown]
# ### Compute number of nights in the search and add as new feature

# %%
# get number of booked nights as difference between check in and check out
hotel_nights = df['srch_co'] - df['srch_ci'] 
hotel_nights = (hotel_nights / np.timedelta64(1, 'D')).astype(float) # convert to float to avoid NA problems
df['hotel_nights'] = hotel_nights
df[['date_time','srch_destination_id','hotel_cluster','is_booking','srch_ci','srch_co','hotel_nights']].head()
# Out:
#             date_time  srch_destination_id  hotel_cluster  is_booking  \
# 0 2014-08-11 07:46:59                 8250              1       False
# 1 2014-08-11 08:22:12                 8250              1        True
# 2 2014-08-11 08:24:33                 8250              1       False
# 3 2014-08-09 18:05:16                14984             80       False
# 4 2014-08-09 18:08:18                14984             21       False
#
#      srch_ci    srch_co  hotel_nights
# 0 2014-08-27 2014-08-31           4.0
# 1 2014-08-29 2014-09-02           4.0
# 2 2014-08-29 2014-09-02           4.0
# 3 2014-11-23 2014-11-28           5.0
# 4 2014-11-23 2014-11-28           5.0

# %% [markdown]
# ### Get the total number of bookings per srch_destination_id, and hotel cluster. This will tell us the total number of bookings for each cluster in the dataset.
#
# ### Clusters with most booking are the most popular. Now we have to find out more bout the search criteria. Seach destination id is a 1st criteria.

# %%
df.groupby(['srch_destination_id','hotel_cluster'])['is_booking'].agg(['sum','count'])
# Out:
#                                    sum  count
# srch_destination_id hotel_cluster
# 11                  94               1      2
# 14                  20               1      3
#                     75               0      2
# 16                  7                1      2
# 19                  20               0      1
# ...                                ...    ...
# 64871               46               0      2
# 64999               54               0      1
# 65035               10               1      7
#                     35               0      1
#                     36               0      1
#
# [16077 rows x 2 columns]

# %% [markdown]
# #### Table below shows search destination id 24, has 6 hotel clusters. Cluster 3 was searched once and no booking. Cluster 32 was search 4 times resulting in 2 bookings-both with one adult and no children. We can compute a measure for a hotel cluster that will rate it as popular or unpopular.

# %%
df[df['srch_destination_id']==24][['srch_adults_cnt', 'srch_children_cnt','srch_rm_cnt','srch_destination_id','hotel_cluster','is_booking']]
# Out:
#        srch_adults_cnt  srch_children_cnt  srch_rm_cnt  srch_destination_id  \
# 34527                1                  0            1                   24
# 34528                1                  0            1                   24
# 34529                1                  0            1                   24
# 34530                1                  0            1                   24
# 34531                1                  0            1                   24
# 34532                1                  0            1                   24
# 34533                1                  0            1                   24
# 34550                1                  0            1                   24
# 40929                1                  0            2                   24
#
#        hotel_cluster  is_booking
# 34527              3       False
# 34528             32       False
# 34529             32        True
# 34530             76       False
# 34531             32       False
# ...

# %%
df[df['srch_destination_id']==24][['srch_destination_id','hotel_cluster','is_booking']].groupby(['srch_destination_id','hotel_cluster'])['is_booking'].agg(['sum','count'])
# Out:
#                                    sum  count
# srch_destination_id hotel_cluster
# 24                  3                0      1
#                     32               2      4
#                     42               0      1
#                     76               0      1
#                     91               0      1
#                     94               1      1

# %% [markdown]
# #### Compute bookings and clicks. Bookings are aggregated with those with value of 1, clicks are the total number of searches in each group

# %%
df_aggs = df.groupby(['srch_destination_id','hotel_cluster'])['is_booking'].agg(['sum','count']).reset_index()
df_aggs[df_aggs['srch_destination_id']==24]
# Out:
#     srch_destination_id  hotel_cluster  sum  count
# 26                   24              3    0      1
# 27                   24             32    2      4
# 28                   24             42    0      1
# 29                   24             76    0      1
# 30                   24             91    0      1
# 31                   24             94    1      1

# %% [markdown]
# #### Compute the relevance of hotel cluster based on number of bookings per search. relevance is high when number of bookings is closer to number of search results. This is weighted by total number of searches as shown below and number of bookings. Relevence of 0 is the lowest with no bookings at all(regardless of number of searches)

# %%
df_agg  = df.groupby(['srch_destination_id','hotel_cluster'])['is_booking'].agg(['sum','count']).reset_index()
df_agg = df_agg.rename(columns={'sum':'bookings','count':'clicks'})
df_agg['relevance'] = df_agg['bookings'] + 0.05*(df_agg['clicks']* df_agg['bookings'])

# %% [markdown]
# #### The tables below show that  the relevance of hotel clusters varies depending on the srch_destinationID. For example  hotel cluster 3 at destination of 24 has relevance of 0 but 1.05 for destination 235.

# %%
# Show relevance per search destination id.
df_agg[(df_agg['srch_destination_id'] == 24) | (df_agg['srch_destination_id'] == 235)]
# Out:
#      srch_destination_id  hotel_cluster  bookings  clicks  relevance
# 26                    24              3         0       1       0.00
# 27                    24             32         2       4       2.40
# 28                    24             42         0       1       0.00
# 29                    24             76         0       1       0.00
# 30                    24             91         0       1       0.00
# 31                    24             94         1       1       1.05
# 120                  235              3         1       1       1.05
# 121                  235             77         0       1       0.00

# %% [markdown]
# #### This table shows variance of relevance for each srch_destination_id. This can be surmized to be true for other search criterial. We will look at srch_adult_cnt below.

# %%
df_agg[df_agg['hotel_cluster'] == 3][['hotel_cluster','relevance']]
# Out:
#      hotel_cluster  relevance
# 3                3      48.60
# 103              3      96.30
# 203              3       1.45
# 303              3       0.00
# 403              3       0.00
# 497              3       0.00

# %%
df_agg.describe()
# Out:
#        srch_destination_id  hotel_cluster      bookings        clicks  \
# count         16077.000000   16077.000000  16077.000000  16077.000000
# mean          17593.380979      48.731977      0.255272      3.108229
# std           12770.400526      28.897645      0.724159      7.527323
# min              11.000000       0.000000      0.000000      1.000000
# 25%            8740.000000      23.000000      0.000000      1.000000
# 50%           12602.000000      47.000000      0.000000      2.000000
# 75%           23956.000000      75.000000      0.000000      3.000000
# max           65035.000000      99.000000     34.000000    300.000000
#
#           relevance
# count  16077.000000
# mean       0.468041
# std        5.346835
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      544.000000

# %%
df_agg[df_agg['relevance'] >= 544]
# Out:
#       srch_destination_id  hotel_cluster  bookings  clicks  relevance
# 2717                 8250              1        34     300      544.0

# %%
def most_popular_in_group(group, n_max=10):
    relevance = group['relevance'].values
    hotel_cluster = group['hotel_cluster'].values
    most_popular = hotel_cluster[np.argsort(relevance)[::-1]][:n_max]
    return np.array_str(most_popular)[1:-1] # remove square brackets

# %%
most_pop = df_agg.groupby(['srch_destination_id']).apply(most_popular_in_group)
most_pop = pd.DataFrame(most_pop).rename(columns={0:'hotel_cluster'})
most_pop.head(10)
# Out:
#                                      hotel_cluster
# srch_destination_id
# 11                                              94
# 14                                           20 75
# 16                                               7
# 19                                     61 40 30 20
# 21                   44 46 82 11 15 20 29 30 36 85
# 24                               32 94 91 76 42  3
# 25                                           48 90
# 27                                        89 86 30
# 33                                              78
# 40                                              82

# %% [markdown]
# #### The graph below shows a few outliers. These are the ones with more clicks.

# %%
plt.scatter(df_agg['hotel_cluster'],df_agg['relevance'])
plt.title('hotel_cluster vs. relevance')
plt.xlabel('hotel_cluster')
plt.ylabel('relevance)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(df_agg['hotel_cluster'],df_agg['clicks'])
plt.title('hotel_cluster vs. clicks')
plt.xlabel('hotel_cluster')
plt.ylabel('clicks)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(df_agg['hotel_cluster'],df_agg['bookings'])
plt.title('hotel_cluster vs. bookings')
plt.xlabel('hotel_cluster')
plt.ylabel('bookings)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df_agg
# Out:
#        srch_destination_id  hotel_cluster  bookings  clicks  relevance
# 0                       11             94         1       2       1.10
# 1                       14             20         1       3       1.15
# 2                       14             75         0       2       0.00
# 3                       16              7         1       2       1.10
# 4                       19             20         0       1       0.00
# ...                    ...            ...       ...     ...        ...
# 16076                64871             46         0       2       0.00
# 16077                64999             54         0       1       0.00
# 16078                65035             10         1       7       1.35
# 16079                65035             35         0       1       0.00
# 16080                65035             36         0       1       0.00
#
# [16081 rows x 5 columns]

# %% [markdown]
# #### This shows which clusters have the highest relevance. Cluster 1 showed earlier to have a relevance 0f 544 with 300 clicks and 34 bookings

# %%
most_pop_all = df_agg.groupby('hotel_cluster')['relevance'].sum().nlargest(5).index
most_pop_all = np.array_str(most_pop_all)[1:-1]
most_pop_all
# Out:
# ' 1 91 45 54 41'

# %%
most_pop_all
# Out:
# ' 1 91 45 54 41'

# %% [markdown]
# #### Compute relevance based on srch_adults_cnt

# %%
df_agg  = df[df['srch_adults_cnt'] >0].groupby(['srch_adults_cnt','hotel_cluster'])['is_booking'].agg(['sum','count']).reset_index()
df_agg = df_agg.rename(columns={'sum':'bookings','count':'clicks'})
df_agg['relevance'] = df_agg['bookings'] + 0.05*(df_agg['clicks']* df_agg['bookings'])

# %%
# Show relevance per search destination id.
df_agg[df_agg['relevance'] > 0 ]
# Out:
#      srch_adults_cnt  hotel_cluster  bookings  clicks  relevance
# 0                  1              0         7      91      38.85
# 1                  1              1        15      86      79.50
# 2                  1              2        25     148     210.00
# 3                  1              3         9      88      48.60
# 4                  1              4        13     112      85.80
# ..               ...            ...       ...     ...        ...
# 624                8             47         1       2       1.10
# 627                8             51         1       3       1.15
# 631                8             61         1       7       1.35
# 633                8             63         1       2       1.10
# 648                8             95         1       5       1.25
#
# [397 rows x 5 columns]

# %%
most_pop = df_agg.groupby(['srch_adults_cnt']).apply(most_popular_in_group)
most_pop = pd.DataFrame(most_pop).rename(columns={0:'hotel_cluster'})
most_pop.head(10)
# Out:
#                                  hotel_cluster
# srch_adults_cnt
# 1                91 48 46 42 82 18 59  5 21 64
# 2                91 41 42 48 28 64 95 59 25 97
# 3                91 48 62 16 42 41  5 50 95 25
# 4                16  1 91 48  2 25 42 72  8 41
# 5                25 58 19 98 42 91 41 30 50 43
# 6                83 51 50 91 36 25  1 47  6 54
# 7                28 81 95 70 61 51 45 19 16  9
# 8                61 95 42 13 51 47 63 30 43 41
# 9                98 91 78 76 70 59 56 50 48 41

# %% [markdown]
# #### This graph shows that relevance with respect to adult count is different than those with respect to search destination.

# %%
plt.scatter(df_agg['hotel_cluster'],df_agg['relevance'])
plt.title('hotel_cluster vs. relevance')
plt.xlabel('hotel_cluster')
plt.ylabel('relevance)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Adult count 1 and 2 seem to have most relevance

# %%
plt.scatter(df_agg['srch_adults_cnt'],df_agg['relevance'])
plt.title('srch_adults_cnt vs. relevance')
plt.xlabel('srch_adults_cnt')
plt.ylabel('relevance)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Distribuition of hotel clusters in continents. Continent 2 has the most clustets.

# %%
fig_dims =(30, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x='hotel_cluster', hue='hotel_continent', ax=ax, data=df)
# Out:
# <AxesSubplot:xlabel='hotel_cluster', ylabel='count'>

# %%
plt.figure(figsize=(11, 9))
sns.countplot(x="hotel_nights", data=train)
# Out:
# <AxesSubplot:xlabel='hotel_cluster', ylabel='count'>

# %%
fig_dims =(30, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x='hotel_nights', ax=ax, data=df)
# Out:
# <AxesSubplot:xlabel='hotel_nights', ylabel='count'>
