# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-data-analysis/resources/0dhYG) course resource._
#
# ---

# %% [markdown]
# # The Series Data Structure

# %%
import pandas as pd
pd.Series?

# %%
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers = [1, 2, 3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
animals = ['Tiger', 'Bear', None]
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1, 2, None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index
# Out:
# Index(['Archery', 'Golf', 'Sumo', 'Taekwondo'], dtype='object')

# %%
s = pd.Series(['Tiger', 'Bear', 'Moose'], index=['India', 'America', 'Canada'])
s
# Out:
# India      Tiger
# America     Bear
# Canada     Moose
# dtype: object

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports, index=['Golf', 'Sumo', 'Hockey'])
s
# Out:
# Golf      Scotland
# Sumo         Japan
# Hockey         NaN
# dtype: object

# %% [markdown]
# # Querying a Series

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s[3]
# Out:
# 'South Korea'

# %%
s['Golf']
# Out:
# 'Scotland'

# %%
sports = {99: 'Bhutan',
          100: 'Scotland',
          101: 'Japan',
          102: 'South Korea'}
s = pd.Series(sports)
s
# Out:
# 99          Bhutan
# 100       Scotland
# 101          Japan
# 102    South Korea
# dtype: object

# %%
s[0] #This won't call s.iloc[0] as one might expect, it generates an error instead
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-00fa51989f14> in <module>
# ----> 1 s[0] #This won't call s.iloc[0] as one might expect, it generates an error instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total = 0
for item in s:
    total+=item
print(total)
# Out:
# 324.0

# %%
import numpy as np

total = np.sum(s)
print(total)
# Out:
# 324.0

# %%
#this creates a big series of random numbers
s = pd.Series(np.random.randint(0,1000,10000))
s.tail(10)
# Out:
# 9990    222
# 9991    425
# 9992    126
# 9993     53
# 9994    260
# 9995    193
# 9996    224
# 9997    500
# 9998    430
# 9999    942
# dtype: int32

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item
# Out:
# 665 µs ± 35.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 107 µs ± 23.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s+=2 #adds two to each item in s using broadcasting
s.head()
# Out:
# 0    217
# 1     52
# 2     59
# 3    626
# 4    493
# dtype: int32

# %%
for label, value in s.iteritems():
    s.set_value(label, value+2)
s.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 0    219
# 1     54
# 2     61
# 3    628
# 4    495
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]= value+2

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2

# %%
s = pd.Series([1, 2, 3])
s.loc['Animal'] = 'Bears'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
cricket_loving_countries
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %% [markdown]
# # The DataFrame Data Structure

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.loc['Store 2']
# Out:
# Name                  Vinod
# Item Purchased    Bird Seed
# Cost                      5
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['Store 1']
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.T #Transposes the dataframe
# Out:
#                  Store 1       Store 1    Store 2
# Name               Chris         Kevyn      Vinod
# Item Purchased  Dog Food  Kitty Litter  Bird Seed
# Cost                22.5           2.5          5

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2       5
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df['Cost'].max()
# Out:
# 22.5

# %%
df.loc[:,['Cost']].max()
# Out:
# Cost    22.5
# dtype: float64

# %%
df["Item Purchased"]
# Out:
# Store 1        Dog Food
# Store 1    Kitty Litter
# Store 2       Bird Seed
# Name: Item Purchased, dtype: object

# %%
df.loc['Store 1']['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.loc[:,['Name', 'Cost']]
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %%
df.drop('Store 1')
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df = df.copy()
copy_df = copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df.drop?

# %%
del copy_df['Name']
copy_df
# Out:
#         Item Purchased  Cost
# Store 2      Bird Seed   5.0

# %%
df['Location'] = None
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  22.5     None
# Store 1  Kevyn   Kitty Litter   2.5     None
# Store 2  Vinod      Bird Seed   5.0     None

# %% [markdown]
# # Dataframe Indexing and Loading

# %%
costs = df['Cost']
costs
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
costs+=2
costs
# Out:
# Store 1    24.5
# Store 1     4.5
# Store 2     7.0
# Name: Cost, dtype: float64

# %%
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  24.5     None
# Store 1  Kevyn   Kitty Litter   4.5     None
# Store 2  Vinod      Bird Seed   7.0     None

# %%
# !cat olympics.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('olympics.csv', index_col = 0, skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True) 

df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)               0         2               2
# Algeria (ALG)                   2         8              15
# Argentina (ARG)                24        28              70
# Armenia (ARM)                   2         9              12
# Australasia (ANZ) [ANZ]         4         5              12

# %% [markdown]
# # Querying a DataFrame

# %%
df['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# British West Indies (BWI) [BWI]                 False
# Bulgaria (BUL) [H]                               True
# Burundi (BDI)                                    True
# Cameroon (CMR)                                   True
# Canada (CAN)                                     True
# Chile (CHI) [I]                                  True
# China (CHN) [CHN]                                True
# Colombia (COL)                                   True
# Costa Rica (CRC)                                 True
# Ivory Coast (CIV) [CIV]                         False
# Croatia (CRO)                                    True
# Cuba (CUB) [Z]                                   True
# Cyprus (CYP)                                    False
#                                                 ...
# Spain (ESP) [Z]                                  True
# Sri Lanka (SRI) [SRI]                           False
# Sudan (SUD)                                     False
# Suriname (SUR) [E]                               True
# Sweden (SWE) [Z]                                 True
# Switzerland (SUI)                                True
# Syria (SYR)                                      True
# Chinese Taipei (TPE) [TPE] [TPE2]                True
# Tajikistan (TJK)                                False
# Tanzania (TAN) [TAN]                            False
# Thailand (THA)                                   True
# Togo (TOG)                                      False
# Tonga (TGA)                                     False
# Trinidad and Tobago (TRI) [TRI]                  True
# Tunisia (TUN)                                    True
# Turkey (TUR)                                     True
# Uganda (UGA)                                     True
# Ukraine (UKR)                                    True
# United Arab Emirates (UAE)                       True
# United States (USA) [P] [Q] [R] [Z]              True
# Uruguay (URU)                                    True
# Uzbekistan (UZB)                                 True
# Venezuela (VEN)                                  True
# Vietnam (VIE)                                   False
# Virgin Islands (ISV)                            False
# Yugoslavia (YUG) [YUG]                           True
# Independent Olympic Participants (IOP) [IOP]    False
# Zambia (ZAM) [ZAM]                              False
# Zimbabwe (ZIM) [ZIM]                             True
# Mixed team (ZZX) [ZZX]                           True
# Name: Gold, Length: 146, dtype: bool

# %%
df['Gold'].max()
# Out:
# 976

# %%
df[df['Gold'] == df['Gold'].max()]
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# United States (USA) [P] [Q] [R] [Z]        26   976     757     666   2399
#
#                                      # Winter  Gold.1  Silver.1  Bronze.1  \
# United States (USA) [P] [Q] [R] [Z]        22      96       102        84
#
#                                      Total.1  # Games  Gold.2  Silver.2  \
# United States (USA) [P] [Q] [R] [Z]      282       48    1072       859
#
#                                      Bronze.2  Combined total
# United States (USA) [P] [Q] [R] [Z]       750            2681

# %%
df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# Australia (AUS) [AUS] [Z]                  25   139     152     177    468
# Austria (AUT)                              26    18      33      35     86
# Belarus (BLR)                               5    12      24      39     75
# Belgium (BEL)                              25    37      52      53    142
# Bulgaria (BUL) [H]                         19    51      85      78    214
# Canada (CAN)                               25    59      99     121    279
# China (CHN) [CHN]                           9   201     146     126    473
# Croatia (CRO)                               6     6       7      10     23
# Czech Republic (CZE) [CZE]                  5    14      15      15     44
# Czechoslovakia (TCH) [TCH]                 16    49      49      45    143
# Estonia (EST)                              11     9       9      15     33
# Finland (FIN)                              24   101      84     117    302
# France (FRA) [O] [P] [Z]                   27   202     223     246    671
# Germany (GER) [GER] [Z]                    15   174     182     217    573
# United Team of Germany (EUA) [EUA]          3    28      54      36    118
# East Germany (GDR) [GDR]                    5   153     129     127    409
# West Germany (FRG) [FRG]                    5    56      67      81    204
# Great Britain (GBR) [GBR] [Z]              27   236     272     272    780
# Italy (ITA) [M] [S]                        26   198     166     185    549
# Japan (JPN)                                21   130     126     142    398
# Kazakhstan (KAZ)                            5    16      17      19     52
# South Korea (KOR)                          16    81      82      80    243
# Netherlands (NED) [Z]                      25    77      85     104    266
# Norway (NOR) [Q]                           24    56      49      43    148
# Poland (POL)                               20    64      82     125    271
# Russia (RUS) [RUS]                          5   132     121     142    395
# Soviet Union (URS) [URS]                    9   395     319     296   1010
# Unified Team (EUN) [EUN]                    1    45      38      29    112
# Slovakia (SVK) [SVK]                        5     7       9       8     24
# Slovenia (SLO)                              6     4       6       9     19
# Spain (ESP) [Z]                            22    37      59      35    131
# Sweden (SWE) [Z]                           26   143     164     176    483
# Switzerland (SUI)                          27    47      73      65    185
# Ukraine (UKR)                               5    33      27      55    115
# United States (USA) [P] [Q] [R] [Z]        26   976     757     666   2399
# Uzbekistan (UZB)                            5     5       5      10     20
#
#                                      # Winter  Gold.1  Silver.1  Bronze.1  \
# Australia (AUS) [AUS] [Z]                  18       5         3         4
# Austria (AUT)                              22      59        78        81
# Belarus (BLR)                               6       6         4         5
# Belgium (BEL)                              20       1         1         3
# Bulgaria (BUL) [H]                         19       1         2         3
# Canada (CAN)                               22      62        56        52
# China (CHN) [CHN]                          10      12        22        19
# Croatia (CRO)                               7       4         6         1
# Czech Republic (CZE) [CZE]                  6       7         9         8
# Czechoslovakia (TCH) [TCH]                 16       2         8        15
# Estonia (EST)                               9       4         2         1
# Finland (FIN)                              22      42        62        57
# France (FRA) [O] [P] [Z]                   22      31        31        47
# Germany (GER) [GER] [Z]                    11      78        78        53
# United Team of Germany (EUA) [EUA]          3       8         6         5
# East Germany (GDR) [GDR]                    6      39        36        35
# West Germany (FRG) [FRG]                    6      11        15        13
# Great Britain (GBR) [GBR] [Z]              22      10         4        12
# Italy (ITA) [M] [S]                        22      37        34        43
# Japan (JPN)                                20      10        17        18
# Kazakhstan (KAZ)                            6       1         3         3
# South Korea (KOR)                          17      26        17        10
# Netherlands (NED) [Z]                      20      37        38        35
# Norway (NOR) [Q]                           22     118       111       100
# Poland (POL)                               22       6         7         7
# Russia (RUS) [RUS]                          6      49        40        35
# Soviet Union (URS) [URS]                    9      78        57        59
# Unified Team (EUN) [EUN]                    1       9         6         8
# Slovakia (SVK) [SVK]                        6       2         2         1
# Slovenia (SLO)                              7       2         4         9
# Spain (ESP) [Z]                            19       1         0         1
# Sweden (SWE) [Z]                           22      50        40        54
# Switzerland (SUI)                          22      50        40        48
# Ukraine (UKR)                               6       2         1         4
# United States (USA) [P] [Q] [R] [Z]        22      96       102        84
# Uzbekistan (UZB)                            6       1         0         0
#
#                                      Total.1  # Games  Gold.2  Silver.2  \
# Australia (AUS) [AUS] [Z]                 12       43     144       155
# Austria (AUT)                            218       48      77       111
# Belarus (BLR)                             15       11      18        28
# Belgium (BEL)                              5       45      38        53
# Bulgaria (BUL) [H]                         6       38      52        87
# Canada (CAN)                             170       47     121       155
# China (CHN) [CHN]                         53       19     213       168
# Croatia (CRO)                             11       13      10        13
# Czech Republic (CZE) [CZE]                24       11      21        24
# Czechoslovakia (TCH) [TCH]                25       32      51        57
# Estonia (EST)                              7       20      13        11
# Finland (FIN)                            161       46     143       146
# France (FRA) [O] [P] [Z]                 109       49     233       254
# Germany (GER) [GER] [Z]                  209       26     252       260
# United Team of Germany (EUA) [EUA]        19        6      36        60
# East Germany (GDR) [GDR]                 110       11     192       165
# West Germany (FRG) [FRG]                  39       11      67        82
# Great Britain (GBR) [GBR] [Z]             26       49     246       276
# Italy (ITA) [M] [S]                      114       48     235       200
# Japan (JPN)                               45       41     140       143
# Kazakhstan (KAZ)                           7       11      17        20
# South Korea (KOR)                         53       33     107        99
# Netherlands (NED) [Z]                    110       45     114       123
# Norway (NOR) [Q]                         329       46     174       160
# Poland (POL)                              20       42      70        89
# Russia (RUS) [RUS]                       124       11     181       161
# Soviet Union (URS) [URS]                 194       18     473       376
# Unified Team (EUN) [EUN]                  23        2      54        44
# Slovakia (SVK) [SVK]                       5       11       9        11
# Slovenia (SLO)                            15       13       6        10
# Spain (ESP) [Z]                            2       41      38        59
# Sweden (SWE) [Z]                         144       48     193       204
# Switzerland (SUI)                        138       49      97       113
# Ukraine (UKR)                              7       11      35        28
# United States (USA) [P] [Q] [R] [Z]      282       48    1072       859
# Uzbekistan (UZB)                           1       11       6         5
#
#                                      Bronze.2  Combined total
# Australia (AUS) [AUS] [Z]                 181             480
# Austria (AUT)                             116             304
# Belarus (BLR)                              44              90
# Belgium (BEL)                              56             147
# Bulgaria (BUL) [H]                         81             220
# Canada (CAN)                              173             449
# China (CHN) [CHN]                         145             526
# Croatia (CRO)                              11              34
# Czech Republic (CZE) [CZE]                 23              68
# Czechoslovakia (TCH) [TCH]                 60             168
# Estonia (EST)                              16              40
# Finland (FIN)                             174             463
# France (FRA) [O] [P] [Z]                  293             780
# Germany (GER) [GER] [Z]                   270             782
# United Team of Germany (EUA) [EUA]         41             137
# East Germany (GDR) [GDR]                  162             519
# West Germany (FRG) [FRG]                   94             243
# Great Britain (GBR) [GBR] [Z]             284             806
# Italy (ITA) [M] [S]                       228             663
# Japan (JPN)                               160             443
# Kazakhstan (KAZ)                           22              59
# South Korea (KOR)                          90             296
# Netherlands (NED) [Z]                     139             376
# Norway (NOR) [Q]                          143             477
# Poland (POL)                              132             291
# Russia (RUS) [RUS]                        177             519
# Soviet Union (URS) [URS]                  355            1204
# Unified Team (EUN) [EUN]                   37             135
# Slovakia (SVK) [SVK]                        9              29
# Slovenia (SLO)                             18              34
# Spain (ESP) [Z]                            36             133
# Sweden (SWE) [Z]                          230             627
# Switzerland (SUI)                         113             323
# Ukraine (UKR)                              59             122
# United States (USA) [P] [Q] [R] [Z]       750            2681
# Uzbekistan (UZB)                           10              21

# %%
only_gold = df.where(df['Gold'] > 0)
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)             NaN       NaN             NaN
# Algeria (ALG)                 2.0       8.0            15.0
# Argentina (ARG)              24.0      28.0            70.0
# Armenia (ARM)                 2.0       9.0            12.0
# Australasia (ANZ) [ANZ]       4.0       5.0            12.0

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
df['Gold'].count()
# Out:
# 147

# %%
only_gold = only_gold.dropna()
only_gold.head()
# Out:
#                            # Summer   Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                  12.0    5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)                23.0   18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                   5.0    1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]         2.0    3.0     4.0     5.0   12.0       0.0
# Australia (AUS) [AUS] [Z]      25.0  139.0   152.0   177.0  468.0      18.0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                 0.0       0.0       0.0      0.0     15.0
# Argentina (ARG)               0.0       0.0       0.0      0.0     41.0
# Armenia (ARM)                 0.0       0.0       0.0      0.0     11.0
# Australasia (ANZ) [ANZ]       0.0       0.0       0.0      0.0      2.0
# Australia (AUS) [AUS] [Z]     5.0       3.0       4.0     12.0     43.0
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# Algeria (ALG)                 5.0       2.0       8.0            15.0
# Argentina (ARG)              18.0      24.0      28.0            70.0
# Armenia (ARM)                 1.0       2.0       9.0            12.0
# Australasia (ANZ) [ANZ]       3.0       4.0       5.0            12.0
# Australia (AUS) [AUS] [Z]   144.0     155.0     181.0           480.0

# %%
only_gold = df[df['Gold'] > 0]
only_gold.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# Algeria (ALG)                   5         2         8              15
# Argentina (ARG)                18        24        28              70
# Armenia (ARM)                   1         2         9              12
# Australasia (ANZ) [ANZ]         3         4         5              12
# Australia (AUS) [AUS] [Z]     144       155       181             480

# %%
len(df[(df['Gold'] > 0) | (df['Gold.1'] > 0)])
# Out:
# 101

# %%
df[(df['Gold'] > 0) | (df['Gold.1'] > 0)].head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# Algeria (ALG)                   5         2         8              15
# Argentina (ARG)                18        24        28              70
# Armenia (ARM)                   1         2         9              12
# Australasia (ANZ) [ANZ]         3         4         5              12
# Australia (AUS) [AUS] [Z]     144       155       181             480

# %%
df[(df['Gold.1'] > 0) & (df['Gold'] == 0)]
# Out:
#                      # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Liechtenstein (LIE)        16     0       0       0      0        18       2
#
#                      Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9       34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %% [markdown]
# # Indexing Dataframes

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)               0         2               2
# Algeria (ALG)                   2         8              15
# Argentina (ARG)                24        28              70
# Armenia (ARM)                   2         9              12
# Australasia (ANZ) [ANZ]         4         5              12

# %%
df['country'] = df.index
df = df.set_index('Gold')
df.head()
# Out:
#       # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0           13       0       2      2         0       0         0         0
# 5           12       2       8     15         3       0         0         0
# 18          23      24      28     70        18       0         0         0
# 1            5       2       9     12         6       0         0         0
# 3            2       4       5     12         0       0         0         0
#
#       Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0       13       0         0         2               2
# 5           0       15       5         2         8              15
# 18          0       41      18        24        28              70
# 1           0       11       1         2         9              12
# 3           0        2       3         4         5              12
#
#                       country
# Gold
# 0           Afghanistan (AFG)
# 5               Algeria (ALG)
# 18            Argentina (ARG)
# 1               Armenia (ARM)
# 3     Australasia (ANZ) [ANZ]

# %%
df = df.reset_index()
df.head()
# Out:
#    Gold  # Summer  Silver  Bronze  Total  # Winter  Gold.1  Silver.1  \
# 0     0        13       0       2      2         0       0         0
# 1     5        12       2       8     15         3       0         0
# 2    18        23      24      28     70        18       0         0
# 3     1         5       2       9     12         6       0         0
# 4     3         2       4       5     12         0       0         0
#
#    Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# 0         0        0       13       0         0         2               2
# 1         0        0       15       5         2         8              15
# 2         0        0       41      18        24        28              70
# 3         0        0       11       1         2         9              12
# 4         0        0        2       3         4         5              12
#
#                    country
# 0        Afghanistan (AFG)
# 1            Algeria (ALG)
# 2          Argentina (ARG)
# 3            Armenia (ARM)
# 4  Australasia (ANZ) [ANZ]

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# 1          7.242091         -2.915927         -3.012349          2.265971
# 2         14.832960         17.647293         21.845705         19.243287
# 3         -4.728132         -2.500690         -7.056824         -3.904217
# 4         -5.527043         -5.068871         -6.201001         -0.177537
#
#    RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# 0         -0.467369     1.030015     0.826644     1.383282     1.724718
# 1         -2.530799     7.606016    -2.626146    -2.722002     2.592270
# 2         17.197872    15.844176    18.559627    22.727626    20.317142
# 3        -10.543299    -4.874741    -2.758113    -7.167664    -3.978583
# 4          0.177258    -5.088389    -4.363636    -5.403729     0.754533
#
#    RNETMIG2015
# 0     0.712594
# 1    -2.187333
# 2    18.293499
# 3   -10.543299
# 4     1.107861
#
# [5 rows x 100 columns]

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df['diff'] = df['DIVISION'] - df['REGION']

df[df['diff'] == df['diff'].max()]
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME  \
# 68        40       4         9      2       0      Alaska
# 69        50       4         9      2      13      Alaska
# 70        50       4         9      2      16      Alaska
# 71        50       4         9      2      20      Alaska
# 72        50       4         9      2      50      Alaska
# 73        50       4         9      2      60      Alaska
# 74        50       4         9      2      68      Alaska
# 75        50       4         9      2      70      Alaska
# 76        50       4         9      2      90      Alaska
# 77        50       4         9      2     100      Alaska
# 78        50       4         9      2     105      Alaska
# 79        50       4         9      2     110      Alaska
# 94           Valdez-Cordova Census Area           9636               9636
# 95            Wrangell City and Borough           2369               2365
# 96             Yakutat City and Borough            662                662
# 97            Yukon-Koyukuk Census Area           5588               5588
# ...                                 ...            ...                ...
# 3010                       Ferry County           7551               7551
# 3011                    Franklin County          78163              78163
# 3012                    Garfield County           2266               2266
# 3013                       Grant County          89120              89120
# 3014                Grays Harbor County          72797              72797
# 3015                      Island County          78506              78506
# 3016                   Jefferson County          29872              29872
# 3017                        King County        1931249            1931256
# 3018                      Kitsap County         251133             251133
# 3019                    Kittitas County          40915              40909
# 3020                   Klickitat County          20318              20318
# 3021                       Lewis County          75455              75455
# 3022                     Lincoln County          10570              10570
# 3023                       Mason County          60699              60699
# 3024                    Okanogan County          41120              41120
# 3025                     Pacific County          20920              20920
# 3026                Pend Oreille County          13001              13001
# 3027                      Pierce County         795225             795229
# 3028                    San Juan County          15769              15769
# 3029                      Skagit County         116901             116901
# 3030                    Skamania County          11066              11066
# 3031                   Snohomish County         713335             713330
# 3032                     Spokane County         471221             471221
# 3033                     Stevens County          43531              43531
# 3034                    Thurston County         252264             252264
# 3035                   Wahkiakum County           3978               3978
# 3036                 Walla Walla County          58781              58781
# 3037                     Whatcom County         201140             201140
# 3038                     Whitman County          44776              44776
# 3039                      Yakima County         243231             243231
#
#       POPESTIMATE2010  ...   RDOMESTICMIG2012  RDOMESTICMIG2013  \
# 68             714021  ...          -1.946424         -3.915107
# 69               3169  ...         -12.221204        -17.257039
# 70               5546  ...           0.000000        -13.711875
# 71             293405  ...          -7.563712         -3.962343
# 72              17080  ...          -3.926031         -9.731949
# 73               1002  ...         -54.401583        -33.023736
# 74               1837  ...           2.647604          0.000000
# 75               4856  ...         -12.911035         -8.644954
# 76              98289  ...           5.430293         -9.147023
# 77               2501  ...          -5.059350         -3.506721
# 78               2147  ...           5.621926         -5.599627
# 79              31388  ...          -0.526080         -1.812930
# 80              55573  ...           3.211689         -4.349694
# 81              13525  ...          -5.341333        -11.325442
# 82              13651  ...          -1.578532        -16.758983
# 83               7464  ...          -6.345506          2.540973
# 84               1637  ...         -20.618557         -1.213961
# 85              89761  ...          11.474315         12.906763
# 86               9536  ...         -15.023093        -12.046363
# 87               9468  ...          -3.438575         -4.329897
# 88               7545  ...         -16.833927        -19.691670
# 89               3217  ...          -5.536758        -14.463764
# 90               6212  ...          -6.896552         -1.878081
# 91               8898  ...           3.339270        -12.626682
# 92                965  ...          22.575680         10.994503
# 93               7070  ...         -12.705061        -35.389496
# 94               9659  ...         -10.381334         -7.282798
# 95               2370  ...           5.432511          4.990643
# 96                662  ...          -6.134969        -35.686579
# 97               5588  ...          -4.885709        -17.029494
# ...               ...  ...                ...               ...
# 3010             7549  ...           3.509912         -7.169393
# 3011            79132  ...          13.644082         -7.633101
# 3012             2265  ...          -2.684564         15.212528
# 3013            89627  ...          -0.745839         -6.005613
# 3014            72857  ...          -9.577547         -9.048189
# 3015            78712  ...          -4.714239        -15.802112
# 3015   -12.710119     5.474938    13.164151     5
# 3016    10.856494    10.057090    11.702268     5
# 3017    12.704538    11.206066    10.589099     5
# 3018    -9.801432     1.260215    18.186905     5
# 3019     3.783797    16.179201    10.543466     5
# 3020     9.157068     0.862523     6.299363     5
# 3021    -5.876540    -0.984029     7.266422     5
# 3022   -12.353424    -2.629785     7.290755     5
# 3023    -3.857503     3.958959     6.063245     5
# 3024    -3.954487     1.720899     1.906762     5
# 3025    -0.781002    12.397804    18.792724     5
# 3026    -3.632710     5.884175    13.677053     5
# 3027     2.480196     7.920039     8.699104     5
# 3028     8.837547    11.409585    14.808848     5
# 3029     3.454727     9.712636     9.497421     5
# 3030     7.942883     4.249104     0.000000     5
# 3031    11.496756    11.768105    10.410479     5
# 3032     3.785143     6.474023     8.964867     5
# 3033    -5.085838     5.293623     4.785511     5
# 3034    10.485059     8.696573     8.779202     5
# 3035    22.114548     8.125077     0.000000     5
# 3036    -0.084027     1.189818     6.943693     5
# 3037     3.510734     7.101533    13.522667     5
# 3038    -0.834332    -1.471419    21.721074     5
# 3039    -6.734307    -6.674208    -4.172977     5
#
# [172 rows x 101 columns]

# %%
df[df['SUMLEV'] == 50].head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...   RDOMESTICMIG2012  \
# 1          54571              54571            54660  ...          -2.915927
# 2         182265             182265           183193  ...          17.647293
# 3          27457              27457            27341  ...          -2.500690
# 4          22915              22919            22861  ...          -5.068871
# 5          57322              57322            57373  ...          -1.177622
#
#    RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# 1         -3.012349          2.265971         -2.530799     7.606016
# 2         21.845705         19.243287         17.197872    15.844176
# 3         -7.056824         -3.904217        -10.543299    -4.874741
# 4         -6.201001         -0.177537          0.177258    -5.088389
# 5         -1.748766         -2.062535         -1.369970     1.859511
#
#    RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  diff
# 1    -2.626146    -2.722002     2.592270    -2.187333     3
# 2    18.559627    22.727626    20.317142    18.293499     3
# 3    -2.758113    -7.167664    -3.978583   -10.543299     3
# 4    -4.363636    -5.403729     0.754533     1.107861     3
# 5    -0.848580    -1.402476    -1.577232    -0.884411     3
#
# [5 rows x 101 columns]

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']
df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 0  Alabama         Alabama       14226       59689       59062       57938
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0       58334       58305          4785161          4801108          4816089
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# 0          4830533          4846411          4858979
# 1            55038            55290            55347
# 2           195126           199713           203709
# 3            26973            26815            26489
# 4            22512            22549            22583

# %%
df = df.set_index(['STNAME', 'CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama              14226       59689       59062       57938
#         Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama              58334       58305          4785161
#         Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Alabama                 4801108          4816089          4830533
#         Autauga County            55253            55175            55038
#         Baldwin County           186659           190396           195126
#         Barbour County            27226            27159            26973
#         Bibb County               22733            22642            22512
#
#                         POPESTIMATE2014  POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Alabama                 4846411          4858979
#         Autauga County            55290            55347
#         Baldwin County           199713           203709
#         Barbour County            26815            26489
#         Bibb County               22549            22583

# %%
df.loc['Michigan', 'Washtenaw County']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880

# %%
df.loc[ [('Michigan', 'Washtenaw County'),
         ('Michigan', 'Wayne County')] ]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Wayne County           23607       23586          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Wayne County              1801273          1792514          1775713
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Wayne County              1766008          1759335

# %% [markdown]
# # Missing values

# %%
df = pd.read_csv('log.csv')
df

# %%
df.fillna?

# %%
df = df.set_index('time')
df = df.sort_index()
df

# %%
df = df.reset_index()
df = df.set_index(['time', 'user'])
df

# %%
df = df.fillna(method='ffill')
df.head()
